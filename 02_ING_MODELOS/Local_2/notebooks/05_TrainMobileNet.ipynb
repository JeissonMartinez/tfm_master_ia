# %% [markdown]
# # 🧠 MobileNetV3 Small + SSD-Lite para ESP32-S3
#
# **Objetivo**: Entrenar un modelo de detección de objetos ligero usando Transfer Learning con MobileNetV3 Small como backbone y cabezal SSD-Lite, optimizado para despliegue en ESP32-S3 (N16R8).
#
# ## Arquitectura
#
# - **Backbone**: MobileNetV3 Small (minimalistic=True para compatibilidad TFLite)
# - **Head**: SSD-Lite con convoluciones separables en profundidad
# - **Clases**: 4 (door, footpath, obstacle, person)
# - **Input**: 224×224×3 RGB
#
# ## Estrategia de Entrenamiento (2 Fases)
#
# | Fase | Backbone | LR | Épocas | Objetivo |
# |------|----------|----|---------| ---------|
# | 1. Warm-up | 🔒 Congelado | 1e-3 | 15 | Entrenar solo el cabezal SSD-Lite |
# | 2. Fine-tuning | 🔓 Últimas 30 capas | 1e-5 | 100 | Ajustar backbone + head con early stopping |
#
# ## Manejo de Desbalance
#
# - **Focal Loss** (α=0.25, γ=2.0) para enfocar en ejemplos difíciles
# - **Class Weights** calculados por frecuencia inversa

# %% [markdown]
# ## 1. Setup y Configuración

# %%
# Imports y configuración inicial
import os
import sys
import json
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Suprimir warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# TensorFlow
import tensorflow as tf
print(f"TensorFlow version: {tf.__version__}")
print(f"GPU disponible: {tf.config.list_physical_devices('GPU')}")

# Configurar memoria GPU (evitar OOM)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ Memory growth habilitado para {len(gpus)} GPU(s)")
    except RuntimeError as e:
        print(f"⚠️ Error configurando GPU: {e}")
# Out:
# TensorFlow version: 2.16.2
# GPU disponible: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ✅ Memory growth habilitado para 1 GPU(s)

# %%
# Agregar paths al sistema
PROJECT_ROOT = Path.cwd().parent.parent  # TFM_UNIR
ING_MODELOS = PROJECT_ROOT / "02_ING_MODELOS"
ING_DATOS = PROJECT_ROOT / "01_ING_DATOS"

# Agregar módulos personalizados
sys.path.insert(0, str(ING_MODELOS))
sys.path.insert(0, str(ING_MODELOS / "src_mobilenet"))

print(f"📁 Project root: {PROJECT_ROOT}")
print(f"📁 ING_MODELOS: {ING_MODELOS}")
print(f"📁 ING_DATOS: {ING_DATOS}")
# Out:
# 📁 Project root: /Users/admin/Documents/TFM_UNIR
# 📁 ING_MODELOS: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS
# 📁 ING_DATOS: /Users/admin/Documents/TFM_UNIR/01_ING_DATOS

# %%
# Importar módulos personalizados de src_mobilenet
from src_mobilenet.utils_mobilenet_model import (
    build_mobilenetv3_ssd_lite,
    build_mobilenetv3_large_ssd_lite,  # NEW: MobileNetV3 Large backbone
    build_mobilenetv2_ssd_lite,
    print_model_summary,
)
from src_mobilenet.utils_mobilenet_data import (
    load_coco_annotations,
    compute_class_weights,
    generate_anchors,
    COCODataGenerator,
    compute_anchor_statistics,
    ObstacleBank,  # 🧬 NEW: Copy-Paste Augmentation
    apply_copy_paste_augmentation,  # 🧬 NEW: Copy-Paste function
)
from src_mobilenet.utils_mobilenet_losses import (
    focal_loss,
    binary_focal_loss,
    smooth_l1_loss,
    ssd_combined_loss,
)
from src_mobilenet.utils_mobilenet_train import (
    freeze_backbone,
    unfreeze_backbone_layers,
    create_callbacks,
    train_two_phase,
    save_training_history,
    plot_training_history,
    LearningRateLogger,
)
from src_mobilenet.utils_mobilenet_export import (
    export_tflite,
    export_tflite_int8,
    export_for_esp32,
    estimate_model_size,
    verify_tflite_model,
)

print("✅ Módulos de src_mobilenet importados correctamente")
# Out:
# ✅ Módulos de src_mobilenet importados correctamente

# %% [markdown]
# ## 🔬 Configuración del Experimento
#
# Esta sección define los parámetros del experimento actual. Modifica estas variables para crear diferentes experimentos:
#
# - **EXPERIMENT_NAME**: Identificador único del experimento
# - **SELECTED_CLASSES**: Subconjunto de clases a entrenar (o None para todas)
# - **AUGMENTATION_LEVEL**: "none", "light", "medium", "heavy"

# %%
# ============================================
# 🔬 CONFIGURACIÓN DEL EXPERIMENTO
# ============================================
# Modifica estos valores para cada experimento diferente

# Nombre único del experimento
EXPERIMENT_NAME = "MBNTv3_ssdlite_v7"

# Descripción del experimento
EXPERIMENT_DESCRIPTION = "MobileNetV3 Small + Copy-Paste Augmentation para obstacles. Objetivo: Obstacle AP ≥ 40%, Gap < 40pp, Size < 800KB"

# Clases a incluir (None = todas, o lista de nombres)
# Ejemplo: ["door", "person"] para entrenar solo 2 clases
# SELECTED_CLASSES = None  # Usar todas: door, footpath, obstacle, person
SELECTED_CLASSES = ["obstacle", "footpath"]  # Excluir person y door

# Nivel de augmentación: "none", "light", "medium", "heavy"
AUGMENTATION_LEVEL = "heavy"

# ============================================
# 🏗️ SELECCIÓN DE BACKBONE
# ============================================
# Opciones disponibles:
#   "small"  - MobileNetV3 Small (default, ~736KB INT8)
#   "large"  - MobileNetV3 Large (más capacidad, ~1.0-1.3MB INT8)
#   "v2"     - MobileNetV2 (alternativa legacy)
BACKBONE_TYPE = "small"  # <-- v7: Volvemos a Small para cumplir límite ESP32

# ============================================
# 🧬 COPY-PASTE AUGMENTATION (NUEVA TÉCNICA)
# ============================================
# Activa pegar obstacles de otras imágenes para aumentar variabilidad
COPY_PASTE_ENABLED = True
COPY_PASTE_CONFIG = {
    "enabled": COPY_PASTE_ENABLED,
    "target_class_idx": 1,  # obstacle = class index 1
    "num_pastes": 2,        # Intentar pegar 2 obstacles por imagen
    "paste_prob": 0.5,      # 50% probabilidad por intento
    "scale_range": (0.6, 1.4),  # Escalar entre 60% y 140%
    "blend_mode": "direct", # Pegar directamente (sin blending)
}

# ============================================
# Importar gestión de experimentos
# ============================================
from src_mobilenet.utils_mobilenet_experiment import (
    ExperimentConfig,
    ExperimentResults,
    Experiment,
    save_experiment,
    create_default_config,
)
from src_mobilenet.utils_mobilenet_eval import (
    evaluate_model_full,
    compare_keras_vs_tflite,
    plot_confusion_matrix,
)
from src_mobilenet.utils_mobilenet_infer import (
    postprocess_detections,
    visualize_detections,
    visualize_predictions_nms,
    run_inference_keras,
    run_inference_tflite,
)

print(f"🔬 Experimento: {EXPERIMENT_NAME}")
print(f"📝 Descripción: {EXPERIMENT_DESCRIPTION}")
print(f"📋 Clases seleccionadas: {SELECTED_CLASSES or 'Todas (4 clases)'}")
print(f"🔄 Augmentación: {AUGMENTATION_LEVEL}")
print(f"🏗️ Backbone: MobileNetV3 {BACKBONE_TYPE.upper()}")
print(f"🧬 Copy-Paste Augmentation: {'ACTIVADO' if COPY_PASTE_ENABLED else 'DESACTIVADO'}")
# Out:
# 🔬 Experimento: MBNTv3_ssdlite_v7
# 📝 Descripción: MobileNetV3 Small + Copy-Paste Augmentation para obstacles. Objetivo: Obstacle AP ≥ 40%, Gap < 40pp, Size < 800KB
# 📋 Clases seleccionadas: ['obstacle', 'footpath']
# 🔄 Augmentación: heavy
# 🏗️ Backbone: MobileNetV3 SMALL
# 🧬 Copy-Paste Augmentation: ACTIVADO

# %%
# ============================================
# CONFIGURACIÓN DE RUTAS Y PARÁMETROS
# ============================================

# --- Rutas del Dataset ---
TRAIN_IMG_DIR = ING_DATOS / "Dataset/train/augmented2_images"
TRAIN_JSON = ING_DATOS / "Dataset/train/augmented2_images/train_final2.json"

VAL_IMG_DIR = ING_DATOS / "Dataset/valid"
VAL_JSON = ING_DATOS / "Dataset/valid/val_final.json"

TEST_IMG_DIR = ING_DATOS / "Dataset/test"
TEST_JSON = ING_DATOS / "Dataset/test/test_final.json"

# --- Rutas de Salida ---
REPORTS_DIR = ING_MODELOS / "reports"
FIGURES_DIR = ING_MODELOS / "reports/figures" / EXPERIMENT_NAME 
MODELS_DIR = ING_MODELOS / "models"
CHECKPOINTS_DIR = ING_MODELOS / "models/checkpoints"
EXPORT_DIR = ING_MODELOS / "models/final_export"
LOGS_DIR = ING_MODELOS / "logs"
DATASETS_DIR = ING_MODELOS / "datasets/mobilenet"

# Crear directorios
for d in [REPORTS_DIR, FIGURES_DIR, MODELS_DIR, CHECKPOINTS_DIR, EXPORT_DIR, LOGS_DIR, DATASETS_DIR]:
    d.mkdir(parents=True, exist_ok=True)

# --- Parámetros del Modelo ---
IMG_SIZE = 224

# Clases: se actualizan después de cargar el dataset si SELECTED_CLASSES está definido
if SELECTED_CLASSES is not None:
    CLASS_NAMES = SELECTED_CLASSES
    NUM_CLASSES = len(SELECTED_CLASSES)
else:
    CLASS_NAMES = ["door", "footpath", "obstacle", "person"]  # Orden por category_id
    NUM_CLASSES = 4

print(f"   Clases ({NUM_CLASSES}): {CLASS_NAMES}")

# --- Parámetros de Anchors ---
FEATURE_MAP_SIZE = 7  # 224 / 32
ANCHOR_SCALES = [0.03, 0.08, 0.2, 0.45]
ANCHOR_RATIOS = [0.5, 1.0, 2.0]
NUM_ANCHORS_PER_CELL = len(ANCHOR_SCALES) * len(ANCHOR_RATIOS)
IOU_THRESHOLD = 0.35

# --- Hiperparámetros de Entrenamiento ---
BATCH_SIZE = 16

# Fase 1: Warm-up
PHASE1_EPOCHS = 30
PHASE1_LR = 1e-3

# Fase 2: Fine-tuning  
PHASE2_EPOCHS = 50
PHASE2_LR = 5e-5
NUM_LAYERS_TO_UNFREEZE = 50  # Aumentado para MobileNetV3 Large (más capas)

# Callbacks
PATIENCE_REDUCE_LR = 7
PATIENCE_EARLY_STOP = 12
REDUCE_LR_FACTOR = 0.5

# Loss weights
CLS_WEIGHT = 1.5
OBJ_WEIGHT = 2.0
BBOX_WEIGHT = 1.0

# Focal Loss params
FOCAL_ALPHA = 0.25
FOCAL_GAMMA = 2.0

# Umbral de puntuación para filtrar detecciones en evaluación/inferencia
SCORE_THRESHOLD = 0.35

# NMS 
NMS_IOU_THRESHOLD = 0.4

# ============================================
# 🏗️ PARÁMETROS ESPECÍFICOS DEL BACKBONE
# ============================================
# Estos parámetros dependen del BACKBONE_TYPE seleccionado

if BACKBONE_TYPE == "large":
    # MobileNetV3 Large: más capacidad, ~1.0-1.3MB INT8
    ALPHA = 0.75  # Con minimalistic=False, soporta 0.75 o 1.0
    MINIMALISTIC = False  # Usa hard-swish (más capacidad, puede ser más lento en ESP32)
    FEATURE_CHANNELS = 128  # Reducido porque Large ya tiene más canales internos
    DROPOUT_RATE = 0.3
elif BACKBONE_TYPE == "small":
    # MobileNetV3 Small: default, ~736KB INT8
    ALPHA = 1.0  # Con minimalistic=True, solo soporta 1.0
    MINIMALISTIC = True  # Usa ReLU (mejor para ESP32-S3)
    FEATURE_CHANNELS = 192
    DROPOUT_RATE = 0.35
else:  # v2
    # MobileNetV2: legacy, ~250-400KB INT8
    ALPHA = 0.35
    MINIMALISTIC = True
    FEATURE_CHANNELS = 128
    DROPOUT_RATE = 0.2

# Nombre del experimento
MODEL_NAME = EXPERIMENT_NAME

print("✅ Configuración cargada")
print(f"   Dataset train: {TRAIN_IMG_DIR}")
print(f"   Modelo: {MODEL_NAME}")
print(f"   Backbone: MobileNetV3 {BACKBONE_TYPE.upper()}")
print(f"   Alpha: {ALPHA}")
print(f"   Minimalistic: {MINIMALISTIC}")
print(f"   Feature channels: {FEATURE_CHANNELS}")
print(f"   Dropout rate: {DROPOUT_RATE}")
print(f"   Anchors por celda: {NUM_ANCHORS_PER_CELL}")
# Out:
#    Clases (2): ['obstacle', 'footpath']
# ✅ Configuración cargada
#    Dataset train: /Users/admin/Documents/TFM_UNIR/01_ING_DATOS/Dataset/train/augmented2_images
#    Modelo: MBNTv3_ssdlite_v7
#    Backbone: MobileNetV3 SMALL
#    Alpha: 1.0
#    Minimalistic: True
#    Feature channels: 192
#    Dropout rate: 0.35
#    Anchors por celda: 12

# %% [markdown]
# ## 2. Cargar y Analizar Dataset

# %%
# Cargar anotaciones COCO (con filtrado opcional de clases)
print("📂 Cargando dataset de entrenamiento...")
train_data, cat_id_to_name, cat_id_to_idx, CLASS_NAMES = load_coco_annotations(
    json_path=str(TRAIN_JSON),
    image_dir=str(TRAIN_IMG_DIR),
    allowed_classes=SELECTED_CLASSES,  # Filtra clases si está definido
)

# Actualizar NUM_CLASSES basado en el dataset cargado
NUM_CLASSES = len(CLASS_NAMES)
print(f"   Clases activas ({NUM_CLASSES}): {CLASS_NAMES}")

print("\n📂 Cargando dataset de validación...")
val_data, _, _, _ = load_coco_annotations(
    json_path=str(VAL_JSON),
    image_dir=str(VAL_IMG_DIR),
    allowed_classes=SELECTED_CLASSES,
)

print("\n📂 Cargando dataset de test...")
test_data, _, _, _ = load_coco_annotations(
    json_path=str(TEST_JSON),
    image_dir=str(TEST_IMG_DIR),
    allowed_classes=SELECTED_CLASSES,
)

print(f"\n📊 Resumen del Dataset:")
print(f"   Train: {len(train_data)} imágenes")
print(f"   Val:   {len(val_data)} imágenes")
print(f"   Test:  {len(test_data)} imágenes")
# Out:
# 📂 Cargando dataset de entrenamiento...
# 📋 Filtering to 2 classes: ['footpath', 'obstacle']
#    Removed 376 images with no annotations for selected classes
# ✅ Loaded 995 images with annotations
#    Categories: {5: 'footpath', 6: 'obstacle'}
#    Class mapping: {5: 0, 6: 1}
#    Class names (ordered): ['footpath', 'obstacle']
#    Clases activas (2): ['footpath', 'obstacle']
#
# 📂 Cargando dataset de validación...
# 📋 Filtering to 2 classes: ['footpath', 'obstacle']
#    Removed 17 images with no annotations for selected classes
# ✅ Loaded 68 images with annotations
#    Categories: {5: 'footpath', 6: 'obstacle'}
#    Class mapping: {5: 0, 6: 1}
#    Class names (ordered): ['footpath', 'obstacle']
#
# 📂 Cargando dataset de test...
# 📋 Filtering to 2 classes: ['footpath', 'obstacle']
#    Removed 13 images with no annotations for selected classes
# ✅ Loaded 71 images with annotations
#    Categories: {5: 'footpath', 6: 'obstacle'}
#    Class mapping: {5: 0, 6: 1}
#    Class names (ordered): ['footpath', 'obstacle']
#
# 📊 Resumen del Dataset:
#    Train: 995 imágenes
#    Val:   68 imágenes
#    Test:  71 imágenes

# %%
# Calcular pesos de clase para manejar desbalance
# class_weights = compute_class_weights(train_data, NUM_CLASSES, method="effective_samples")  # method="inverse_freq"

class_weights = np.array([0.7, 2.0])  # Manuales [footpath, obstacle]

# Convertir a tensor para la loss function
class_weights_tensor = tf.constant(class_weights, dtype=tf.float32)
print(f"\n⚖️ Class weights tensor: {class_weights}")
# Out:
# ⚖️ Class weights tensor: [0.7 2. ]

# %%
# Visualizar distribución de clases
from collections import Counter

def plot_class_distribution(data_list, title="Class Distribution"):
    """Visualizar distribución de clases."""
    class_counts = Counter()
    for img in data_list:
        for cls in img["classes"]:
            class_counts[cls] += 1
    
    classes = list(range(NUM_CLASSES))
    counts = [class_counts.get(c, 0) for c in classes]
    
    fig, ax = plt.subplots(figsize=(10, 5))
    bars = ax.bar(CLASS_NAMES, counts, color=['#2ecc71', '#3498db', '#e74c3c', '#9b59b6'])
    ax.set_xlabel('Clase')
    ax.set_ylabel('Número de instancias')
    ax.set_title(title)
    
    # Agregar etiquetas en las barras
    for bar, count in zip(bars, counts):
        height = bar.get_height()
        ax.annotate(f'{count}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points",
                    ha='center', va='bottom', fontsize=12)
    
    plt.tight_layout()
    return fig

fig = plot_class_distribution(train_data, "Distribución de Clases - Train")
fig.savefig(FIGURES_DIR /   "mobilenet_class_distribution.png", dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3. Generar Anchors y Data Generators

# %%
# Generar anchors para SSD
anchors = generate_anchors(
    feature_map_size=FEATURE_MAP_SIZE,
    scales=ANCHOR_SCALES,
    aspect_ratios=ANCHOR_RATIOS,
)

print(f"📦 Anchors generados: {anchors.shape}")
print(f"   Feature map: {FEATURE_MAP_SIZE}×{FEATURE_MAP_SIZE}")
print(f"   Anchors por celda: {NUM_ANCHORS_PER_CELL}")
print(f"   Total anchors: {len(anchors)}")

# Estadísticas de los anchors
print(f"\n   Tamaños de anchors (w×h):")
for scale in ANCHOR_SCALES:
    for ratio in ANCHOR_RATIOS:
        w = scale * np.sqrt(ratio)
        h = scale / np.sqrt(ratio)
        print(f"      scale={scale}, ratio={ratio:.1f} → w={w:.3f}, h={h:.3f}")
# Out:
# 📦 Anchors generados: (588, 4)
#    Feature map: 7×7
#    Anchors por celda: 12
#    Total anchors: 588
#
#    Tamaños de anchors (w×h):
#       scale=0.03, ratio=0.5 → w=0.021, h=0.042
#       scale=0.03, ratio=1.0 → w=0.030, h=0.030
#       scale=0.03, ratio=2.0 → w=0.042, h=0.021
#       scale=0.08, ratio=0.5 → w=0.057, h=0.113
#       scale=0.08, ratio=1.0 → w=0.080, h=0.080
#       scale=0.08, ratio=2.0 → w=0.113, h=0.057
#       scale=0.2, ratio=0.5 → w=0.141, h=0.283
#       scale=0.2, ratio=1.0 → w=0.200, h=0.200
#       scale=0.2, ratio=2.0 → w=0.283, h=0.141
#       scale=0.45, ratio=0.5 → w=0.318, h=0.636
#       scale=0.45, ratio=1.0 → w=0.450, h=0.450
#       scale=0.45, ratio=2.0 → w=0.636, h=0.318

# %%
# Verificar matching de anchors con el dataset
anchor_stats = compute_anchor_statistics(train_data, anchors, iou_threshold=IOU_THRESHOLD)
# Out:
# 📊 Anchor Matching Statistics:
#    Total GT boxes: 2432
#    Matched GT boxes (IoU≥0.35): 2001 (82.3%)
#    Avg max IoU per GT: 0.500
#    Min max IoU: 0.093
#    Avg positive anchors/image: 18.6

# %%
# Crear generadores de datos
print("🔧 Creando generadores de datos...")
print(f"   Nivel de augmentación: {AUGMENTATION_LEVEL}")
print(f"   Copy-Paste: {'ACTIVADO' if COPY_PASTE_ENABLED else 'DESACTIVADO'}")

train_gen = COCODataGenerator(
    images_data=train_data,
    anchors=anchors,
    batch_size=BATCH_SIZE,
    img_size=IMG_SIZE,
    num_classes=NUM_CLASSES,
    iou_threshold=IOU_THRESHOLD,
    augmentation_level=AUGMENTATION_LEVEL,  # Usar nivel configurado
    shuffle=True,
    copy_paste_config=COPY_PASTE_CONFIG if COPY_PASTE_ENABLED else None,  # 🧬 NUEVO: Copy-Paste
)

val_gen = COCODataGenerator(
    images_data=val_data,
    anchors=anchors,
    batch_size=BATCH_SIZE,
    img_size=IMG_SIZE,
    num_classes=NUM_CLASSES,
    iou_threshold=IOU_THRESHOLD,
    augmentation_level="none",  # Sin augmentación para validación
    shuffle=False,
)

test_gen = COCODataGenerator(
    images_data=test_data,
    anchors=anchors,
    batch_size=BATCH_SIZE,
    img_size=IMG_SIZE,
    num_classes=NUM_CLASSES,
    iou_threshold=IOU_THRESHOLD,
    augmentation_level="none",  # Sin augmentación para test
    shuffle=False,
)

print(f"✅ Generadores creados:")
print(f"   Train: {len(train_gen)} batches × {BATCH_SIZE} = ~{len(train_gen)*BATCH_SIZE} samples")
print(f"   Val:   {len(val_gen)} batches")
print(f"   Test:  {len(test_gen)} batches")
# Out:
# 🔧 Creando generadores de datos...
#    Nivel de augmentación: heavy
#    Copy-Paste: ACTIVADO
# 🏦 Building obstacle bank for class 1...
#    ✅ Extracted 1620 obstacle crops
# 📊 DataGenerator: 995 images, augmentation=heavy, copy-paste=enabled
# 📊 DataGenerator: 68 images, augmentation=none, copy-paste=disabled
# 📊 DataGenerator: 71 images, augmentation=none, copy-paste=disabled
# ✅ Generadores creados:
#    Train: 63 batches × 16 = ~1008 samples
#    Val:   5 batches
#    Test:  5 batches

# %%
# Verificar un batch
sample_batch_x, sample_batch_y = train_gen[0]

print(f"📊 Verificación de batch:")
print(f"   X shape: {sample_batch_x.shape}")
print(f"   Y objectness shape: {sample_batch_y['objectness'].shape}")
print(f"   Y class_out shape: {sample_batch_y['class_out'].shape}")
print(f"   Y bbox_out shape: {sample_batch_y['bbox_out'].shape}")

# Estadísticas de positivos
positives_per_sample = sample_batch_y['objectness'].sum(axis=(1, 2))
print(f"\n   Positivos por imagen: min={positives_per_sample.min():.0f}, max={positives_per_sample.max():.0f}, mean={positives_per_sample.mean():.1f}")
# Out:
# 📊 Verificación de batch:
#    X shape: (16, 224, 224, 3)
#    Y objectness shape: (16, 588, 1)
#    Y class_out shape: (16, 588, 2)
#    Y bbox_out shape: (16, 588, 4)
#
#    Positivos por imagen: min=1, max=57, mean=23.9

# %% [markdown]
# ## 4. Construir Modelo MobileNetV3 + SSD-Lite

# %%
# ============================================
# CONSTRUIR MODELO SEGÚN BACKBONE SELECCIONADO
# ============================================
# El backbone se selecciona con BACKBONE_TYPE en la celda de configuración

if BACKBONE_TYPE == "large":
    print("🏗️ Construyendo MobileNetV3 LARGE + SSD-Lite...")
    model = build_mobilenetv3_large_ssd_lite(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        num_classes=NUM_CLASSES,
        num_anchors_per_cell=NUM_ANCHORS_PER_CELL,
        alpha=ALPHA,
        minimalistic=MINIMALISTIC,
        feature_channels=FEATURE_CHANNELS,
        use_batchnorm=True,
        dropout_rate=DROPOUT_RATE,
        model_name=MODEL_NAME,
    )
elif BACKBONE_TYPE == "small":
    print("🏗️ Construyendo MobileNetV3 SMALL + SSD-Lite...")
    model = build_mobilenetv3_ssd_lite(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        num_classes=NUM_CLASSES,
        num_anchors_per_cell=NUM_ANCHORS_PER_CELL,
        alpha=ALPHA,
        minimalistic=MINIMALISTIC,
        feature_channels=FEATURE_CHANNELS,
        use_batchnorm=True,
        dropout_rate=DROPOUT_RATE,
        model_name=MODEL_NAME,
    )
else:  # v2
    print("🏗️ Construyendo MobileNetV2 + SSD-Lite...")
    model = build_mobilenetv2_ssd_lite(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        num_classes=NUM_CLASSES,
        num_anchors_per_cell=NUM_ANCHORS_PER_CELL,
        alpha=ALPHA,
        feature_channels=FEATURE_CHANNELS,
        use_batchnorm=True,
        dropout_rate=DROPOUT_RATE,
        model_name=MODEL_NAME,
    )

print_model_summary(model)
# Out:
# 🏗️ Construyendo MobileNetV3 SMALL + SSD-Lite...
#
# ============================================================
# Model: MBNTv3_ssdlite_v7
# ============================================================
# Total params: 616,188
# Trainable params: 601,772
# Non-trainable params: 14,416
# ============================================================
# Estimated size (float32): 2.35 MB
# Estimated size (int8): 0.59 MB
# ============================================================

# %%
# ============================================
# COMPARACIÓN DE BACKBONES DISPONIBLES
# ============================================
# Esta celda es solo informativa. El backbone se selecciona con BACKBONE_TYPE.

backbones_info = """
┌─────────────────────┬──────────┬─────────────┬──────────────┬──────────────────┐
│ Backbone            │ Alpha    │ Tamaño INT8 │ Capacidad    │ ESP32-S3         │
├─────────────────────┼──────────┼─────────────┼──────────────┼──────────────────┤
│ MobileNetV3 Small   │ 1.0      │ ~600-800KB  │ Media        │ ✅ Recomendado   │
│ MobileNetV3 Large   │ 0.75     │ ~1.0-1.3MB  │ Alta         │ ✅ Dentro límite │
│ MobileNetV3 Large   │ 1.0      │ ~1.5-1.8MB  │ Muy Alta     │ ⚠️ Ajustado      │
│ MobileNetV2         │ 0.35     │ ~250-400KB  │ Baja         │ ✅ Muy ligero    │
└─────────────────────┴──────────┴─────────────┴──────────────┴──────────────────┘

Nota: MobileNetV3 Large con minimalistic=False usa hard-swish, lo cual puede
ser más lento en ESP32-S3 pero proporciona mayor capacidad de extracción de features.
"""
print(backbones_info)
print(f"🔧 Backbone actual: {BACKBONE_TYPE.upper()} (alpha={ALPHA})")
# Out:
# ┌─────────────────────┬──────────┬─────────────┬──────────────┬──────────────────┐
# │ Backbone            │ Alpha    │ Tamaño INT8 │ Capacidad    │ ESP32-S3         │
# ├─────────────────────┼──────────┼─────────────┼──────────────┼──────────────────┤
# │ MobileNetV3 Small   │ 1.0      │ ~600-800KB  │ Media        │ ✅ Recomendado   │
# │ MobileNetV3 Large   │ 0.75     │ ~1.0-1.3MB  │ Alta         │ ✅ Dentro límite │
# │ MobileNetV3 Large   │ 1.0      │ ~1.5-1.8MB  │ Muy Alta     │ ⚠️ Ajustado      │
# │ MobileNetV2         │ 0.35     │ ~250-400KB  │ Baja         │ ✅ Muy ligero    │
# └─────────────────────┴──────────┴─────────────┴──────────────┴──────────────────┘
#
# Nota: MobileNetV3 Large con minimalistic=False usa hard-swish, lo cual puede
# ser más lento en ESP32-S3 pero proporciona mayor capacidad de extracción de features.
#
# 🔧 Backbone actual: SMALL (alpha=1.0)

# %%
# Visualizar arquitectura del modelo
model.summary(show_trainable=True, expand_nested=False)
# Out:
# Model: "MBNTv3_ssdlite_v7"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer       │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv (Conv2D)     │ (None, 112,     │       432 │ input_layer[0… │   Y   │
# │                   │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv_bn           │ (None, 112,     │        64 │ conv[0][0]     │   Y   │
# │ (BatchNormalizat… │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu (ReLU)      │ (None, 112,     │         0 │ conv_bn[0][0]  │   -   │
# │                   │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 113,     │         0 │ re_lu[0][0]    │   -   │
# │ (ZeroPadding2D)   │ 113, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 56, 56,  │       144 │ expanded_conv… │   Y   │
# │ (DepthwiseConv2D) │ 16)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 56, 56,  │        64 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 16)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_1 (ReLU)    │ (None, 56, 56,  │         0 │ expanded_conv… │   -   │
# │                   │ 16)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_pr… │ (None, 56, 56,  │       256 │ re_lu_1[0][0]  │   Y   │
# │ (Conv2D)          │ 16)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_pr… │ (None, 56, 56,  │        64 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 16)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_1_… │ (None, 56, 56,  │     1,152 │ expanded_conv… │   Y   │
# │ (Conv2D)          │ 72)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_1_… │ (None, 56, 56,  │       288 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 72)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_2 (ReLU)    │ (None, 56, 56,  │         0 │ expanded_conv… │   -   │
# │                   │ 72)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_1_… │ (None, 57, 57,  │         0 │ re_lu_2[0][0]  │   -   │
# │ (ZeroPadding2D)   │ 72)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_1_… │ (None, 28, 28,  │       648 │ expanded_conv… │   Y   │
# │ (DepthwiseConv2D) │ 72)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_1_… │ (None, 28, 28,  │       288 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 72)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_3 (ReLU)    │ (None, 28, 28,  │         0 │ expanded_conv… │   -   │
# │                   │ 72)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_1_… │ (None, 28, 28,  │     1,728 │ re_lu_3[0][0]  │   Y   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_1_… │ (None, 28, 28,  │        96 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_2_… │ (None, 28, 28,  │     2,112 │ expanded_conv… │   Y   │
# │ (Conv2D)          │ 88)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_2_… │ (None, 28, 28,  │       352 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 88)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_4 (ReLU)    │ (None, 28, 28,  │         0 │ expanded_conv… │   -   │
# │                   │ 88)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_2_… │ (None, 28, 28,  │       792 │ re_lu_4[0][0]  │   Y   │
# │ (DepthwiseConv2D) │ 88)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_2_… │ (None, 28, 28,  │       352 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 88)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_5 (ReLU)    │ (None, 28, 28,  │         0 │ expanded_conv… │   -   │
# │                   │ 88)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_2_… │ (None, 28, 28,  │     2,112 │ re_lu_5[0][0]  │   Y   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_2_… │ (None, 28, 28,  │        96 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_2_… │ (None, 28, 28,  │         0 │ expanded_conv… │   -   │
# │ (Add)             │ 24)             │           │ expanded_conv… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_3_… │ (None, 28, 28,  │     2,304 │ expanded_conv… │   Y   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_3_… │ (None, 28, 28,  │       384 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_6 (ReLU)    │ (None, 28, 28,  │         0 │ expanded_conv… │   -   │
# │                   │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_3_… │ (None, 29, 29,  │         0 │ re_lu_6[0][0]  │   -   │
# │ (ZeroPadding2D)   │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_3_… │ (None, 14, 14,  │       864 │ expanded_conv… │   Y   │
# │ (DepthwiseConv2D) │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_3_… │ (None, 14, 14,  │       384 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_7 (ReLU)    │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │                   │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_3_… │ (None, 14, 14,  │     3,840 │ re_lu_7[0][0]  │   Y   │
# │ (Conv2D)          │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_3_… │ (None, 14, 14,  │       160 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_4_… │ (None, 14, 14,  │     9,600 │ expanded_conv… │   Y   │
# │ (Conv2D)          │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_4_… │ (None, 14, 14,  │       960 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_8 (ReLU)    │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │                   │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_4_… │ (None, 14, 14,  │     2,160 │ re_lu_8[0][0]  │   Y   │
# │ (DepthwiseConv2D) │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_4_… │ (None, 14, 14,  │       960 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_9 (ReLU)    │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │                   │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_4_… │ (None, 14, 14,  │     9,600 │ re_lu_9[0][0]  │   Y   │
# │ (Conv2D)          │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_4_… │ (None, 14, 14,  │       160 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_4_… │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │ (Add)             │ 40)             │           │ expanded_conv… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_5_… │ (None, 14, 14,  │     9,600 │ expanded_conv… │   Y   │
# │ (Conv2D)          │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_5_… │ (None, 14, 14,  │       960 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_10 (ReLU)   │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │                   │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_5_… │ (None, 14, 14,  │     2,160 │ re_lu_10[0][0] │   Y   │
# │ (DepthwiseConv2D) │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_5_… │ (None, 14, 14,  │       960 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_11 (ReLU)   │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │                   │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_5_… │ (None, 14, 14,  │     9,600 │ re_lu_11[0][0] │   Y   │
# │ (Conv2D)          │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_5_… │ (None, 14, 14,  │       160 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_5_… │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │ (Add)             │ 40)             │           │ expanded_conv… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_6_… │ (None, 14, 14,  │     4,800 │ expanded_conv… │   Y   │
# │ (Conv2D)          │ 120)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_6_… │ (None, 14, 14,  │       480 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 120)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_12 (ReLU)   │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │                   │ 120)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_6_… │ (None, 14, 14,  │     1,080 │ re_lu_12[0][0] │   Y   │
# │ (DepthwiseConv2D) │ 120)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_6_… │ (None, 14, 14,  │       480 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 120)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_13 (ReLU)   │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │                   │ 120)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_6_… │ (None, 14, 14,  │     5,760 │ re_lu_13[0][0] │   Y   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_6_… │ (None, 14, 14,  │       192 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_7_… │ (None, 14, 14,  │     6,912 │ expanded_conv… │   Y   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_7_… │ (None, 14, 14,  │       576 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_14 (ReLU)   │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │                   │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_7_… │ (None, 14, 14,  │     1,296 │ re_lu_14[0][0] │   Y   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_7_… │ (None, 14, 14,  │       576 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_15 (ReLU)   │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │                   │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_7_… │ (None, 14, 14,  │     6,912 │ re_lu_15[0][0] │   Y   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_7_… │ (None, 14, 14,  │       192 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_7_… │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │ (Add)             │ 48)             │           │ expanded_conv… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_8_… │ (None, 14, 14,  │    13,824 │ expanded_conv… │   Y   │
# │ (Conv2D)          │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_8_… │ (None, 14, 14,  │     1,152 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_16 (ReLU)   │ (None, 14, 14,  │         0 │ expanded_conv… │   -   │
# │                   │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_8_… │ (None, 15, 15,  │         0 │ re_lu_16[0][0] │   -   │
# │ (ZeroPadding2D)   │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_8_… │ (None, 7, 7,    │     2,592 │ expanded_conv… │   Y   │
# │ (DepthwiseConv2D) │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_8_… │ (None, 7, 7,    │     1,152 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_17 (ReLU)   │ (None, 7, 7,    │         0 │ expanded_conv… │   -   │
# │                   │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_8_… │ (None, 7, 7,    │    27,648 │ re_lu_17[0][0] │   Y   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_8_… │ (None, 7, 7,    │       384 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_9_… │ (None, 7, 7,    │    55,296 │ expanded_conv… │   Y   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_9_… │ (None, 7, 7,    │     2,304 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_18 (ReLU)   │ (None, 7, 7,    │         0 │ expanded_conv… │   -   │
# │                   │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_9_… │ (None, 7, 7,    │     5,184 │ re_lu_18[0][0] │   Y   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_9_… │ (None, 7, 7,    │     2,304 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_19 (ReLU)   │ (None, 7, 7,    │         0 │ expanded_conv… │   -   │
# │                   │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_9_… │ (None, 7, 7,    │    55,296 │ re_lu_19[0][0] │   Y   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_9_… │ (None, 7, 7,    │       384 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_9_… │ (None, 7, 7,    │         0 │ expanded_conv… │   -   │
# │ (Add)             │ 96)             │           │ expanded_conv… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_10… │ (None, 7, 7,    │    55,296 │ expanded_conv… │   Y   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_10… │ (None, 7, 7,    │     2,304 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_20 (ReLU)   │ (None, 7, 7,    │         0 │ expanded_conv… │   -   │
# │                   │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_10… │ (None, 7, 7,    │     5,184 │ re_lu_20[0][0] │   Y   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_10… │ (None, 7, 7,    │     2,304 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_21 (ReLU)   │ (None, 7, 7,    │         0 │ expanded_conv… │   -   │
# │                   │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_10… │ (None, 7, 7,    │    55,296 │ re_lu_21[0][0] │   Y   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_10… │ (None, 7, 7,    │       384 │ expanded_conv… │   Y   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_10… │ (None, 7, 7,    │         0 │ expanded_conv… │   -   │
# │ (Add)             │ 96)             │           │ expanded_conv… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv_1 (Conv2D)   │ (None, 7, 7,    │    55,296 │ expanded_conv… │   Y   │
# │                   │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv_1_bn         │ (None, 7, 7,    │     2,304 │ conv_1[0][0]   │   Y   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ re_lu_22 (ReLU)   │ (None, 7, 7,    │         0 │ conv_1_bn[0][… │   -   │
# │                   │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ feature_dropout   │ (None, 7, 7,    │         0 │ re_lu_22[0][0] │   -   │
# │ (SpatialDropout2… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared1… │ (None, 7, 7,    │     5,184 │ feature_dropo… │   Y   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared1… │ (None, 7, 7,    │     2,304 │ ssd_lite_shar… │   Y   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared1… │ (None, 7, 7,    │         0 │ ssd_lite_shar… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared1… │ (None, 7, 7,    │   110,592 │ ssd_lite_shar… │   Y   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared1… │ (None, 7, 7,    │       768 │ ssd_lite_shar… │   Y   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared1… │ (None, 7, 7,    │         0 │ ssd_lite_shar… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared2… │ (None, 7, 7,    │     1,728 │ ssd_lite_shar… │   Y   │
# │ (DepthwiseConv2D) │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared2… │ (None, 7, 7,    │       768 │ ssd_lite_shar… │   Y   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared2… │ (None, 7, 7,    │         0 │ ssd_lite_shar… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared2… │ (None, 7, 7,    │    36,864 │ ssd_lite_shar… │   Y   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared2… │ (None, 7, 7,    │       768 │ ssd_lite_shar… │   Y   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_shared2… │ (None, 7, 7,    │         0 │ ssd_lite_shar… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_bbox_co… │ (None, 7, 7,    │     9,264 │ ssd_lite_shar… │   Y   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_cls_conv │ (None, 7, 7,    │     4,632 │ ssd_lite_shar… │   Y   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_obj_conv │ (None, 7, 7,    │     2,316 │ ssd_lite_shar… │   Y   │
# │ (Conv2D)          │ 12)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_bbox_re… │ (None, 588, 4)  │         0 │ ssd_lite_bbox… │   -   │
# │ (Reshape)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_cls_res… │ (None, 588, 2)  │         0 │ ssd_lite_cls_… │   -   │
# │ (Reshape)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ ssd_lite_obj_res… │ (None, 588, 1)  │         0 │ ssd_lite_obj_… │   -   │
# │ (Reshape)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bbox_out          │ (None, 588, 4)  │         0 │ ssd_lite_bbox… │   -   │
# │ (Activation)      │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ class_out         │ (None, 588, 2)  │         0 │ ssd_lite_cls_… │   -   │
# │ (Activation)      │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ objectness        │ (None, 588, 1)  │         0 │ ssd_lite_obj_… │   -   │
# │ (Activation)      │                 │           │                │       │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 616,188 (2.35 MB)
#  Trainable params: 601,772 (2.30 MB)
#  Non-trainable params: 14,416 (56.31 KB)

# %%
# Estimar tamaño del modelo para ESP32-S3
model_sizes = estimate_model_size(model)
# Out:
# 📊 Model Size Estimates:
#    Total parameters: 616,188
#    Float32: 2407.0 KB (2.35 MB)
#    Float16: 1203.5 KB (1.18 MB)
#    INT8:    601.7 KB (0.59 MB)
#    ✅ INT8 model fits ESP32-S3 flash limit (1024 KB)

# %% [markdown]
# ## 5. Configurar Losses y Métricas

# %%
# Configurar funciones de pérdida con Focal Loss
# Focal Loss es clave para manejar el desbalance de clases en detección de objetos

loss_config = ssd_combined_loss(
    cls_weight=CLS_WEIGHT,
    obj_weight=OBJ_WEIGHT,
    bbox_weight=BBOX_WEIGHT,
    focal_alpha=FOCAL_ALPHA,
    focal_gamma=FOCAL_GAMMA,
    smooth_l1_delta=1.0,
    class_weights=class_weights_tensor,  # Pesos de clase calculados
    use_giou=False,  # Smooth L1 por defecto, cambiar a True para GIoU
)

losses = loss_config["losses"]
loss_weights = loss_config["weights"]

print("📉 Funciones de pérdida configuradas:")
print(f"   Objectness: Binary Focal Loss (α={FOCAL_ALPHA}, γ={FOCAL_GAMMA}) × {OBJ_WEIGHT}")
print(f"   Classification: Focal Loss (α={FOCAL_ALPHA}, γ={FOCAL_GAMMA}) × {CLS_WEIGHT}")
print(f"   Bounding Box: Smooth L1 Loss × {BBOX_WEIGHT}")
print(f"   Class weights: {class_weights}")
# Out:
# 📉 Funciones de pérdida configuradas:
#    Objectness: Binary Focal Loss (α=0.25, γ=2.0) × 2.0
#    Classification: Focal Loss (α=0.25, γ=2.0) × 1.5
#    Bounding Box: Smooth L1 Loss × 1.0
#    Class weights: [0.7 2. ]

# %% [markdown]
# ## 6. Entrenamiento Fase 1: Warm-up (Backbone Congelado)
#
# En esta fase solo entrenamos el cabezal SSD-Lite. El backbone MobileNetV3 permanece congelado con los pesos de ImageNet.

# %%
# FASE 1: Congelar backbone, entrenar solo el cabezal SSD-Lite
print("\n" + "="*70)
print("🔒 FASE 1: WARM-UP - Backbone Congelado")
print("="*70)

# Congelar todas las capas del backbone
freeze_backbone(model)

# Compilar modelo para Fase 1
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=PHASE1_LR),
    loss=losses,
    loss_weights=loss_weights,
    metrics={
        "objectness": ["binary_accuracy"],
        "class_out": ["categorical_accuracy"],
    }
)

print(f"\n📋 Configuración Fase 1:")
print(f"   Learning Rate: {PHASE1_LR}")
print(f"   Épocas: {PHASE1_EPOCHS}")
print(f"   Batch Size: {BATCH_SIZE}")
# Out:
# ======================================================================
# 🔒 FASE 1: WARM-UP - Backbone Congelado
# ======================================================================
# 🔒 Frozen 103 backbone layers
#    Trainable params: 172,884 / 616,188 (28.1%)
#
# 📋 Configuración Fase 1:
#    Learning Rate: 0.001
#    Épocas: 30
#    Batch Size: 16

# %%
# Callbacks para Fase 1
phase1_callbacks = create_callbacks(
    checkpoint_dir=str(CHECKPOINTS_DIR),
    log_dir=str(LOGS_DIR ),
    model_name=f"{MODEL_NAME}_phase1",
    monitor="val_loss",
    patience_reduce_lr=PATIENCE_REDUCE_LR,
    patience_early_stop=PHASE1_EPOCHS,  # Sin early stopping en fase 1
    reduce_lr_factor=REDUCE_LR_FACTOR,
)

# Agregar logger de learning rate
lr_logger = LearningRateLogger()
phase1_callbacks.append(lr_logger)
# Out:
# 📋 Created 5 callbacks:
#    Checkpoint: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
#    Logs: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/MBNTv3_ssdlite_v7_phase1_history.csv
#    Monitor: val_loss
#    ReduceLR patience: 7, factor: 0.5
#    EarlyStopping patience: 30

# %%
# Entrenar Fase 1
print("\n🚀 Iniciando entrenamiento Fase 1...")

history_phase1 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=PHASE1_EPOCHS,
    callbacks=phase1_callbacks,
    verbose=1,
)

print("\n✅ Fase 1 completada")
# Out:
# 🚀 Iniciando entrenamiento Fase 1...
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - bbox_out_loss: 0.1197 - class_out_categorical_accuracy: 0.3243 - class_out_loss: 0.2149 - loss: 0.6344 - objectness_binary_accuracy: 0.7806 - objectness_loss: 0.0967
# Epoch 1: val_loss improved from None to 0.46751, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 161ms/step - bbox_out_loss: 0.0954 - class_out_categorical_accuracy: 0.2609 - class_out_loss: 0.1607 - loss: 0.4315 - objectness_binary_accuracy: 0.8873 - objectness_loss: 0.0492 - val_bbox_out_loss: 0.0696 - val_class_out_categorical_accuracy: 0.3061 - val_class_out_loss: 0.2129 - val_loss: 0.4675 - val_objectness_binary_accuracy: 0.9708 - val_objectness_loss: 0.0412 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - bbox_out_loss: 0.0642 - class_out_categorical_accuracy: 0.1911 - class_out_loss: 0.1069 - loss: 0.2527 - objectness_binary_accuracy: 0.9557 - objectness_loss: 0.0158
# Epoch 2: val_loss improved from 0.46751 to 0.35370, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - bbox_out_loss: 0.0609 - class_out_categorical_accuracy: 0.1828 - class_out_loss: 0.1011 - loss: 0.2377 - objectness_binary_accuracy: 0.9556 - objectness_loss: 0.0152 - val_bbox_out_loss: 0.0652 - val_class_out_categorical_accuracy: 0.2549 - val_class_out_loss: 0.1765 - val_loss: 0.3537 - val_objectness_binary_accuracy: 0.9708 - val_objectness_loss: 0.0145 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - bbox_out_loss: 0.0514 - class_out_categorical_accuracy: 0.1779 - class_out_loss: 0.0900 - loss: 0.2152 - objectness_binary_accuracy: 0.9553 - objectness_loss: 0.0141
# Epoch 3: val_loss improved from 0.35370 to 0.26487, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - bbox_out_loss: 0.0495 - class_out_categorical_accuracy: 0.1762 - class_out_loss: 0.0838 - loss: 0.2028 - objectness_binary_accuracy: 0.9558 - objectness_loss: 0.0136 - val_bbox_out_loss: 0.0622 - val_class_out_categorical_accuracy: 0.1526 - val_class_out_loss: 0.1241 - val_loss: 0.2649 - val_objectness_binary_accuracy: 0.9708 - val_objectness_loss: 0.0100 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0462 - class_out_categorical_accuracy: 0.1716 - class_out_loss: 0.0792 - loss: 0.1914 - objectness_binary_accuracy: 0.9561 - objectness_loss: 0.0129
# Epoch 4: val_loss improved from 0.26487 to 0.20636, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - bbox_out_loss: 0.0447 - class_out_categorical_accuracy: 0.1721 - class_out_loss: 0.0791 - loss: 0.1890 - objectness_binary_accuracy: 0.9567 - objectness_loss: 0.0127 - val_bbox_out_loss: 0.0580 - val_class_out_categorical_accuracy: 0.1335 - val_class_out_loss: 0.0872 - val_loss: 0.2064 - val_objectness_binary_accuracy: 0.9708 - val_objectness_loss: 0.0091 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0415 - class_out_categorical_accuracy: 0.1821 - class_out_loss: 0.0874 - loss: 0.1968 - objectness_binary_accuracy: 0.9575 - objectness_loss: 0.0120
# Epoch 5: val_loss improved from 0.20636 to 0.16093, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - bbox_out_loss: 0.0410 - class_out_categorical_accuracy: 0.1839 - class_out_loss: 0.0790 - loss: 0.1843 - objectness_binary_accuracy: 0.9571 - objectness_loss: 0.0122 - val_bbox_out_loss: 0.0547 - val_class_out_categorical_accuracy: 0.1308 - val_class_out_loss: 0.0596 - val_loss: 0.1609 - val_objectness_binary_accuracy: 0.9708 - val_objectness_loss: 0.0089 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0394 - class_out_categorical_accuracy: 0.1896 - class_out_loss: 0.0686 - loss: 0.1666 - objectness_binary_accuracy: 0.9564 - objectness_loss: 0.0122
# Epoch 6: val_loss improved from 0.16093 to 0.13871, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - bbox_out_loss: 0.0389 - class_out_categorical_accuracy: 0.1904 - class_out_loss: 0.0733 - loss: 0.1722 - objectness_binary_accuracy: 0.9571 - objectness_loss: 0.0119 - val_bbox_out_loss: 0.0484 - val_class_out_categorical_accuracy: 0.1466 - val_class_out_loss: 0.0479 - val_loss: 0.1387 - val_objectness_binary_accuracy: 0.9708 - val_objectness_loss: 0.0089 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0370 - class_out_categorical_accuracy: 0.1925 - class_out_loss: 0.0668 - loss: 0.1611 - objectness_binary_accuracy: 0.9560 - objectness_loss: 0.0120
# Epoch 7: val_loss improved from 0.13871 to 0.11497, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - bbox_out_loss: 0.0372 - class_out_categorical_accuracy: 0.1950 - class_out_loss: 0.0669 - loss: 0.1616 - objectness_binary_accuracy: 0.9564 - objectness_loss: 0.0119 - val_bbox_out_loss: 0.0437 - val_class_out_categorical_accuracy: 0.1704 - val_class_out_loss: 0.0353 - val_loss: 0.1150 - val_objectness_binary_accuracy: 0.9706 - val_objectness_loss: 0.0087 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0366 - class_out_categorical_accuracy: 0.1922 - class_out_loss: 0.0653 - loss: 0.1586 - objectness_binary_accuracy: 0.9570 - objectness_loss: 0.0116
# Epoch 8: val_loss improved from 0.11497 to 0.10865, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - bbox_out_loss: 0.0361 - class_out_categorical_accuracy: 0.1911 - class_out_loss: 0.0650 - loss: 0.1579 - objectness_binary_accuracy: 0.9572 - objectness_loss: 0.0116 - val_bbox_out_loss: 0.0446 - val_class_out_categorical_accuracy: 0.1654 - val_class_out_loss: 0.0312 - val_loss: 0.1087 - val_objectness_binary_accuracy: 0.9710 - val_objectness_loss: 0.0083 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - bbox_out_loss: 0.0345 - class_out_categorical_accuracy: 0.1949 - class_out_loss: 0.0590 - loss: 0.1462 - objectness_binary_accuracy: 0.9574 - objectness_loss: 0.0113
# Epoch 9: val_loss improved from 0.10865 to 0.10025, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - bbox_out_loss: 0.0347 - class_out_categorical_accuracy: 0.1951 - class_out_loss: 0.0605 - loss: 0.1485 - objectness_binary_accuracy: 0.9572 - objectness_loss: 0.0114 - val_bbox_out_loss: 0.0416 - val_class_out_categorical_accuracy: 0.1825 - val_class_out_loss: 0.0280 - val_loss: 0.1002 - val_objectness_binary_accuracy: 0.9714 - val_objectness_loss: 0.0080 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - bbox_out_loss: 0.0346 - class_out_categorical_accuracy: 0.1950 - class_out_loss: 0.0648 - loss: 0.1539 - objectness_binary_accuracy: 0.9572 - objectness_loss: 0.0114
# Epoch 10: val_loss improved from 0.10025 to 0.09304, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - bbox_out_loss: 0.0340 - class_out_categorical_accuracy: 0.1947 - class_out_loss: 0.0649 - loss: 0.1536 - objectness_binary_accuracy: 0.9576 - objectness_loss: 0.0113 - val_bbox_out_loss: 0.0389 - val_class_out_categorical_accuracy: 0.1852 - val_class_out_loss: 0.0256 - val_loss: 0.0930 - val_objectness_binary_accuracy: 0.9712 - val_objectness_loss: 0.0078 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0327 - class_out_categorical_accuracy: 0.1989 - class_out_loss: 0.0646 - loss: 0.1508 - objectness_binary_accuracy: 0.9585 - objectness_loss: 0.0110
# Epoch 11: val_loss did not improve from 0.09304
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - bbox_out_loss: 0.0324 - class_out_categorical_accuracy: 0.2011 - class_out_loss: 0.0626 - loss: 0.1478 - objectness_binary_accuracy: 0.9580 - objectness_loss: 0.0111 - val_bbox_out_loss: 0.0374 - val_class_out_categorical_accuracy: 0.1831 - val_class_out_loss: 0.0258 - val_loss: 0.0931 - val_objectness_binary_accuracy: 0.9716 - val_objectness_loss: 0.0078 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - bbox_out_loss: 0.0320 - class_out_categorical_accuracy: 0.2066 - class_out_loss: 0.0655 - loss: 0.1494 - objectness_binary_accuracy: 0.9583 - objectness_loss: 0.0109
# Epoch 12: val_loss did not improve from 0.09304
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - bbox_out_loss: 0.0323 - class_out_categorical_accuracy: 0.2030 - class_out_loss: 0.0652 - loss: 0.1507 - objectness_binary_accuracy: 0.9575 - objectness_loss: 0.0110 - val_bbox_out_loss: 0.0386 - val_class_out_categorical_accuracy: 0.1807 - val_class_out_loss: 0.0272 - val_loss: 0.0970 - val_objectness_binary_accuracy: 0.9712 - val_objectness_loss: 0.0078 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - bbox_out_loss: 0.0306 - class_out_categorical_accuracy: 0.1962 - class_out_loss: 0.0555 - loss: 0.1367 - objectness_binary_accuracy: 0.9583 - objectness_loss: 0.0109
# Epoch 13: val_loss did not improve from 0.09304
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - bbox_out_loss: 0.0311 - class_out_categorical_accuracy: 0.1994 - class_out_loss: 0.0617 - loss: 0.1461 - objectness_binary_accuracy: 0.9585 - objectness_loss: 0.0108 - val_bbox_out_loss: 0.0343 - val_class_out_categorical_accuracy: 0.1925 - val_class_out_loss: 0.0335 - val_loss: 0.1014 - val_objectness_binary_accuracy: 0.9718 - val_objectness_loss: 0.0077 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - bbox_out_loss: 0.0304 - class_out_categorical_accuracy: 0.2067 - class_out_loss: 0.0576 - loss: 0.1387 - objectness_binary_accuracy: 0.9590 - objectness_loss: 0.0107
# Epoch 14: val_loss did not improve from 0.09304
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - bbox_out_loss: 0.0305 - class_out_categorical_accuracy: 0.2046 - class_out_loss: 0.0580 - loss: 0.1398 - objectness_binary_accuracy: 0.9586 - objectness_loss: 0.0108 - val_bbox_out_loss: 0.0376 - val_class_out_categorical_accuracy: 0.1913 - val_class_out_loss: 0.0351 - val_loss: 0.1070 - val_objectness_binary_accuracy: 0.9720 - val_objectness_loss: 0.0079 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0313 - class_out_categorical_accuracy: 0.1966 - class_out_loss: 0.0599 - loss: 0.1407 - objectness_binary_accuracy: 0.9596 - objectness_loss: 0.0105
# Epoch 15: val_loss did not improve from 0.09304
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - bbox_out_loss: 0.0307 - class_out_categorical_accuracy: 0.1974 - class_out_loss: 0.0627 - loss: 0.1442 - objectness_binary_accuracy: 0.9586 - objectness_loss: 0.0106 - val_bbox_out_loss: 0.0380 - val_class_out_categorical_accuracy: 0.1901 - val_class_out_loss: 0.0291 - val_loss: 0.0993 - val_objectness_binary_accuracy: 0.9720 - val_objectness_loss: 0.0077 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - bbox_out_loss: 0.0307 - class_out_categorical_accuracy: 0.2010 - class_out_loss: 0.0567 - loss: 0.1374 - objectness_binary_accuracy: 0.9586 - objectness_loss: 0.0107
# Epoch 16: val_loss did not improve from 0.09304
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - bbox_out_loss: 0.0301 - class_out_categorical_accuracy: 0.2002 - class_out_loss: 0.0548 - loss: 0.1342 - objectness_binary_accuracy: 0.9588 - objectness_loss: 0.0106 - val_bbox_out_loss: 0.0356 - val_class_out_categorical_accuracy: 0.1960 - val_class_out_loss: 0.0278 - val_loss: 0.0956 - val_objectness_binary_accuracy: 0.9721 - val_objectness_loss: 0.0076 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - bbox_out_loss: 0.0298 - class_out_categorical_accuracy: 0.1982 - class_out_loss: 0.0565 - loss: 0.1360 - objectness_binary_accuracy: 0.9580 - objectness_loss: 0.0107
# Epoch 17: val_loss improved from 0.09304 to 0.09225, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - bbox_out_loss: 0.0296 - class_out_categorical_accuracy: 0.1973 - class_out_loss: 0.0571 - loss: 0.1371 - objectness_binary_accuracy: 0.9589 - objectness_loss: 0.0106 - val_bbox_out_loss: 0.0356 - val_class_out_categorical_accuracy: 0.1938 - val_class_out_loss: 0.0264 - val_loss: 0.0922 - val_objectness_binary_accuracy: 0.9725 - val_objectness_loss: 0.0077 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0299 - class_out_categorical_accuracy: 0.1983 - class_out_loss: 0.0560 - loss: 0.1364 - objectness_binary_accuracy: 0.9582 - objectness_loss: 0.0110
# Epoch 18: val_loss did not improve from 0.09225
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - bbox_out_loss: 0.0293 - class_out_categorical_accuracy: 0.1991 - class_out_loss: 0.0553 - loss: 0.1338 - objectness_binary_accuracy: 0.9587 - objectness_loss: 0.0107 - val_bbox_out_loss: 0.0344 - val_class_out_categorical_accuracy: 0.2009 - val_class_out_loss: 0.0284 - val_loss: 0.0947 - val_objectness_binary_accuracy: 0.9721 - val_objectness_loss: 0.0075 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0290 - class_out_categorical_accuracy: 0.2019 - class_out_loss: 0.0526 - loss: 0.1280 - objectness_binary_accuracy: 0.9586 - objectness_loss: 0.0105
# Epoch 19: val_loss did not improve from 0.09225
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - bbox_out_loss: 0.0287 - class_out_categorical_accuracy: 0.2000 - class_out_loss: 0.0567 - loss: 0.1332 - objectness_binary_accuracy: 0.9586 - objectness_loss: 0.0105 - val_bbox_out_loss: 0.0328 - val_class_out_categorical_accuracy: 0.1913 - val_class_out_loss: 0.0341 - val_loss: 0.0998 - val_objectness_binary_accuracy: 0.9722 - val_objectness_loss: 0.0075 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - bbox_out_loss: 0.0284 - class_out_categorical_accuracy: 0.1993 - class_out_loss: 0.0516 - loss: 0.1243 - objectness_binary_accuracy: 0.9573 - objectness_loss: 0.0106
# Epoch 20: val_loss improved from 0.09225 to 0.08888, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase1_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - bbox_out_loss: 0.0286 - class_out_categorical_accuracy: 0.2000 - class_out_loss: 0.0533 - loss: 0.1282 - objectness_binary_accuracy: 0.9580 - objectness_loss: 0.0106 - val_bbox_out_loss: 0.0317 - val_class_out_categorical_accuracy: 0.1856 - val_class_out_loss: 0.0255 - val_loss: 0.0889 - val_objectness_binary_accuracy: 0.9722 - val_objectness_loss: 0.0075 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - bbox_out_loss: 0.0288 - class_out_categorical_accuracy: 0.1980 - class_out_loss: 0.0587 - loss: 0.1371 - objectness_binary_accuracy: 0.9602 - objectness_loss: 0.0103
# Epoch 21: val_loss did not improve from 0.08888
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - bbox_out_loss: 0.0280 - class_out_categorical_accuracy: 0.1984 - class_out_loss: 0.0542 - loss: 0.1296 - objectness_binary_accuracy: 0.9596 - objectness_loss: 0.0103 - val_bbox_out_loss: 0.0334 - val_class_out_categorical_accuracy: 0.1958 - val_class_out_loss: 0.0271 - val_loss: 0.0919 - val_objectness_binary_accuracy: 0.9727 - val_objectness_loss: 0.0075 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0282 - class_out_categorical_accuracy: 0.2004 - class_out_loss: 0.0538 - loss: 0.1276 - objectness_binary_accuracy: 0.9595 - objectness_loss: 0.0107
# Epoch 22: val_loss did not improve from 0.08888
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - bbox_out_loss: 0.0279 - class_out_categorical_accuracy: 0.2000 - class_out_loss: 0.0533 - loss: 0.1275 - objectness_binary_accuracy: 0.9594 - objectness_loss: 0.0104 - val_bbox_out_loss: 0.0337 - val_class_out_categorical_accuracy: 0.1920 - val_class_out_loss: 0.0291 - val_loss: 0.0960 - val_objectness_binary_accuracy: 0.9726 - val_objectness_loss: 0.0076 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0278 - class_out_categorical_accuracy: 0.2016 - class_out_loss: 0.0532 - loss: 0.1293 - objectness_binary_accuracy: 0.9591 - objectness_loss: 0.0103
# Epoch 23: val_loss did not improve from 0.08888
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - bbox_out_loss: 0.0282 - class_out_categorical_accuracy: 0.2003 - class_out_loss: 0.0553 - loss: 0.1326 - objectness_binary_accuracy: 0.9586 - objectness_loss: 0.0103 - val_bbox_out_loss: 0.0346 - val_class_out_categorical_accuracy: 0.1751 - val_class_out_loss: 0.0330 - val_loss: 0.1030 - val_objectness_binary_accuracy: 0.9726 - val_objectness_loss: 0.0077 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - bbox_out_loss: 0.0272 - class_out_categorical_accuracy: 0.1972 - class_out_loss: 0.0537 - loss: 0.1256 - objectness_binary_accuracy: 0.9607 - objectness_loss: 0.0099
# Epoch 24: val_loss did not improve from 0.08888
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - bbox_out_loss: 0.0279 - class_out_categorical_accuracy: 0.1991 - class_out_loss: 0.0573 - loss: 0.1327 - objectness_binary_accuracy: 0.9592 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0326 - val_class_out_categorical_accuracy: 0.1929 - val_class_out_loss: 0.0268 - val_loss: 0.0906 - val_objectness_binary_accuracy: 0.9725 - val_objectness_loss: 0.0077 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - bbox_out_loss: 0.0273 - class_out_categorical_accuracy: 0.1921 - class_out_loss: 0.0481 - loss: 0.1191 - objectness_binary_accuracy: 0.9605 - objectness_loss: 0.0099
# Epoch 25: val_loss did not improve from 0.08888
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - bbox_out_loss: 0.0277 - class_out_categorical_accuracy: 0.1958 - class_out_loss: 0.0532 - loss: 0.1284 - objectness_binary_accuracy: 0.9593 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0331 - val_class_out_categorical_accuracy: 0.1908 - val_class_out_loss: 0.0304 - val_loss: 0.0959 - val_objectness_binary_accuracy: 0.9728 - val_objectness_loss: 0.0076 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - bbox_out_loss: 0.0274 - class_out_categorical_accuracy: 0.1920 - class_out_loss: 0.0438 - loss: 0.1135 - objectness_binary_accuracy: 0.9608 - objectness_loss: 0.0098
# Epoch 26: val_loss did not improve from 0.08888
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - bbox_out_loss: 0.0271 - class_out_categorical_accuracy: 0.1931 - class_out_loss: 0.0504 - loss: 0.1237 - objectness_binary_accuracy: 0.9598 - objectness_loss: 0.0100 - val_bbox_out_loss: 0.0331 - val_class_out_categorical_accuracy: 0.1921 - val_class_out_loss: 0.0294 - val_loss: 0.0936 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0073 - learning_rate: 0.0010 - lr: 0.0010
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - bbox_out_loss: 0.0277 - class_out_categorical_accuracy: 0.2008 - class_out_loss: 0.0507 - loss: 0.1240 - objectness_binary_accuracy: 0.9597 - objectness_loss: 0.0101
# Epoch 27: val_loss did not improve from 0.08888
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - bbox_out_loss: 0.0274 - class_out_categorical_accuracy: 0.1980 - class_out_loss: 0.0510 - loss: 0.1244 - objectness_binary_accuracy: 0.9598 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0333 - val_class_out_categorical_accuracy: 0.1854 - val_class_out_loss: 0.0300 - val_loss: 0.0956 - val_objectness_binary_accuracy: 0.9727 - val_objectness_loss: 0.0075 - learning_rate: 0.0010 - lr: 5.0000e-04
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - bbox_out_loss: 0.0258 - class_out_categorical_accuracy: 0.1941 - class_out_loss: 0.0524 - loss: 0.1233 - objectness_binary_accuracy: 0.9602 - objectness_loss: 0.0098
# Epoch 28: val_loss did not improve from 0.08888
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - bbox_out_loss: 0.0262 - class_out_categorical_accuracy: 0.1941 - class_out_loss: 0.0517 - loss: 0.1227 - objectness_binary_accuracy: 0.9602 - objectness_loss: 0.0099 - val_bbox_out_loss: 0.0314 - val_class_out_categorical_accuracy: 0.1841 - val_class_out_loss: 0.0274 - val_loss: 0.0889 - val_objectness_binary_accuracy: 0.9724 - val_objectness_loss: 0.0073 - learning_rate: 5.0000e-04 - lr: 5.0000e-04
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - bbox_out_loss: 0.0263 - class_out_categorical_accuracy: 0.1937 - class_out_loss: 0.0504 - loss: 0.1223 - objectness_binary_accuracy: 0.9589 - objectness_loss: 0.0101
# Epoch 29: val_loss did not improve from 0.08888
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - bbox_out_loss: 0.0263 - class_out_categorical_accuracy: 0.1931 - class_out_loss: 0.0508 - loss: 0.1231 - objectness_binary_accuracy: 0.9598 - objectness_loss: 0.0100 - val_bbox_out_loss: 0.0315 - val_class_out_categorical_accuracy: 0.1931 - val_class_out_loss: 0.0289 - val_loss: 0.0916 - val_objectness_binary_accuracy: 0.9727 - val_objectness_loss: 0.0074 - learning_rate: 5.0000e-04 - lr: 5.0000e-04
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - bbox_out_loss: 0.0261 - class_out_categorical_accuracy: 0.1999 - class_out_loss: 0.0483 - loss: 0.1168 - objectness_binary_accuracy: 0.9599 - objectness_loss: 0.0100
# Epoch 30: val_loss did not improve from 0.08888
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - bbox_out_loss: 0.0257 - class_out_categorical_accuracy: 0.2021 - class_out_loss: 0.0483 - loss: 0.1168 - objectness_binary_accuracy: 0.9595 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0309 - val_class_out_categorical_accuracy: 0.1879 - val_class_out_loss: 0.0277 - val_loss: 0.0901 - val_objectness_binary_accuracy: 0.9727 - val_objectness_loss: 0.0074 - learning_rate: 5.0000e-04 - lr: 5.0000e-04
# Restoring model weights from the end of the best epoch: 20.
#
# ✅ Fase 1 completada

# %%
# Guardar historial Fase 1
df_phase1 = save_training_history(
    history_phase1, 
    str(LOGS_DIR  / f"{MODEL_NAME}_phase1_history.csv")
)

# Visualizar progreso Fase 1
plot_training_history(
    history_phase1, 
    output_path=str(FIGURES_DIR / f"{MODEL_NAME}_phase1_curves.png"), 
    title=f"Fase 1: Warm-up - {MODEL_NAME}"
    )
# Out:
# 💾 Saved training history to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/MBNTv3_ssdlite_v7_phase1_history.csv
# 📊 Saved training plot to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/reports/figures/MBNTv3_ssdlite_v7/MBNTv3_ssdlite_v7_phase1_curves.png

# %% [markdown]
# ## 7. Entrenamiento Fase 2: Fine-Tuning (Backbone Parcialmente Descongelado)
#
# Descongelamos las últimas capas del backbone MobileNetV3 para que aprenda características específicas de nuestro dataset. **Learning rate muy bajo** para no destruir los pesos pre-entrenados.

# %%
# FASE 2: Descongelar últimas capas del backbone
print("\n" + "="*70)
print("🔓 FASE 2: FINE-TUNING - Backbone Parcialmente Descongelado")
print("="*70)

# Descongelar últimas N capas
unfreeze_backbone_layers(model, num_layers_to_unfreeze=NUM_LAYERS_TO_UNFREEZE)

# Recompilar con LR muy bajo (CRÍTICO)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=PHASE2_LR),
    loss=losses,
    loss_weights=loss_weights,
    metrics={
        "objectness": ["binary_accuracy"],
        "class_out": ["categorical_accuracy"],
    }
)

print(f"\n📋 Configuración Fase 2:")
print(f"   Learning Rate: {PHASE2_LR} (muy bajo para no destruir pesos)")
print(f"   Épocas máximas: {PHASE2_EPOCHS}")
print(f"   Early Stopping patience: {PATIENCE_EARLY_STOP}")
print(f"   ReduceLR patience: {PATIENCE_REDUCE_LR}")
# Out:
# ======================================================================
# 🔓 FASE 2: FINE-TUNING - Backbone Parcialmente Descongelado
# ======================================================================
# 🔓 Unfroze last 50 layers
#    Trainable params: 496,884 / 616,188 (80.6%)
#
# 📋 Configuración Fase 2:
#    Learning Rate: 5e-05 (muy bajo para no destruir pesos)
#    Épocas máximas: 50
#    Early Stopping patience: 12
#    ReduceLR patience: 7

# %%
# Callbacks para Fase 2 (con Early Stopping activo)
phase2_callbacks = create_callbacks(
    checkpoint_dir=str(CHECKPOINTS_DIR),
    log_dir=str(LOGS_DIR),
    model_name=f"{MODEL_NAME}_phase2",
    monitor="val_loss",
    patience_reduce_lr=PATIENCE_REDUCE_LR,
    patience_early_stop=PATIENCE_EARLY_STOP,
    reduce_lr_factor=REDUCE_LR_FACTOR,
)

# Agregar logger de learning rate
lr_logger_2 = LearningRateLogger()
phase2_callbacks.append(lr_logger_2)
# Out:
# 📋 Created 5 callbacks:
#    Checkpoint: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
#    Logs: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/MBNTv3_ssdlite_v7_phase2_history.csv
#    Monitor: val_loss
#    ReduceLR patience: 7, factor: 0.5
#    EarlyStopping patience: 12

# %%
# Entrenar Fase 2
print("\n🚀 Iniciando entrenamiento Fase 2 (Fine-tuning)...")
print("   Esto puede tomar tiempo. Early stopping detendrá si no mejora.")

history_phase2 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=PHASE2_EPOCHS,
    callbacks=phase2_callbacks,
    verbose=1,
)

print("\n✅ Fase 2 completada")
# Out:
# 🚀 Iniciando entrenamiento Fase 2 (Fine-tuning)...
#    Esto puede tomar tiempo. Early stopping detendrá si no mejora.
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - bbox_out_loss: 0.0313 - class_out_categorical_accuracy: 0.2002 - class_out_loss: 0.0656 - loss: 0.1509 - objectness_binary_accuracy: 0.9583 - objectness_loss: 0.0107
# Epoch 1: val_loss improved from None to 0.08934, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 27s 257ms/step - bbox_out_loss: 0.0308 - class_out_categorical_accuracy: 0.2009 - class_out_loss: 0.0622 - loss: 0.1451 - objectness_binary_accuracy: 0.9587 - objectness_loss: 0.0106 - val_bbox_out_loss: 0.0311 - val_class_out_categorical_accuracy: 0.2094 - val_class_out_loss: 0.0272 - val_loss: 0.0893 - val_objectness_binary_accuracy: 0.9728 - val_objectness_loss: 0.0073 - learning_rate: 5.0000e-05 - lr: 5.0000e-05
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - bbox_out_loss: 0.0299 - class_out_categorical_accuracy: 0.2033 - class_out_loss: 0.0590 - loss: 0.1392 - objectness_binary_accuracy: 0.9592 - objectness_loss: 0.0104
# Epoch 2: val_loss did not improve from 0.08934
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 166ms/step - bbox_out_loss: 0.0298 - class_out_categorical_accuracy: 0.2041 - class_out_loss: 0.0580 - loss: 0.1382 - objectness_binary_accuracy: 0.9592 - objectness_loss: 0.0104 - val_bbox_out_loss: 0.0309 - val_class_out_categorical_accuracy: 0.2186 - val_class_out_loss: 0.0294 - val_loss: 0.0917 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0073 - learning_rate: 5.0000e-05 - lr: 5.0000e-05
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - bbox_out_loss: 0.0302 - class_out_categorical_accuracy: 0.2032 - class_out_loss: 0.0561 - loss: 0.1353 - objectness_binary_accuracy: 0.9600 - objectness_loss: 0.0103
# Epoch 3: val_loss did not improve from 0.08934
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - bbox_out_loss: 0.0299 - class_out_categorical_accuracy: 0.2037 - class_out_loss: 0.0543 - loss: 0.1329 - objectness_binary_accuracy: 0.9595 - objectness_loss: 0.0104 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2242 - val_class_out_loss: 0.0309 - val_loss: 0.0934 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0073 - learning_rate: 5.0000e-05 - lr: 5.0000e-05
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - bbox_out_loss: 0.0302 - class_out_categorical_accuracy: 0.2027 - class_out_loss: 0.0544 - loss: 0.1319 - objectness_binary_accuracy: 0.9598 - objectness_loss: 0.0102
# Epoch 4: val_loss did not improve from 0.08934
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 189ms/step - bbox_out_loss: 0.0296 - class_out_categorical_accuracy: 0.2029 - class_out_loss: 0.0538 - loss: 0.1307 - objectness_binary_accuracy: 0.9587 - objectness_loss: 0.0105 - val_bbox_out_loss: 0.0305 - val_class_out_categorical_accuracy: 0.2239 - val_class_out_loss: 0.0317 - val_loss: 0.0939 - val_objectness_binary_accuracy: 0.9729 - val_objectness_loss: 0.0073 - learning_rate: 5.0000e-05 - lr: 5.0000e-05
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - bbox_out_loss: 0.0298 - class_out_categorical_accuracy: 0.2020 - class_out_loss: 0.0486 - loss: 0.1236 - objectness_binary_accuracy: 0.9603 - objectness_loss: 0.0102
# Epoch 5: val_loss did not improve from 0.08934
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - bbox_out_loss: 0.0296 - class_out_categorical_accuracy: 0.2028 - class_out_loss: 0.0509 - loss: 0.1270 - objectness_binary_accuracy: 0.9596 - objectness_loss: 0.0104 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2262 - val_class_out_loss: 0.0316 - val_loss: 0.0939 - val_objectness_binary_accuracy: 0.9729 - val_objectness_loss: 0.0073 - learning_rate: 5.0000e-05 - lr: 5.0000e-05
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - bbox_out_loss: 0.0286 - class_out_categorical_accuracy: 0.2047 - class_out_loss: 0.0525 - loss: 0.1276 - objectness_binary_accuracy: 0.9588 - objectness_loss: 0.0105
# Epoch 6: val_loss did not improve from 0.08934
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 161ms/step - bbox_out_loss: 0.0285 - class_out_categorical_accuracy: 0.2036 - class_out_loss: 0.0522 - loss: 0.1257 - objectness_binary_accuracy: 0.9591 - objectness_loss: 0.0103 - val_bbox_out_loss: 0.0308 - val_class_out_categorical_accuracy: 0.2257 - val_class_out_loss: 0.0308 - val_loss: 0.0932 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 5.0000e-05 - lr: 5.0000e-05
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - bbox_out_loss: 0.0290 - class_out_categorical_accuracy: 0.2043 - class_out_loss: 0.0504 - loss: 0.1237 - objectness_binary_accuracy: 0.9585 - objectness_loss: 0.0105
# Epoch 7: val_loss did not improve from 0.08934
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - bbox_out_loss: 0.0288 - class_out_categorical_accuracy: 0.2038 - class_out_loss: 0.0512 - loss: 0.1252 - objectness_binary_accuracy: 0.9591 - objectness_loss: 0.0104 - val_bbox_out_loss: 0.0308 - val_class_out_categorical_accuracy: 0.2251 - val_class_out_loss: 0.0302 - val_loss: 0.0923 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 5.0000e-05 - lr: 5.0000e-05
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - bbox_out_loss: 0.0274 - class_out_categorical_accuracy: 0.2047 - class_out_loss: 0.0445 - loss: 0.1170 - objectness_binary_accuracy: 0.9594 - objectness_loss: 0.0102
# Epoch 8: val_loss did not improve from 0.08934
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - bbox_out_loss: 0.0279 - class_out_categorical_accuracy: 0.2039 - class_out_loss: 0.0492 - loss: 0.1231 - objectness_binary_accuracy: 0.9593 - objectness_loss: 0.0103 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2251 - val_class_out_loss: 0.0297 - val_loss: 0.0914 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 5.0000e-05 - lr: 2.5000e-05
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - bbox_out_loss: 0.0289 - class_out_categorical_accuracy: 0.2045 - class_out_loss: 0.0534 - loss: 0.1216 - objectness_binary_accuracy: 0.9589 - objectness_loss: 0.0103
# Epoch 9: val_loss did not improve from 0.08934
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - bbox_out_loss: 0.0283 - class_out_categorical_accuracy: 0.2042 - class_out_loss: 0.0493 - loss: 0.1207 - objectness_binary_accuracy: 0.9591 - objectness_loss: 0.0103 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2233 - val_class_out_loss: 0.0289 - val_loss: 0.0900 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - bbox_out_loss: 0.0286 - class_out_categorical_accuracy: 0.2017 - class_out_loss: 0.0485 - loss: 0.1226 - objectness_binary_accuracy: 0.9614 - objectness_loss: 0.0100
# Epoch 10: val_loss improved from 0.08934 to 0.08922, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 189ms/step - bbox_out_loss: 0.0280 - class_out_categorical_accuracy: 0.2024 - class_out_loss: 0.0497 - loss: 0.1239 - objectness_binary_accuracy: 0.9600 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2206 - val_class_out_loss: 0.0284 - val_loss: 0.0892 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - bbox_out_loss: 0.0273 - class_out_categorical_accuracy: 0.2033 - class_out_loss: 0.0478 - loss: 0.1197 - objectness_binary_accuracy: 0.9591 - objectness_loss: 0.0103
# Epoch 11: val_loss improved from 0.08922 to 0.08828, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - bbox_out_loss: 0.0277 - class_out_categorical_accuracy: 0.2027 - class_out_loss: 0.0494 - loss: 0.1229 - objectness_binary_accuracy: 0.9592 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2183 - val_class_out_loss: 0.0278 - val_loss: 0.0883 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - bbox_out_loss: 0.0282 - class_out_categorical_accuracy: 0.2031 - class_out_loss: 0.0442 - loss: 0.1131 - objectness_binary_accuracy: 0.9593 - objectness_loss: 0.0103
# Epoch 12: val_loss improved from 0.08828 to 0.08774, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - bbox_out_loss: 0.0279 - class_out_categorical_accuracy: 0.2025 - class_out_loss: 0.0493 - loss: 0.1218 - objectness_binary_accuracy: 0.9587 - objectness_loss: 0.0104 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2189 - val_class_out_loss: 0.0274 - val_loss: 0.0877 - val_objectness_binary_accuracy: 0.9732 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - bbox_out_loss: 0.0272 - class_out_categorical_accuracy: 0.2025 - class_out_loss: 0.0474 - loss: 0.1189 - objectness_binary_accuracy: 0.9582 - objectness_loss: 0.0104
# Epoch 13: val_loss improved from 0.08774 to 0.08686, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - bbox_out_loss: 0.0271 - class_out_categorical_accuracy: 0.2019 - class_out_loss: 0.0495 - loss: 0.1216 - objectness_binary_accuracy: 0.9588 - objectness_loss: 0.0103 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2173 - val_class_out_loss: 0.0268 - val_loss: 0.0869 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - bbox_out_loss: 0.0277 - class_out_categorical_accuracy: 0.2022 - class_out_loss: 0.0480 - loss: 0.1206 - objectness_binary_accuracy: 0.9582 - objectness_loss: 0.0105
# Epoch 14: val_loss improved from 0.08686 to 0.08648, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - bbox_out_loss: 0.0275 - class_out_categorical_accuracy: 0.2011 - class_out_loss: 0.0502 - loss: 0.1226 - objectness_binary_accuracy: 0.9592 - objectness_loss: 0.0104 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2173 - val_class_out_loss: 0.0265 - val_loss: 0.0865 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - bbox_out_loss: 0.0267 - class_out_categorical_accuracy: 0.2029 - class_out_loss: 0.0454 - loss: 0.1156 - objectness_binary_accuracy: 0.9587 - objectness_loss: 0.0104
# Epoch 15: val_loss improved from 0.08648 to 0.08622, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 180ms/step - bbox_out_loss: 0.0273 - class_out_categorical_accuracy: 0.2016 - class_out_loss: 0.0478 - loss: 0.1195 - objectness_binary_accuracy: 0.9591 - objectness_loss: 0.0104 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2168 - val_class_out_loss: 0.0264 - val_loss: 0.0862 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - bbox_out_loss: 0.0272 - class_out_categorical_accuracy: 0.2040 - class_out_loss: 0.0499 - loss: 0.1229 - objectness_binary_accuracy: 0.9577 - objectness_loss: 0.0104
# Epoch 16: val_loss improved from 0.08622 to 0.08596, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 171ms/step - bbox_out_loss: 0.0273 - class_out_categorical_accuracy: 0.2031 - class_out_loss: 0.0523 - loss: 0.1264 - objectness_binary_accuracy: 0.9591 - objectness_loss: 0.0103 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2155 - val_class_out_loss: 0.0262 - val_loss: 0.0860 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - bbox_out_loss: 0.0277 - class_out_categorical_accuracy: 0.2020 - class_out_loss: 0.0481 - loss: 0.1205 - objectness_binary_accuracy: 0.9595 - objectness_loss: 0.0102
# Epoch 17: val_loss improved from 0.08596 to 0.08547, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 166ms/step - bbox_out_loss: 0.0273 - class_out_categorical_accuracy: 0.2017 - class_out_loss: 0.0478 - loss: 0.1197 - objectness_binary_accuracy: 0.9595 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2156 - val_class_out_loss: 0.0259 - val_loss: 0.0855 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - bbox_out_loss: 0.0273 - class_out_categorical_accuracy: 0.2017 - class_out_loss: 0.0468 - loss: 0.1181 - objectness_binary_accuracy: 0.9591 - objectness_loss: 0.0104
# Epoch 18: val_loss improved from 0.08547 to 0.08470, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - bbox_out_loss: 0.0272 - class_out_categorical_accuracy: 0.2027 - class_out_loss: 0.0485 - loss: 0.1205 - objectness_binary_accuracy: 0.9586 - objectness_loss: 0.0104 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2142 - val_class_out_loss: 0.0253 - val_loss: 0.0847 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - bbox_out_loss: 0.0262 - class_out_categorical_accuracy: 0.2005 - class_out_loss: 0.0487 - loss: 0.1194 - objectness_binary_accuracy: 0.9603 - objectness_loss: 0.0101
# Epoch 19: val_loss improved from 0.08470 to 0.08442, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - bbox_out_loss: 0.0266 - class_out_categorical_accuracy: 0.2017 - class_out_loss: 0.0480 - loss: 0.1190 - objectness_binary_accuracy: 0.9591 - objectness_loss: 0.0103 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2131 - val_class_out_loss: 0.0252 - val_loss: 0.0844 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - bbox_out_loss: 0.0269 - class_out_categorical_accuracy: 0.1998 - class_out_loss: 0.0488 - loss: 0.1202 - objectness_binary_accuracy: 0.9610 - objectness_loss: 0.0101
# Epoch 20: val_loss improved from 0.08442 to 0.08440, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 173ms/step - bbox_out_loss: 0.0270 - class_out_categorical_accuracy: 0.2006 - class_out_loss: 0.0475 - loss: 0.1178 - objectness_binary_accuracy: 0.9605 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0305 - val_class_out_categorical_accuracy: 0.2122 - val_class_out_loss: 0.0252 - val_loss: 0.0844 - val_objectness_binary_accuracy: 0.9732 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - bbox_out_loss: 0.0259 - class_out_categorical_accuracy: 0.1995 - class_out_loss: 0.0462 - loss: 0.1161 - objectness_binary_accuracy: 0.9601 - objectness_loss: 0.0101
# Epoch 21: val_loss improved from 0.08440 to 0.08321, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 188ms/step - bbox_out_loss: 0.0264 - class_out_categorical_accuracy: 0.2012 - class_out_loss: 0.0452 - loss: 0.1150 - objectness_binary_accuracy: 0.9594 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0305 - val_class_out_categorical_accuracy: 0.2102 - val_class_out_loss: 0.0244 - val_loss: 0.0832 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - bbox_out_loss: 0.0276 - class_out_categorical_accuracy: 0.1991 - class_out_loss: 0.0498 - loss: 0.1225 - objectness_binary_accuracy: 0.9596 - objectness_loss: 0.0101
# Epoch 22: val_loss improved from 0.08321 to 0.08245, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - bbox_out_loss: 0.0270 - class_out_categorical_accuracy: 0.1998 - class_out_loss: 0.0458 - loss: 0.1158 - objectness_binary_accuracy: 0.9597 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2096 - val_class_out_loss: 0.0238 - val_loss: 0.0825 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - bbox_out_loss: 0.0271 - class_out_categorical_accuracy: 0.1997 - class_out_loss: 0.0439 - loss: 0.1134 - objectness_binary_accuracy: 0.9602 - objectness_loss: 0.0103
# Epoch 23: val_loss improved from 0.08245 to 0.08188, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - bbox_out_loss: 0.0267 - class_out_categorical_accuracy: 0.2000 - class_out_loss: 0.0432 - loss: 0.1114 - objectness_binary_accuracy: 0.9601 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2096 - val_class_out_loss: 0.0234 - val_loss: 0.0819 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - bbox_out_loss: 0.0264 - class_out_categorical_accuracy: 0.2005 - class_out_loss: 0.0469 - loss: 0.1175 - objectness_binary_accuracy: 0.9595 - objectness_loss: 0.0102
# Epoch 24: val_loss improved from 0.08188 to 0.08186, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - bbox_out_loss: 0.0265 - class_out_categorical_accuracy: 0.2003 - class_out_loss: 0.0467 - loss: 0.1173 - objectness_binary_accuracy: 0.9597 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2086 - val_class_out_loss: 0.0234 - val_loss: 0.0819 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - bbox_out_loss: 0.0266 - class_out_categorical_accuracy: 0.2022 - class_out_loss: 0.0453 - loss: 0.1130 - objectness_binary_accuracy: 0.9595 - objectness_loss: 0.0102
# Epoch 25: val_loss improved from 0.08186 to 0.08129, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - bbox_out_loss: 0.0268 - class_out_categorical_accuracy: 0.2008 - class_out_loss: 0.0439 - loss: 0.1116 - objectness_binary_accuracy: 0.9597 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0308 - val_class_out_categorical_accuracy: 0.2082 - val_class_out_loss: 0.0230 - val_loss: 0.0813 - val_objectness_binary_accuracy: 0.9729 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - bbox_out_loss: 0.0272 - class_out_categorical_accuracy: 0.2017 - class_out_loss: 0.0522 - loss: 0.1239 - objectness_binary_accuracy: 0.9590 - objectness_loss: 0.0104
# Epoch 26: val_loss improved from 0.08129 to 0.08048, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - bbox_out_loss: 0.0267 - class_out_categorical_accuracy: 0.2010 - class_out_loss: 0.0491 - loss: 0.1192 - objectness_binary_accuracy: 0.9594 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2054 - val_class_out_loss: 0.0225 - val_loss: 0.0805 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - bbox_out_loss: 0.0264 - class_out_categorical_accuracy: 0.2006 - class_out_loss: 0.0400 - loss: 0.1063 - objectness_binary_accuracy: 0.9603 - objectness_loss: 0.0101
# Epoch 27: val_loss improved from 0.08048 to 0.08007, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 175ms/step - bbox_out_loss: 0.0264 - class_out_categorical_accuracy: 0.2008 - class_out_loss: 0.0417 - loss: 0.1088 - objectness_binary_accuracy: 0.9601 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2057 - val_class_out_loss: 0.0222 - val_loss: 0.0801 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - bbox_out_loss: 0.0257 - class_out_categorical_accuracy: 0.2005 - class_out_loss: 0.0463 - loss: 0.1156 - objectness_binary_accuracy: 0.9606 - objectness_loss: 0.0101
# Epoch 28: val_loss did not improve from 0.08007
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - bbox_out_loss: 0.0259 - class_out_categorical_accuracy: 0.2014 - class_out_loss: 0.0456 - loss: 0.1149 - objectness_binary_accuracy: 0.9596 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2049 - val_class_out_loss: 0.0222 - val_loss: 0.0802 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - bbox_out_loss: 0.0259 - class_out_categorical_accuracy: 0.2010 - class_out_loss: 0.0476 - loss: 0.1167 - objectness_binary_accuracy: 0.9609 - objectness_loss: 0.0099
# Epoch 29: val_loss improved from 0.08007 to 0.07984, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - bbox_out_loss: 0.0259 - class_out_categorical_accuracy: 0.2020 - class_out_loss: 0.0449 - loss: 0.1123 - objectness_binary_accuracy: 0.9601 - objectness_loss: 0.0100 - val_bbox_out_loss: 0.0308 - val_class_out_categorical_accuracy: 0.2048 - val_class_out_loss: 0.0219 - val_loss: 0.0798 - val_objectness_binary_accuracy: 0.9728 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - bbox_out_loss: 0.0272 - class_out_categorical_accuracy: 0.2010 - class_out_loss: 0.0444 - loss: 0.1135 - objectness_binary_accuracy: 0.9612 - objectness_loss: 0.0099
# Epoch 30: val_loss improved from 0.07984 to 0.07896, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - bbox_out_loss: 0.0269 - class_out_categorical_accuracy: 0.2019 - class_out_loss: 0.0445 - loss: 0.1126 - objectness_binary_accuracy: 0.9602 - objectness_loss: 0.0100 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2050 - val_class_out_loss: 0.0213 - val_loss: 0.0790 - val_objectness_binary_accuracy: 0.9729 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - bbox_out_loss: 0.0254 - class_out_categorical_accuracy: 0.2038 - class_out_loss: 0.0414 - loss: 0.1082 - objectness_binary_accuracy: 0.9592 - objectness_loss: 0.0103
# Epoch 31: val_loss improved from 0.07896 to 0.07828, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - bbox_out_loss: 0.0259 - class_out_categorical_accuracy: 0.2031 - class_out_loss: 0.0430 - loss: 0.1113 - objectness_binary_accuracy: 0.9598 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2044 - val_class_out_loss: 0.0210 - val_loss: 0.0783 - val_objectness_binary_accuracy: 0.9729 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - bbox_out_loss: 0.0263 - class_out_categorical_accuracy: 0.2045 - class_out_loss: 0.0423 - loss: 0.1096 - objectness_binary_accuracy: 0.9589 - objectness_loss: 0.0102
# Epoch 32: val_loss improved from 0.07828 to 0.07807, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 189ms/step - bbox_out_loss: 0.0260 - class_out_categorical_accuracy: 0.2033 - class_out_loss: 0.0444 - loss: 0.1113 - objectness_binary_accuracy: 0.9597 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2021 - val_class_out_loss: 0.0208 - val_loss: 0.0781 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - bbox_out_loss: 0.0262 - class_out_categorical_accuracy: 0.2028 - class_out_loss: 0.0384 - loss: 0.1039 - objectness_binary_accuracy: 0.9590 - objectness_loss: 0.0101
# Epoch 33: val_loss improved from 0.07807 to 0.07753, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 170ms/step - bbox_out_loss: 0.0262 - class_out_categorical_accuracy: 0.2024 - class_out_loss: 0.0410 - loss: 0.1076 - objectness_binary_accuracy: 0.9595 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2024 - val_class_out_loss: 0.0204 - val_loss: 0.0775 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - bbox_out_loss: 0.0262 - class_out_categorical_accuracy: 0.2035 - class_out_loss: 0.0417 - loss: 0.1094 - objectness_binary_accuracy: 0.9603 - objectness_loss: 0.0100
# Epoch 34: val_loss improved from 0.07753 to 0.07728, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - bbox_out_loss: 0.0259 - class_out_categorical_accuracy: 0.2029 - class_out_loss: 0.0395 - loss: 0.1057 - objectness_binary_accuracy: 0.9599 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0308 - val_class_out_categorical_accuracy: 0.2032 - val_class_out_loss: 0.0202 - val_loss: 0.0773 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - bbox_out_loss: 0.0260 - class_out_categorical_accuracy: 0.2025 - class_out_loss: 0.0426 - loss: 0.1102 - objectness_binary_accuracy: 0.9597 - objectness_loss: 0.0100
# Epoch 35: val_loss improved from 0.07728 to 0.07661, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - bbox_out_loss: 0.0256 - class_out_categorical_accuracy: 0.2043 - class_out_loss: 0.0430 - loss: 0.1111 - objectness_binary_accuracy: 0.9587 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0305 - val_class_out_categorical_accuracy: 0.2035 - val_class_out_loss: 0.0199 - val_loss: 0.0766 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - bbox_out_loss: 0.0262 - class_out_categorical_accuracy: 0.2059 - class_out_loss: 0.0441 - loss: 0.1103 - objectness_binary_accuracy: 0.9586 - objectness_loss: 0.0101
# Epoch 36: val_loss did not improve from 0.07661
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - bbox_out_loss: 0.0260 - class_out_categorical_accuracy: 0.2066 - class_out_loss: 0.0425 - loss: 0.1088 - objectness_binary_accuracy: 0.9587 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2044 - val_class_out_loss: 0.0199 - val_loss: 0.0768 - val_objectness_binary_accuracy: 0.9729 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - bbox_out_loss: 0.0257 - class_out_categorical_accuracy: 0.2036 - class_out_loss: 0.0388 - loss: 0.1043 - objectness_binary_accuracy: 0.9605 - objectness_loss: 0.0099
# Epoch 37: val_loss improved from 0.07661 to 0.07651, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - bbox_out_loss: 0.0253 - class_out_categorical_accuracy: 0.2036 - class_out_loss: 0.0414 - loss: 0.1079 - objectness_binary_accuracy: 0.9599 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2039 - val_class_out_loss: 0.0198 - val_loss: 0.0765 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - bbox_out_loss: 0.0249 - class_out_categorical_accuracy: 0.2039 - class_out_loss: 0.0408 - loss: 0.1069 - objectness_binary_accuracy: 0.9582 - objectness_loss: 0.0105
# Epoch 38: val_loss did not improve from 0.07651
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 185ms/step - bbox_out_loss: 0.0252 - class_out_categorical_accuracy: 0.2031 - class_out_loss: 0.0417 - loss: 0.1080 - objectness_binary_accuracy: 0.9595 - objectness_loss: 0.0102 - val_bbox_out_loss: 0.0307 - val_class_out_categorical_accuracy: 0.2026 - val_class_out_loss: 0.0198 - val_loss: 0.0765 - val_objectness_binary_accuracy: 0.9729 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - bbox_out_loss: 0.0250 - class_out_categorical_accuracy: 0.2028 - class_out_loss: 0.0408 - loss: 0.1058 - objectness_binary_accuracy: 0.9601 - objectness_loss: 0.0100
# Epoch 39: val_loss improved from 0.07651 to 0.07632, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 170ms/step - bbox_out_loss: 0.0254 - class_out_categorical_accuracy: 0.2033 - class_out_loss: 0.0408 - loss: 0.1054 - objectness_binary_accuracy: 0.9600 - objectness_loss: 0.0100 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2010 - val_class_out_loss: 0.0197 - val_loss: 0.0763 - val_objectness_binary_accuracy: 0.9729 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - bbox_out_loss: 0.0255 - class_out_categorical_accuracy: 0.2014 - class_out_loss: 0.0450 - loss: 0.1130 - objectness_binary_accuracy: 0.9607 - objectness_loss: 0.0099
# Epoch 40: val_loss improved from 0.07632 to 0.07593, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - bbox_out_loss: 0.0254 - class_out_categorical_accuracy: 0.2025 - class_out_loss: 0.0422 - loss: 0.1091 - objectness_binary_accuracy: 0.9598 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0304 - val_class_out_categorical_accuracy: 0.2009 - val_class_out_loss: 0.0196 - val_loss: 0.0759 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - bbox_out_loss: 0.0250 - class_out_categorical_accuracy: 0.2028 - class_out_loss: 0.0410 - loss: 0.1061 - objectness_binary_accuracy: 0.9607 - objectness_loss: 0.0099
# Epoch 41: val_loss did not improve from 0.07593
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - bbox_out_loss: 0.0248 - class_out_categorical_accuracy: 0.2034 - class_out_loss: 0.0417 - loss: 0.1073 - objectness_binary_accuracy: 0.9599 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0306 - val_class_out_categorical_accuracy: 0.2017 - val_class_out_loss: 0.0196 - val_loss: 0.0761 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - bbox_out_loss: 0.0251 - class_out_categorical_accuracy: 0.2026 - class_out_loss: 0.0397 - loss: 0.1043 - objectness_binary_accuracy: 0.9608 - objectness_loss: 0.0098
# Epoch 42: val_loss improved from 0.07593 to 0.07580, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - bbox_out_loss: 0.0252 - class_out_categorical_accuracy: 0.2028 - class_out_loss: 0.0402 - loss: 0.1056 - objectness_binary_accuracy: 0.9599 - objectness_loss: 0.0100 - val_bbox_out_loss: 0.0305 - val_class_out_categorical_accuracy: 0.2031 - val_class_out_loss: 0.0194 - val_loss: 0.0758 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - bbox_out_loss: 0.0255 - class_out_categorical_accuracy: 0.2036 - class_out_loss: 0.0386 - loss: 0.1047 - objectness_binary_accuracy: 0.9595 - objectness_loss: 0.0101
# Epoch 43: val_loss improved from 0.07580 to 0.07554, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 186ms/step - bbox_out_loss: 0.0251 - class_out_categorical_accuracy: 0.2025 - class_out_loss: 0.0452 - loss: 0.1139 - objectness_binary_accuracy: 0.9599 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0304 - val_class_out_categorical_accuracy: 0.2010 - val_class_out_loss: 0.0194 - val_loss: 0.0755 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - bbox_out_loss: 0.0248 - class_out_categorical_accuracy: 0.2032 - class_out_loss: 0.0391 - loss: 0.1030 - objectness_binary_accuracy: 0.9598 - objectness_loss: 0.0100
# Epoch 44: val_loss improved from 0.07554 to 0.07527, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - bbox_out_loss: 0.0248 - class_out_categorical_accuracy: 0.2034 - class_out_loss: 0.0441 - loss: 0.1092 - objectness_binary_accuracy: 0.9594 - objectness_loss: 0.0100 - val_bbox_out_loss: 0.0304 - val_class_out_categorical_accuracy: 0.2006 - val_class_out_loss: 0.0192 - val_loss: 0.0753 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - bbox_out_loss: 0.0248 - class_out_categorical_accuracy: 0.2024 - class_out_loss: 0.0391 - loss: 0.1034 - objectness_binary_accuracy: 0.9600 - objectness_loss: 0.0099
# Epoch 45: val_loss did not improve from 0.07527
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - bbox_out_loss: 0.0248 - class_out_categorical_accuracy: 0.2030 - class_out_loss: 0.0414 - loss: 0.1068 - objectness_binary_accuracy: 0.9605 - objectness_loss: 0.0099 - val_bbox_out_loss: 0.0305 - val_class_out_categorical_accuracy: 0.1993 - val_class_out_loss: 0.0192 - val_loss: 0.0753 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - bbox_out_loss: 0.0244 - class_out_categorical_accuracy: 0.2047 - class_out_loss: 0.0382 - loss: 0.1001 - objectness_binary_accuracy: 0.9594 - objectness_loss: 0.0101
# Epoch 46: val_loss did not improve from 0.07527
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - bbox_out_loss: 0.0250 - class_out_categorical_accuracy: 0.2033 - class_out_loss: 0.0386 - loss: 0.1019 - objectness_binary_accuracy: 0.9597 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0305 - val_class_out_categorical_accuracy: 0.2004 - val_class_out_loss: 0.0191 - val_loss: 0.0753 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - bbox_out_loss: 0.0255 - class_out_categorical_accuracy: 0.2040 - class_out_loss: 0.0380 - loss: 0.1027 - objectness_binary_accuracy: 0.9589 - objectness_loss: 0.0101
# Epoch 47: val_loss improved from 0.07527 to 0.07523, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 168ms/step - bbox_out_loss: 0.0251 - class_out_categorical_accuracy: 0.2032 - class_out_loss: 0.0397 - loss: 0.1049 - objectness_binary_accuracy: 0.9594 - objectness_loss: 0.0099 - val_bbox_out_loss: 0.0305 - val_class_out_categorical_accuracy: 0.2003 - val_class_out_loss: 0.0191 - val_loss: 0.0752 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - bbox_out_loss: 0.0248 - class_out_categorical_accuracy: 0.2013 - class_out_loss: 0.0359 - loss: 0.0991 - objectness_binary_accuracy: 0.9608 - objectness_loss: 0.0097
# Epoch 48: val_loss improved from 0.07523 to 0.07476, saving model to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - bbox_out_loss: 0.0249 - class_out_categorical_accuracy: 0.2022 - class_out_loss: 0.0375 - loss: 0.1017 - objectness_binary_accuracy: 0.9601 - objectness_loss: 0.0099 - val_bbox_out_loss: 0.0304 - val_class_out_categorical_accuracy: 0.1974 - val_class_out_loss: 0.0188 - val_loss: 0.0748 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - bbox_out_loss: 0.0247 - class_out_categorical_accuracy: 0.2038 - class_out_loss: 0.0407 - loss: 0.1056 - objectness_binary_accuracy: 0.9588 - objectness_loss: 0.0102
# Epoch 49: val_loss did not improve from 0.07476
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 187ms/step - bbox_out_loss: 0.0250 - class_out_categorical_accuracy: 0.2030 - class_out_loss: 0.0394 - loss: 0.1023 - objectness_binary_accuracy: 0.9594 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0303 - val_class_out_categorical_accuracy: 0.1985 - val_class_out_loss: 0.0190 - val_loss: 0.0751 - val_objectness_binary_accuracy: 0.9730 - val_objectness_loss: 0.0072 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - bbox_out_loss: 0.0249 - class_out_categorical_accuracy: 0.2050 - class_out_loss: 0.0438 - loss: 0.1105 - objectness_binary_accuracy: 0.9592 - objectness_loss: 0.0100
# Epoch 50: val_loss did not improve from 0.07476
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - bbox_out_loss: 0.0249 - class_out_categorical_accuracy: 0.2041 - class_out_loss: 0.0407 - loss: 0.1056 - objectness_binary_accuracy: 0.9593 - objectness_loss: 0.0101 - val_bbox_out_loss: 0.0303 - val_class_out_categorical_accuracy: 0.2002 - val_class_out_loss: 0.0190 - val_loss: 0.0751 - val_objectness_binary_accuracy: 0.9731 - val_objectness_loss: 0.0073 - learning_rate: 2.5000e-05 - lr: 2.5000e-05
# Restoring model weights from the end of the best epoch: 48.
#
# ✅ Fase 2 completada

# %%
# Guardar historial Fase 2
df_phase2 = save_training_history(
    history_phase2,
    str(LOGS_DIR / f"{MODEL_NAME}_phase2_history.csv")
)

# Visualizar progreso Fase 2
plot_training_history(
    history_phase2, 
    output_path=str(FIGURES_DIR   / f"{MODEL_NAME}_phase2_curves.png"),
    title=f"Fase 2: Fine Tuning - {MODEL_NAME}"
    )
# Out:
# 💾 Saved training history to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/MBNTv3_ssdlite_v7_phase2_history.csv
# 📊 Saved training plot to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/reports/figures/MBNTv3_ssdlite_v7/MBNTv3_ssdlite_v7_phase2_curves.png

# %% [markdown]
# ## 8. Evaluación del Modelo

# %%
# Cargar mejor modelo guardado
best_model_path = CHECKPOINTS_DIR   / f"{MODEL_NAME}_phase2_best.keras"

if best_model_path.exists():
    print(f"📂 Cargando mejor modelo desde: {best_model_path}")
    model = tf.keras.models.load_model(
        best_model_path,
        custom_objects={
            "loss_fn": binary_focal_loss(FOCAL_ALPHA, FOCAL_GAMMA),
        },
        compile=False
    )
    # Recompilar
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=PHASE2_LR),
        loss=losses,
        loss_weights=loss_weights,
        metrics={
            "objectness": ["binary_accuracy"],
            "class_out": ["categorical_accuracy"],
        }
    )
    print("✅ Mejor modelo cargado")
else:
    print("⚠️ No se encontró checkpoint, usando modelo actual")
# Out:
# 📂 Cargando mejor modelo desde: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/MBNTv3_ssdlite_v7_phase2_best.keras
# ✅ Mejor modelo cargado

# %%
# Evaluar en conjunto de validación
print("\n📊 Evaluación en conjunto de VALIDACIÓN:")
val_results = model.evaluate(val_gen, verbose=1)

print("\n📊 Evaluación en conjunto de TEST:")
test_results = model.evaluate(test_gen, verbose=1)

# Mostrar métricas
metric_names = model.metrics_names
print(f"\n{'='*50}")
print("RESUMEN DE MÉTRICAS")
print(f"{'='*50}")
print(f"{'Métrica':<35} {'Val':>10} {'Test':>10}")
print(f"{'-'*50}")
for name, val, test in zip(metric_names, val_results, test_results):
    print(f"{name:<35} {val:>10.4f} {test:>10.4f}")
# Out:
# 📊 Evaluación en conjunto de VALIDACIÓN:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - bbox_out_loss: 0.0304 - class_out_categorical_accuracy: 0.1974 - class_out_loss: 0.0188 - loss: 0.0748 - objectness_binary_accuracy: 0.9730 - objectness_loss: 0.0072
#
# 📊 Evaluación en conjunto de TEST:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - bbox_out_loss: 0.0229 - class_out_categorical_accuracy: 0.2151 - class_out_loss: 0.0476 - loss: 0.1115 - objectness_binary_accuracy: 0.9722 - objectness_loss: 0.0072
#
# ==================================================
# RESUMEN DE MÉTRICAS
# ==================================================
# Métrica                                    Val       Test
# --------------------------------------------------
# loss                                    0.0748     0.1115
# compile_metrics                         0.0072     0.0072
# objectness_loss                         0.0188     0.0476
# class_out_loss                          0.0304     0.0229
# bbox_out_loss                           0.1974     0.2151

# %%
# Visualizar predicciones en imágenes aleatorias de test (CON NMS)
# La función visualize_predictions_nms está modularizada en src_mobilenet/utils_mobilenet_infer.py
#SCORE_THRESHOLD = 0.45

fig = visualize_predictions_nms(
    model=model,
    images_data=test_data,
    anchors=anchors,
    class_names=CLASS_NAMES,
    img_size=IMG_SIZE,
    num_samples=12,
    score_threshold=SCORE_THRESHOLD,
    nms_iou_threshold=NMS_IOU_THRESHOLD,
    random_seed=None,  # None = selección aleatoria cada vez, o fijar un número para reproducibilidad
    save_path=str(FIGURES_DIR / f"{MODEL_NAME}_predictions_nms.png"),
    title=f"Predicciones con NMS - {MODEL_NAME}",
    max_cols=4
)
plt.show()
print("✅ Predicciones visualizadas con NMS aplicado (imágenes aleatorias)")
# Out:
# ✅ Predicciones visualizadas con NMS aplicado (imágenes aleatorias)

# %% [markdown]
# ## 9. Exportar a TFLite para ESP32-S3

# %%
# Guardar modelo Keras final
model_keras_path = EXPORT_DIR   / f"{MODEL_NAME}_final.keras"
model.save(model_keras_path)
print(f"💾 Modelo Keras guardado: {model_keras_path}")
# Out:
# 💾 Modelo Keras guardado: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/final_export/MBNTv3_ssdlite_v7_final.keras

# %%
# ============================================
# EXPORTACIÓN TFLite PARA ESP32-S3
# ============================================
# 
# IMPORTANTE: La conversión TFLite puede fallar en el notebook por problemas de memoria.
# Se recomienda ejecutar el script externo para máxima estabilidad.

import subprocess
import sys

# Verificar que el modelo Keras existe
model_keras_path = EXPORT_DIR   / f"{MODEL_NAME}_final.keras"
int8_tflite_path = EXPORT_DIR   / f"{MODEL_NAME}_int8.tflite"

if not model_keras_path.exists():
    print(f"❌ Error: No se encontró el modelo: {model_keras_path}")
    print("   Ejecuta la celda de 'Guardar modelo Keras final' primero")
elif int8_tflite_path.exists():
    # Ya existe el modelo TFLite
    size_kb = int8_tflite_path.stat().st_size / 1024
    print(f"✅ Modelo TFLite ya existe: {int8_tflite_path}")
    print(f"   Tamaño: {size_kb:.1f} KB ({size_kb/1024:.2f} MB)")
    if size_kb < 1024:
        print(f"   🎉 ¡Cabe en ESP32-S3!")
else:
    print(f"✅ Modelo Keras encontrado: {model_keras_path}")
    print(f"   Tamaño: {model_keras_path.stat().st_size / 1024 / 1024:.2f} MB")
    
    print("\n" + "="*60)
    print("🔧 Ejecutando exportación en terminal...")
    print("="*60)
    
    # Ejecutar el script de exportación
    script_path = ING_MODELOS / "scripts/export_tflite_v2.py"
    
    if script_path.exists():
        result = subprocess.run(
            [sys.executable, str(script_path)],
            capture_output=True,
            text=True,
            cwd=str(ING_MODELOS),
        )
        print(result.stdout)
        if result.returncode != 0:
            print(f"⚠️ Advertencias: {result.stderr}")
    else:
        print(f"❌ Script no encontrado: {script_path}")
        print("\nEjecuta manualmente en terminal:")
        print(f"   python scripts/export_tflite_v2.py")
# Out:
# ✅ Modelo Keras encontrado: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/final_export/MBNTv3_ssdlite_v7_final.keras
#    Tamaño: 2.78 MB
#
# ============================================================
# 🔧 Ejecutando exportación en terminal...
# ============================================================
# ============================================================
# 📦 EXPORTACIÓN TFLite PARA ESP32-S3
# ============================================================
#
# 🔍 Auto-detectado modelo más reciente: MBNTv3_ssdlite_v7
#
# 📁 Modelo entrada: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/final_export/MBNTv3_ssdlite_v7_final.keras
# 📁 Modelo salida:  /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/final_export/MBNTv3_ssdlite_v7_int8.tflite
#
# 📷 Cargando imágenes de calibración...
#    Imágenes: (50, 224, 224, 3)
#
# 📂 Cargando modelo...
# ✅ Modelo cargado: MBNTv3_ssdlite_v7
#
# 🔧 Estrategia 1: Usando Concrete Function...
#    ✅ Conversión exitosa
#
# 💾 Guardando modelo TFLite...
#
# ✅ Modelo guardado: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/final_export/MBNTv3_ssdlite_v7_int8.tflite
#    Tamaño: 803.0 KB (0.78 MB)
#
# 🎉 ¡El modelo CABE en ESP32-S3!
#
# 🔍 Verificando modelo...
#    Input: [  1 224 224   3] dtype=<class 'numpy.float32'>
#    Outputs: 3
#    ✅ Inferencia OK
#
# ============================================================
# ✅ EXPORTACIÓN COMPLETADA
# ============================================================

# %%
# Verificar modelo TFLite exportado
import time

int8_tflite_path = EXPORT_DIR   / f"{MODEL_NAME}_int8.tflite"

if int8_tflite_path.exists():
    size_kb = int8_tflite_path.stat().st_size / 1024
    size_mb = size_kb / 1024
    
    print(f"✅ Modelo TFLite encontrado: {int8_tflite_path.name}")
    print(f"   Tamaño: {size_kb:.1f} KB ({size_mb:.2f} MB)")
    
    if size_kb < 1024:
        print(f"\n🎉 ¡El modelo CABE en ESP32-S3! (límite ~1 MB)")
    else:
        print(f"\n⚠️ El modelo podría ser muy grande para ESP32-S3")
    
    # Guardar path para uso posterior
    tflite_paths = {"int8": str(int8_tflite_path)}
    
    # Cargar y verificar
    print(f"\n🔍 Verificando modelo TFLite...")
    interpreter = tf.lite.Interpreter(model_path=str(int8_tflite_path))
    interpreter.allocate_tensors()
    
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    
    print(f"\n📊 Detalles del modelo:")
    print(f"   Input: {input_details[0]['shape']} dtype={input_details[0]['dtype']}")
    print(f"   Outputs: {len(output_details)}")
    for i, out in enumerate(output_details):
        name = out['name'].split('/')[-1] if '/' in out['name'] else out['name']
        print(f"      [{i}] {name}: {out['shape']} dtype={out['dtype']}")
    
    # Test de inferencia
    print(f"\n🧪 Test de inferencia...")
    test_input = np.random.rand(1, 224, 224, 3).astype(np.float32)
    interpreter.set_tensor(input_details[0]['index'], test_input)
    interpreter.invoke()
    print(f"   ✅ Inferencia de prueba exitosa")
    
    # Benchmark de tiempo (promedio de 10 runs)
    times = []
    for _ in range(10):
        start = time.time()
        interpreter.invoke()
        times.append(time.time() - start)
    
    avg_time_ms = np.mean(times) * 1000
    print(f"\n⏱️ Tiempo de inferencia (CPU Mac):")
    print(f"   Promedio: {avg_time_ms:.1f} ms")
    print(f"   📝 En ESP32-S3 será ~10-50x más lento (~100-500 ms típico)")
    
else:
    print(f"❌ No se encontró el modelo TFLite: {int8_tflite_path}")
    print("\n   Ejecuta la celda anterior o el script en terminal:")
    print(f"   python scripts/export_tflite_v2.py")
    tflite_paths = {"int8": None}
# Out:
# ✅ Modelo TFLite encontrado: MBNTv3_ssdlite_v7_int8.tflite
#    Tamaño: 803.0 KB (0.78 MB)
#
# 🎉 ¡El modelo CABE en ESP32-S3! (límite ~1 MB)
#
# 🔍 Verificando modelo TFLite...
#
# 📊 Detalles del modelo:
#    Input: [  1 224 224   3] dtype=<class 'numpy.float32'>
#    Outputs: 3
#       [0] Identity: [  1 588   4] dtype=<class 'numpy.float32'>
#       [1] Identity_1: [  1 588   2] dtype=<class 'numpy.float32'>
#       [2] Identity_2: [  1 588   1] dtype=<class 'numpy.float32'>
#
# 🧪 Test de inferencia...
#    ✅ Inferencia de prueba exitosa
#
# ⏱️ Tiempo de inferencia (CPU Mac):
#    Promedio: 1.7 ms
#    📝 En ESP32-S3 será ~10-50x más lento (~100-500 ms típico)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# ## 10. Resumen y Próximos Pasos

# %%
# Resumen final del experimento
print("\n" + "="*70)
print("📋 RESUMEN DEL EXPERIMENTO")
print("="*70)

print(f"\n🏗️ Arquitectura:")
print(f"   Modelo: {MODEL_NAME}")
print(f"   Backbone: MobileNetV3 Small (minimalistic=True)")
print(f"   Head: SSD-Lite con convoluciones separables")
print(f"   Clases: {NUM_CLASSES} ({', '.join(CLASS_NAMES)})")
print(f"   Anchors: {len(anchors)} ({NUM_ANCHORS_PER_CELL} por celda)")

print(f"\n📊 Dataset:")
print(f"   Train: {len(train_data)} imágenes")
print(f"   Val: {len(val_data)} imágenes")
print(f"   Test: {len(test_data)} imágenes")

print(f"\n⚙️ Entrenamiento:")
print(f"   Fase 1: {PHASE1_EPOCHS} épocas (LR={PHASE1_LR})")
print(f"   Fase 2: hasta {PHASE2_EPOCHS} épocas (LR={PHASE2_LR})")

# Verificar archivos generados
print(f"\n💾 Archivos Generados:")

model_keras_path = EXPORT_DIR   /f"{MODEL_NAME}_final.keras"
if model_keras_path.exists():
    size_mb = model_keras_path.stat().st_size / 1024 / 1024
    print(f"   ✅ Modelo Keras: {model_keras_path.name} ({size_mb:.2f} MB)")
else:
    print(f"   ❌ Modelo Keras no encontrado")

int8_tflite_path = EXPORT_DIR   /f"{MODEL_NAME}_int8.tflite"
if int8_tflite_path.exists():
    size_kb = int8_tflite_path.stat().st_size / 1024
    print(f"   ✅ TFLite INT8: {int8_tflite_path.name} ({size_kb:.1f} KB)")
    
    if size_kb < 1024:
        print(f"\n🎉 ¡El modelo INT8 ({size_kb:.1f} KB) CABE en ESP32-S3! (límite: ~1 MB)")
    else:
        print(f"\n⚠️ El modelo INT8 ({size_kb:.1f} KB) excede el límite recomendado")
else:
    print(f"   ⏳ TFLite INT8: Pendiente de exportar")
    print(f"      Ejecuta en terminal: python scripts/export_tflite.py --model {model_keras_path}")

# Verificar logs
phase1_log = LOGS_DIR   / f"{MODEL_NAME}_phase1_history.csv"
phase2_log = LOGS_DIR   /f"{MODEL_NAME}_phase2_history.csv"
if phase1_log.exists():
    print(f"   ✅ Log Fase 1: {phase1_log.name}")
if phase2_log.exists():
    print(f"   ✅ Log Fase 2: {phase2_log.name}")

print("\n" + "="*70)
# Out:
# ======================================================================
# 📋 RESUMEN DEL EXPERIMENTO
# ======================================================================
#
# 🏗️ Arquitectura:
#    Modelo: MBNTv3_ssdlite_v7
#    Backbone: MobileNetV3 Small (minimalistic=True)
#    Head: SSD-Lite con convoluciones separables
#    Clases: 2 (footpath, obstacle)
#    Anchors: 588 (12 por celda)
#
# 📊 Dataset:
#    Train: 995 imágenes
#    Val: 68 imágenes
#    Test: 71 imágenes
#
# ⚙️ Entrenamiento:
#    Fase 1: 30 épocas (LR=0.001)
#    Fase 2: hasta 50 épocas (LR=5e-05)
#
# 💾 Archivos Generados:
#    ✅ Modelo Keras: MBNTv3_ssdlite_v7_final.keras (2.78 MB)
#    ✅ TFLite INT8: MBNTv3_ssdlite_v7_int8.tflite (803.0 KB)
#
# 🎉 ¡El modelo INT8 (803.0 KB) CABE en ESP32-S3! (límite: ~1 MB)
#    ✅ Log Fase 1: MBNTv3_ssdlite_v7_phase1_history.csv
#    ✅ Log Fase 2: MBNTv3_ssdlite_v7_phase2_history.csv
#
# ======================================================================

# %% [markdown]
# ## 📊 Evaluación Avanzada con mAP@50
#
# Esta sección evalúa el modelo con métricas profesionales de detección de objetos:
# - **mAP@50**: Mean Average Precision a IoU threshold 0.5
# - **Precision, Recall, F1-Score** por clase
# - **Matriz de Confusión** normalizada con columna "No Detection" (FN) y fila "Background" (FP)

# %%
# Evaluación completa del modelo Keras
print("🔍 Evaluando modelo Keras en dataset de Test...")

keras_results = evaluate_model_full(
    model=model,
    test_data=test_data,
    anchors=anchors,
    num_classes=NUM_CLASSES,
    class_names=CLASS_NAMES,
    score_threshold=SCORE_THRESHOLD,       # Umbral para NMS
    nms_iou_threshold=NMS_IOU_THRESHOLD,     # IoU para NMS
    eval_iou_threshold=0.5,    # IoU para matching detección-GT
    cm_score_threshold=0.5,    # Umbral para confusion matrix
    img_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    is_tflite=False,
    verbose=True,
)
# Out:
# 🔍 Evaluando modelo Keras en dataset de Test...
# 🔍 Evaluating model on 71 images...
#    Loaded 71 images
#    Computing metrics...
#
# ============================================================
# 📊 EVALUATION RESULTS
# ============================================================
#
# 📈 Overall Metrics:
#    mAP@50:     0.5591
#    Precision:  0.4238
#    Recall:     0.4000
#    F1-Score:   0.4116
#
# 📦 Detection Counts:
#    Ground Truth:     160
#    Predictions:      151
#    True Positives:   64
#    False Positives:  87
#    False Negatives:  96
#
# 📊 Per-Class Metrics:
#    Class              AP@50     Prec   Recall       F1
#    -----------------------------------------------
#    footpath          0.8023   0.6290   0.7091   0.6667
#    obstacle          0.3160   0.2809   0.2381   0.2577
# ============================================================

# %%
# Visualizar matriz de confusión del modelo Keras
fig_cm_keras = plot_confusion_matrix(
    cm=keras_results.confusion_matrix,
    class_names=CLASS_NAMES,
    title=f"Confusion Matrix - {MODEL_NAME} (Keras)",
    figsize=(10, 8),
    save_path=str(FIGURES_DIR   / f"{MODEL_NAME}_confusion_matrix_keras.png"),
)
plt.show()
# Out:
# 💾 Confusion matrix saved to: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/reports/figures/MBNTv3_ssdlite_v7/MBNTv3_ssdlite_v7_confusion_matrix_keras.png

# %%
# Evaluar modelo TFLite INT8 (si existe)
int8_tflite_path = EXPORT_DIR / f"{MODEL_NAME}_int8.tflite"

if int8_tflite_path.exists():
    print("🔍 Evaluando modelo TFLite INT8 en dataset de Test...")
    
    # Cargar interpreter TFLite
    tflite_interpreter = tf.lite.Interpreter(model_path=str(int8_tflite_path))
    tflite_interpreter.allocate_tensors()
    
    tflite_results = evaluate_model_full(
        model=tflite_interpreter,
        test_data=test_data,
        anchors=anchors,
        num_classes=NUM_CLASSES,
        class_names=CLASS_NAMES,
        score_threshold=SCORE_THRESHOLD,
        nms_iou_threshold= NMS_IOU_THRESHOLD,
        eval_iou_threshold=0.5,
        cm_score_threshold=0.5,
        img_size=IMG_SIZE,
        batch_size=1,  # TFLite procesa de uno en uno
        is_tflite=True,
        verbose=True,
    )
    
    # Comparar Keras vs TFLite
    comparison = compare_keras_vs_tflite(keras_results, tflite_results, CLASS_NAMES)
    
    # Confusion matrix TFLite
    fig_cm_tflite = plot_confusion_matrix(
        cm=tflite_results.confusion_matrix,
        class_names=CLASS_NAMES,
        title=f"Confusion Matrix - {MODEL_NAME} (TFLite INT8)",
        figsize=(10, 8),
        save_path=str(FIGURES_DIR   / f"{MODEL_NAME}_confusion_matrix_tflite.png"),
    )
    plt.show()
else:
    print(f"⚠️ Modelo TFLite no encontrado: {int8_tflite_path}")
    print("   Ejecuta la exportación primero para comparar Keras vs TFLite")
    tflite_results = None
# Out:
# 🔍 Evaluando modelo TFLite INT8 en dataset de Test...
# 🔍 Evaluating model on 71 images...
#    Loaded 71 images
#    Processed 50/71 images
#    Computing metrics...
#
# ============================================================
# 📊 EVALUATION RESULTS
# ============================================================
#
# 📈 Overall Metrics:
#    mAP@50:     0.5437
#    Precision:  0.3984
#    Recall:     0.3187
#    F1-Score:   0.3542
#
# 📦 Detection Counts:
#    Ground Truth:     160
#    Predictions:      128
#    True Positives:   51
#    False Positives:  77
#    False Negatives:  109
#
# 📊 Per-Class Metrics:
#    Class              AP@50     Prec   Recall       F1
#    -----------------------------------------------
#    footpath          0.7909   0.6066   0.6727   0.6379
#    obstacle          0.2966   0.2090   0.1333   0.1628
# ============================================================
#
# ============================================================
# 📊 KERAS vs TFLITE COMPARISON
# ============================================================
#
# Metric                    Keras     TFLite       Diff
# --------------------------------------------------
# mAP@50                   0.5591     0.5437    +0.0154
# Precision                0.4238     0.3984    +0.0254
# Recall                   0.4000     0.3187    +0.0813
# F1-Score                 0.4116     0.3542    +0.0574
#
# AP per Class:
#    footpath            0.8023     0.7909    +0.0114
#    obstacle            0.3160     0.2966    +0.0194
#
# ✅ Cuantización exitosa: degradación mAP < 2%
# ============================================================
# 💾 Confusion matrix saved to: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/reports/figures/MBNTv3_ssdlite_v7/MBNTv3_ssdlite_v7_confusion_matrix_tflite.png

# %% [markdown]
# ### Archivos Generados
#
# | Tipo | Ruta |
# |------|------|
# | **Modelo Keras** | `models/final_export/{model_name}_final.keras` |
# | **TFLite Float32** | `models/final_export/{model_name}_float32.tflite` |
# | **TFLite Float16** | `models/final_export/{model_name}_float16.tflite` |
# | **TFLite INT8** ⭐ | `models/final_export/{model_name}_int8.tflite` |
# | **Logs** | `logs/{model_name}_phase{1,2}_history.csv` |
# | **Figuras** | `reports/figures/{model_name}_*.png` |

# %% [markdown]
# ## 💾 Guardar Experimento
#
# Guardamos la configuración y resultados del experimento para poder comparar con otros experimentos.

# %%
# Crear configuración del experimento
# Determinar nombre del backbone para guardar en config
backbone_name = {
    "small": "MobileNetV3Small",
    "large": "MobileNetV3Large",
    "v2": "MobileNetV2"
}.get(BACKBONE_TYPE, "MobileNetV3Small")

experiment_config = ExperimentConfig(
    name=EXPERIMENT_NAME,
    description=EXPERIMENT_DESCRIPTION,
    backbone=backbone_name,
    minimalistic=MINIMALISTIC,
    num_anchors=NUM_ANCHORS_PER_CELL,
    num_classes=NUM_CLASSES,
    selected_classes=CLASS_NAMES,
    img_size=IMG_SIZE,
    augmentation_level=AUGMENTATION_LEVEL,
    phase1_epochs=PHASE1_EPOCHS,
    phase1_lr=PHASE1_LR,
    phase2_epochs=PHASE2_EPOCHS,
    phase2_lr=PHASE2_LR,
    batch_size=BATCH_SIZE,
    use_focal_loss=True,
    focal_alpha=FOCAL_ALPHA,
    focal_gamma=FOCAL_GAMMA,
    quantization="int8",   
    score_threshold=SCORE_THRESHOLD,
    feature_channels=FEATURE_CHANNELS
)

# Crear resultados del experimento
experiment_results = ExperimentResults(
    map50_keras=keras_results.map50,
    map50_tflite=tflite_results.map50 if tflite_results else 0.0,
    precision_keras=keras_results.precision,
    precision_tflite=tflite_results.precision if tflite_results else 0.0,
    recall_keras=keras_results.recall,
    recall_tflite=tflite_results.recall if tflite_results else 0.0,
    f1_keras=keras_results.f1_score,
    f1_tflite=tflite_results.f1_score if tflite_results else 0.0,
    ap_per_class_keras={CLASS_NAMES[k]: v for k, v in keras_results.ap_per_class.items()},
    ap_per_class_tflite={CLASS_NAMES[k]: v for k, v in tflite_results.ap_per_class.items()} if tflite_results else {},
    keras_model_path=str(EXPORT_DIR / f"{MODEL_NAME}_final.keras"),
    tflite_model_path=str(int8_tflite_path),
    tflite_model_size_kb=int8_tflite_path.stat().st_size / 1024 if int8_tflite_path.exists() else 0,
)

# Crear y guardar experimento completo
experiment = Experiment(config=experiment_config, results=experiment_results)
exp_path = save_experiment(experiment, base_dir=str(LOGS_DIR / "experiments"))

experiment_config.print_summary()
print(f"\n✅ Experimento guardado en: {exp_path}")
# Out:
# 💾 Experiment saved to: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/experiments/mbntv3_ssdlite_v7_20260203_193406.json
#
# ============================================================
# 🔬 EXPERIMENT: MBNTv3_ssdlite_v7
# ============================================================
# 📝 MobileNetV3 Small + Copy-Paste Augmentation para obstacles. Objetivo: Obstacle AP ≥ 40%, Gap < 40pp, Size < 800KB
#
# 🏗️ Model:
#    Backbone: MobileNetV3Small (minimalistic=True)
#    Anchors: 12
#    Classes: 2 - ['footpath', 'obstacle']
#
# 📊 Data:
#    Image size: 224x224
#    Augmentation: heavy
#
# 🎯 Training:
#    Phase 1: 30 epochs @ lr=0.001
#    Phase 2: 50 epochs @ lr=5e-05
#    Batch size: 16
#    Focal loss: True (α=0.25, γ=2.0)
#
# 📦 TFLite:
#    Quantization: int8
# ============================================================
#
# ✅ Experimento guardado en: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/experiments/mbntv3_ssdlite_v7_20260203_193406.json

# %% [markdown]
# ## 📈 Comparación de Experimentos
#
# Carga y compara todos los experimentos guardados para análisis.

# %%
# Cargar todos los experimentos guardados
from src_mobilenet.utils_mobilenet_experiment import (
    load_all_experiments,
    compare_experiments,
    plot_experiments_comparison,
    create_experiment_summary_table,
)

all_experiments = load_all_experiments(str(LOGS_DIR / "experiments"))

if len(all_experiments) > 0:
    # Mostrar tabla de comparación
    df_comparison = compare_experiments(all_experiments, sort_by="mAP@50_keras", ascending=False)
    print("\n📊 Comparación de Experimentos:")
    display(df_comparison[["name", "mAP@50_keras", "mAP@50_tflite", "precision_keras", 
                           "recall_keras", "f1_keras", "tflite_size_kb"]])
    
    # Guardar tabla como CSV
    df_comparison.to_csv(REPORTS_DIR / "experiments_comparison.csv", index=False)
    print(f"\n💾 Tabla guardada en: {REPORTS_DIR / 'experiments_comparison.csv'}")
else:
    print("ℹ️ No hay experimentos guardados aún. Este será el primero.")
# Out:
# 📂 Loaded 7 experiments from /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/experiments
#
# 📊 Comparación de Experimentos:
#                  name  mAP@50_keras  mAP@50_tflite  precision_keras  \
# 2   MBNTv3_ssdlite_v3      0.605898       0.574402         0.203647
# 6  MBNTv3L_ssdlite_v6      0.575725       0.576629         0.358025
# 0   MBNTv3_ssdlite_v1      0.567456       0.550925         0.267442
# 5   MBNTv3_ssdlite_v7      0.559126       0.543732         0.423841
# 4   MBNTv3_ssdlite_v5      0.549169       0.470469         0.407143
# 3   MBNTv3_ssdlite_v4      0.452328       0.450111         0.693333
# 1   MBNTv3_ssdlite_v2      0.405844       0.362374         0.686275
#
#    recall_keras  f1_keras  tflite_size_kb
# 2       0.41875  0.274029      735.953125
# 6       0.36250  0.360248     2310.148438
# 0       0.43125  0.330144      749.820312
# 5       0.40000  0.411576      803.015625
# 4       0.35625  0.380000      803.015625
# 3       0.32500  0.442553      735.953125
# 1       0.21875  0.331754      755.148438
# 💾 Tabla guardada en: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/reports/experiments_comparison.csv

# %%
# Gráfico de comparación visual (si hay más de 1 experimento)
if len(all_experiments) > 1:
    fig_comparison = plot_experiments_comparison(
        all_experiments,
        figsize=(14, 10),
        save_path=str(FIGURES_DIR   / "experiments_comparison.png"),
        title="Comparación de Experimentos - mAP@50 Keras vs TFLite",
        esp32_limit_mb=2.0,
    )
    plt.show()
else:
    print("ℹ️ Ejecuta más experimentos cambiando EXPERIMENT_NAME y configuración")
    print("   Luego vuelve a ejecutar esta sección para ver la comparación gráfica")
# Out:
# 💾 Comparison plot saved to: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/reports/figures/MBNTv3_ssdlite_v7/experiments_comparison.png
