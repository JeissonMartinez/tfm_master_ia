# %% [markdown]
# # 📦 Notebook 06: Entrenamiento YOLO26n para ESP32-S3
#
# Este notebook implementa el pipeline completo de entrenamiento del modelo **YOLO26n**
# para detección de objetos en tiempo real, optimizado para deployment en **ESP32-S3**.
#
# ## Características de YOLO26:
# - 🎯 **NMS-free** (end-to-end): Inferencia simplificada sin post-procesado
# - 🚀 **DFL-free**: Mejor cuantización INT8 para edge deployment
# - ⚡ **MuSGD optimizer**: Convergencia estable automática
# - 📊 **ProgLoss + STAL**: Mejora detección de objetos pequeños
# - 🔥 **43% más rápido** en CPU que YOLO11
#
# ## Estructura del Notebook:
# 1. Setup y Configuración
# 2. Configuración del Experimento
# 3. Conversión Dataset COCO → YOLO
# 4. Análisis de Distribución de Clases
# 5. Configuración de Entrenamiento
# 6. Entrenamiento del Modelo
# 7. Extracción y Visualización de Métricas
# 8. Evaluación en Test Set
# 9. Exportación a TFLite INT8
# 10. Comparación Keras vs TFLite
# 11. Guardado de Resultados
# 12. Comparación de Experimentos

# %% [markdown]
# ## 1. Setup y Configuración

# %%
# ============================================================================
# SECCIÓN 1: SETUP Y CONFIGURACIÓN
# ============================================================================

import os
import sys
from pathlib import Path
import warnings

# Suprimir warnings generales
warnings.filterwarnings('ignore')

# -------------------------------------------------------------------------
# Configuración PyTorch/CUDA/MPS (usado por YOLO26/Ultralytics)
# -------------------------------------------------------------------------
import torch

# Detectar dispositivo disponible (CUDA para NVIDIA, MPS para Apple Silicon)
if torch.cuda.is_available():
    DEVICE = "cuda"
    gpu_name = torch.cuda.get_device_name(0)
    gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"✅ GPU detectada (CUDA): {gpu_name} ({gpu_memory:.1f} GB)")
elif torch.backends.mps.is_available():
    DEVICE = "mps"
    print("✅ GPU detectada (MPS - Apple Silicon)")
    print("   💡 Metal Performance Shaders habilitado para aceleración")
else:
    DEVICE = "cpu"
    print("⚠️ GPU no disponible - entrenamiento en CPU (será lento)")

print(f"   🖥️ Dispositivo PyTorch: {DEVICE}")

# -------------------------------------------------------------------------
# Configuración TensorFlow (solo para exportación TFLite en Sección 9)
# -------------------------------------------------------------------------
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suprimir logs verbosos de TF

import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ TensorFlow: memory growth habilitado para {len(gpus)} GPU(s)")
    except RuntimeError as e:
        print(f"⚠️ TensorFlow GPU config: {e}")

# Configurar paths
NOTEBOOK_DIR = Path(os.getcwd())
PROJECT_ROOT = NOTEBOOK_DIR.parent
SRC_PATH = PROJECT_ROOT

# Añadir src_yolo al path
sys.path.insert(0, str(SRC_PATH))

# Verificar estructura de directorios
print("\n📁 Estructura del proyecto:")
print(f"   Notebook: {NOTEBOOK_DIR}")
print(f"   Project:  {PROJECT_ROOT}")
print(f"   Src:      {SRC_PATH}")

# Verificar que src_yolo existe
YOLO_SRC = SRC_PATH / "src_yolo"
if YOLO_SRC.exists():
    print(f"\n✅ src_yolo encontrado en: {YOLO_SRC}")
else:
    print(f"\n❌ src_yolo NO encontrado - verificar estructura")

# Imports de utilidades YOLO26
from src_yolo import (
    # IO
    safe_mkdir, safe_exists,
    # Data
    create_yolo_dataset, get_class_distribution, get_class_distribution_yolo,
    calculate_class_weights, prepare_yolo_from_existing,
    # Model
    load_yolo26_model, print_model_summary,
    check_ultralytics_version, check_yolo26_features, YOLO26_SPECS,
    # Training
    Yolo26TrainConfig, train_yolo26,
    # Metrics
    extract_yolo_metrics, plot_yolo_history, get_best_metrics,
    # Export
    export_tflite_int8, verify_tflite_model, estimate_model_size,
    compare_keras_vs_tflite,
    # Eval
    evaluate_model, plot_confusion_matrix,
    # Experiment
    Yolo26ExperimentConfig, Yolo26ExperimentResults, Yolo26Experiment,
    save_experiment, load_all_experiments, compare_experiments,
)

print("\n✅ Imports de src_yolo completados")

# Verificar versión de Ultralytics
ultralytics_version = check_ultralytics_version()
print(f"\n📦 Ultralytics {ultralytics_version} listo para entrenamiento YOLO26")
# Out:
# ✅ GPU detectada (MPS - Apple Silicon)
#    💡 Metal Performance Shaders habilitado para aceleración
#    🖥️ Dispositivo PyTorch: mps
# ✅ TensorFlow: memory growth habilitado para 1 GPU(s)
#
# 📁 Estructura del proyecto:
#    Notebook: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/notebooks
#    Project:  /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS
#    Src:      /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS
#
# ✅ src_yolo encontrado en: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/src_yolo
#
# ✅ Imports de src_yolo completados
# ✅ Ultralytics version: 8.4.9
#    ✅ Compatible con YOLO26 (end2end, DFL-free)
#
# 📦 Ultralytics 8.4.9 listo para entrenamiento YOLO26

# %% [markdown]
# ## 2. Configuración del Experimento

# %%
# ============================================================================
# SECCIÓN 2A: CONFIGURACIÓN DEL EXPERIMENTO
# ============================================================================
# Modificar estos valores para cada experimento.

# Configuración del modelo YOLO26
MODEL_VARIANT = "yolo26n"  # Variante más pequeña para ESP32
IMGSZ = 224  # Tamaño de imagen para ESP32-S3

# Definir versión del experimento
VERSION = "v2"
EXPERIMENT_NAME = f"{MODEL_VARIANT}_{VERSION}"
DESCRIPTION = """Segundo entrenenamiento YOLO26n para ESP32-S3.
Objetivo: Probar el desempeño con un nuevo dataset optimizado, balanceado y aumentado."""


EXPERIMENT_NOTES = """
Análisis del problema:
1. Dataset: 27,264 anotaciones (obstacle:7,502, dog:4941, person: 4314, stair: 5,778 , door: 4,729)
2. Se elimina el uso de la clase 'footpath'.
3. Se tiene un dataset mucho más equilibrado, con media de : 5452.8 anotaciones por clase, lo que debería mejorar la capacidad de generalización del modelo.

Configuración justificada:
- EPOCHS=5: En esta primera prueba, se reduce a 5 para validar la configuración y evitar largos tiempos de entrenamiento (se aumentará en futuros experimentos)
- PATIENCE=4: Early stopping moderado para evitar overfitting
- LR0=0.01: Default Ultralytics, mayor que v0 para mejor convergencia
- MOSAIC=1.0: Máximo para mejorar detección de objetos pequeños (obstacle)
- MIXUP=0.15: Bajo-moderado, regularización sin confusión
- CLS_LOSS_WEIGHT=1.0: Aumentado para mejorar clasificación (problema en MobileNetV3)
- SCALE=0.5: ±50% escala para variabilidad de tamaños de obstacle

Objetivos: (mantener los de la v1)
- mAP@50 (Keras) ≥ 0.65 (vs 0.606 MobileNetV3)
- mAP@50 (TFLite) ≥ 0.60 (vs 0.574 MobileNetV3)
- Precision ≥ 0.50 (vs 0.204 MobileNetV3)
- Recall ≥ 0.55 (vs 0.419 MobileNetV3)
- F1 ≥ 0.52 (vs 0.274 MobileNetV3)
""".strip()

# Clases del dataset (orden según dataset_maestro_aug)
CLASS_NAMES = ["obstacle", "dog", "person", "stair", "door"]
NUM_CLASSES = len(CLASS_NAMES)

# --- Umbrales de evaluación e inferencia ---
CONF_THRESHOLD = 0.25  # Umbral de confianza para detecciones
IOU_THRESHOLD = 0.5    # Umbral IoU para NMS y matching (estándar COCO)

# --- Entrenamiento ---
EPOCHS = 5              # Épocas suficientes para convergencia
PATIENCE = 4            # Early stopping moderado (evita overfitting)
BATCH_SIZE = 16         # Óptimo para MPS con IMGSZ=224

# --- Optimizador ---
OPTIMIZER = "MuSGD"      # 'auto' selecciona MuSGD para YOLO26 (recomendado)
LR0 = 0.01              # Learning rate inicial (default Ultralytics)
LRF = 0.01              # Factor final: lr_final = lr0 * lrf = 0.0001
COS_LR = True           # Decaimiento coseno (suave y efectivo)

# --- Augmentación (optimizada para objetos pequeños) ---
MOSAIC = 1.0            # Máximo: combina 4 imágenes, mejora small objects
MIXUP = 0.15            # Bajo-moderado: regularización sin confusión
CLOSE_MOSAIC = 15       # Desactivar mosaic últimas 15 épocas (estabiliza)
SCALE = 0.5             # ±50% escala: crítico para obstacle (tamaños variables)
FLIPLR = 0.5            # Flip horizontal estándar

# --- Pesos de Pérdida ---
BOX_LOSS_WEIGHT = 7.5   # Peso de bounding box (default Ultralytics)
CLS_LOSS_WEIGHT = 1.0   # Aumentado: mejorar clasificación (problema MobileNetV3)

# --- YOLO26 Específico ---
MAX_DET = 300           # Máximo detecciones por imagen (end2end head)

# %%
# ============================================================================
# SECCIÓN 2B: RUTAS DE DATOS Y DIRECTORIOS
# ============================================================================

# --- Formato del dataset de origen ---
# Opciones: "COCO" (requiere conversión) o "YOLO" (ya en formato YOLO)
DATASET_FORMAT = "YOLO"

# --- Rutas del proyecto ---
ING_DATOS = PROJECT_ROOT.parent / "01_ING_DATOS"

# --- Ruta del Dataset YOLO (si DATASET_FORMAT == "YOLO") ---
YOLO_SOURCE_DIR = ING_DATOS / "Datasets_options/dataset_maestro_aug"

# --- Rutas del Dataset COCO (si DATASET_FORMAT == "COCO") ---
COCO_TRAIN_JSON = ING_DATOS / "Dataset/train/augmented2_images/train_final2.json"
COCO_VAL_JSON = ING_DATOS / "Dataset/valid/val_final.json"
COCO_TEST_JSON = ING_DATOS / "Dataset/test/test_final.json"

# --- Paths de salida ---
YOLO_DATASET_DIR = PROJECT_ROOT / "datasets" / "yolo26"
MODELS_DIR = PROJECT_ROOT / "models"
LOGS_DIR = PROJECT_ROOT / "logs"
REPORTS_DIR = PROJECT_ROOT / "reports" / EXPERIMENT_NAME
EXPERIMENTS_DIR = LOGS_DIR / "experiments"

# Crear directorios
for dir_path in [YOLO_DATASET_DIR, MODELS_DIR, LOGS_DIR, REPORTS_DIR, EXPERIMENTS_DIR]:
    safe_mkdir(str(dir_path))

# %%
# ============================================================================
# SECCIÓN 2C: RESUMEN DE CONFIGURACIÓN
# ============================================================================

# --- Resumen de Configuración ---
print("\n🔬 CONFIGURACIÓN DEL EXPERIMENTO")
print(f"📋 Nombre: {EXPERIMENT_NAME}")

print(f"📊 Formato de dataset: {DATASET_FORMAT}")
if DATASET_FORMAT == "YOLO":
    print(f"   📁 Origen: {YOLO_SOURCE_DIR}")
    print(f"   📁 Dataset YOLO:         {YOLO_DATASET_DIR}")
    # Verificar la existancia del Dataset YOLO
    print("\n📂 Verificando dataset YOLO:")
    if YOLO_SOURCE_DIR.exists():
        print(f"   ✅ {YOLO_SOURCE_DIR.name} - ENCONTRADO")
        # Verificar subdirectorios
        for subdir in ["train", "val", "test"]:
            subdir_path = YOLO_SOURCE_DIR / subdir
            if subdir_path.exists():
                print(f"      ✅ {subdir}/ - ENCONTRADO")
            else:
                print(f"      ❌ {subdir}/ - NO ENCONTRADO")
else:
    print(f"   📁 COCO Train: {COCO_TRAIN_JSON}")
    print(f"   📁 COCO Val: {COCO_VAL_JSON}")
    print(f"   📁 COCO Test: {COCO_TEST_JSON}")
    # Verificar existencia del dataset
    print("\n📂 Verificando archivos JSON:")
    for json_path in [COCO_TRAIN_JSON, COCO_VAL_JSON, COCO_TEST_JSON]:
        if safe_exists(str(json_path)):
            print(f"   ✅ {json_path.name}")
        else:
            print(f"   ❌ {json_path.name} - NO ENCONTRADO")

print(f"   Modelos:              {MODELS_DIR}")
print(f"   Logs:                 {LOGS_DIR}")


print("\n⚙️ HIPERPARÁMETROS DE ENTRENAMIENTO")
print(f"📊 Entrenamiento:")
print(f"   Epochs:     {EPOCHS}")
print(f"   Patience:   {PATIENCE}")
print(f"   Batch size: {BATCH_SIZE}")

print(f"\n🎯 Optimizador:")
print(f"   Optimizer:  {OPTIMIZER}")
print(f"   LR inicial: {LR0}")
print(f"   LR final:   {LR0 * LRF:.6f} (lr0 × lrf)")
print(f"   Cosine LR:  {COS_LR}")

print(f"\n🔄 Augmentación:")
print(f"   Mosaic:     {MOSAIC}")
print(f"   Mixup:      {MIXUP}")
print(f"   Scale:      ±{SCALE*100:.0f}%")
print(f"   Flip LR:    {FLIPLR}")

print(f"\n⚖️ Loss Weights:")
print(f"   Box:        {BOX_LOSS_WEIGHT}")
print(f"   Cls:        {CLS_LOSS_WEIGHT}")

print(f"\n🤖 Umbrales para evaluación y predicción:")
print(f"   Conf threshold: {CONF_THRESHOLD}")
print(f"   IoU threshold:  {IOU_THRESHOLD}")
# Out:
# 🔬 CONFIGURACIÓN DEL EXPERIMENTO
# 📋 Nombre: yolo26n_v2
# 📊 Formato de dataset: YOLO
#    📁 Origen: /Users/admin/Documents/TFM_UNIR/01_ING_DATOS/Datasets_options/dataset_maestro_aug
#    📁 Dataset YOLO:         /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26
#
# 📂 Verificando dataset YOLO:
#    ✅ dataset_maestro_aug - ENCONTRADO
#       ❌ train/ - NO ENCONTRADO
#       ❌ val/ - NO ENCONTRADO
#       ❌ test/ - NO ENCONTRADO
#    Modelos:              /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models
#    Logs:                 /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs
#
# ⚙️ HIPERPARÁMETROS DE ENTRENAMIENTO
# 📊 Entrenamiento:
#    Epochs:     5
#    Patience:   4
#    Batch size: 16
#
# 🎯 Optimizador:
#    Optimizer:  MuSGD
#    LR inicial: 0.01
#    LR final:   0.000100 (lr0 × lrf)
#    Cosine LR:  True
#
# 🔄 Augmentación:
#    Mosaic:     1.0
#    Mixup:      0.15
#    Scale:      ±50%
#    Flip LR:    0.5
#
# ⚖️ Loss Weights:
#    Box:        7.5
#    Cls:        1.0
#
# 🤖 Umbrales para evaluación y predicción:
#    Conf threshold: 0.25
#    IoU threshold:  0.5

# %% [markdown]
# ## 3. Conversión Dataset COCO → YOLO

# %%
# ============================================================================
# SECCIÓN 3A: PREPARACIÓN/CONVERSIÓN DATASET → YOLO
# ============================================================================

# Esta celda prepara el dataset según DATASET_FORMAT:
#   - "YOLO": Usa dataset existente en formato YOLO, crea splits automáticos (80/10/10)
#   - "COCO": Convierte de formato COCO a YOLO
#
# En ambos casos se genera la estructura:
#   datasets/yolo26/
#   ├── images/
#   │   ├── train/
#   │   ├── val/
#   │   └── test/
#   ├── labels/
#   │   ├── train/
#   │   ├── val/
#   │   └── test/
#   └── data.yaml

if DATASET_FORMAT == "YOLO":
    # Dataset ya está en formato YOLO - preparar con splits automáticos
    print("📊 Modo: Dataset YOLO existente")
    print(f"   📁 Origen: {YOLO_SOURCE_DIR}")
    print(f"   📁 Destino: {YOLO_DATASET_DIR}")
    print(f"   🔀 Splits automáticos: 80% train / 10% val / 10% test\n")
    
    data_yaml_path = prepare_yolo_from_existing(
        source_dir=str(YOLO_SOURCE_DIR),
        output_dir=str(YOLO_DATASET_DIR),
        class_names=CLASS_NAMES,
        split_ratios=(0.70, 0.15, 0.15),  # 70% train, 15% val, 15% test
        seed=42,  # Reproducibilidad
        verbose=True,
    )
else:
    # Conversión COCO → YOLO
    print("📊 Modo: Conversión COCO → YOLO")
    print(f"   📁 Train JSON: {COCO_TRAIN_JSON}")
    print(f"   📁 Val JSON: {COCO_VAL_JSON}")
    print(f"   📁 Test JSON: {COCO_TEST_JSON}\n")
    
    data_yaml_path = create_yolo_dataset(
        coco_train_json=str(COCO_TRAIN_JSON),
        coco_val_json=str(COCO_VAL_JSON),
        coco_test_json=str(COCO_TEST_JSON),
        output_dir=str(YOLO_DATASET_DIR),
        class_names=CLASS_NAMES,
        copy_images=True,
        verbose=True,
    )

# Verificar resultado
if data_yaml_path:
    DATA_YAML = data_yaml_path
    print(f"\n✅ Dataset YOLO preparado exitosamente")
    print(f"   📄 data.yaml: {DATA_YAML}")
else:
    print("❌ Error preparando dataset YOLO")
# Out:
# 📊 Modo: Dataset YOLO existente
#    📁 Origen: /Users/admin/Documents/TFM_UNIR/01_ING_DATOS/Datasets_options/dataset_maestro_aug
#    📁 Destino: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26
#    🔀 Splits automáticos: 80% train / 10% val / 10% test
#
#
# ============================================================
# 🔧 PREPARANDO DATASET YOLO EXISTENTE
# ============================================================
# 📁 Origen: /Users/admin/Documents/TFM_UNIR/01_ING_DATOS/Datasets_options/dataset_maestro_aug
# 📁 Destino: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26
# 📊 Ratios: train=0.7, val=0.15, test=0.15
#
# 📊 Encontradas 14250 imágenes con labels
#    Train: 9975 imágenes (70.0%)
#    Val:   2137 imágenes (15.0%)
#    Test:  2138 imágenes (15.0%)
#
# 🗑️ Directorio existente eliminado
#
# 🔄 Procesando split: TRAIN...
#    ✅ 9975 pares imagen-label copiados
#
# 🔄 Procesando split: VAL...
#    ✅ 2137 pares imagen-label copiados
#
# 🔄 Procesando split: TEST...
#    ✅ 2138 pares imagen-label copiados
#
# ============================================================
# ✅ Dataset YOLO preparado correctamente
# 📄 data.yaml: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/data.yaml
# 📦 Clases: ['obstacle', 'dog', 'person', 'stair', 'door']
# 📊 Distribución total: {'obstacle': 7502, 'dog': 4941, 'person': 4314, 'stair': 5778, 'door': 4729}
# ============================================================
#
#
# ✅ Dataset YOLO preparado exitosamente
#    📄 data.yaml: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/data.yaml

# %%
# ============================================================================
# SECCIÓN 3B: VERIFICACIÓN DE LABELS YOLO
# ============================================================================

# Verificar que los labels se generaron correctamente
# Esto confirma que el mapeo de clases es correcto:
#   - Los índices en los .txt corresponden a CLASS_NAMES
#   - Las coordenadas están normalizadas (0-1)
#   - La distribución de clases es la esperada

from src_yolo import verify_yolo_labels

verification = verify_yolo_labels(
    yolo_root=str(YOLO_DATASET_DIR),
    class_names=CLASS_NAMES,
    num_samples=3,  # Mostrar 3 archivos de ejemplo por split
    verbose=True,
)

# Guardar resultado para uso posterior
if not verification["valid"]:
    print("\n⚠️ ATENCIÓN: Se detectaron errores en los labels.")
    print("   Revisa los mensajes anteriores antes de continuar.")
# Out:
# ============================================================
# 🔍 VERIFICACIÓN DE LABELS YOLO
# ============================================================
#    📂 Dataset: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26
#    🏷️ Clases esperadas (5): ['obstacle', 'dog', 'person', 'stair', 'door']
#
#    📁 TRAIN:
#       Imágenes: 9975
#       Bounding boxes: 19139
#       Distribución por clase:
#          [0] obstacle: 5273 (27.6%)
#          [1] dog: 3568 (18.6%)
#          [2] person: 2990 (15.6%)
#          [3] stair: 4048 (21.2%)
#          [4] door: 3260 (17.0%)
#
#       📋 Muestra de 3 labels:
#          img_001981.txt:
#             idx=3 → 'stair' | bbox=[0.5257, 0.5218, 0.9476, 0.7828]
#          img_000227.txt:
#             idx=0 → 'obstacle' | bbox=[0.4171, 0.2640, 0.2796, 0.3968]
#             idx=0 → 'obstacle' | bbox=[0.1343, 0.2640, 0.2687, 0.3968]
#             idx=0 → 'obstacle' | bbox=[0.9453, 0.2640, 0.1093, 0.3968]
#          img_006961.txt:
#             idx=4 → 'door' | bbox=[0.4437, 0.5015, 0.2125, 0.9343]
#
#    📁 VAL:
#       Imágenes: 2137
#       Bounding boxes: 4125
#       Distribución por clase:
#          [0] obstacle: 1138 (27.6%)
#          [1] dog: 660 (16.0%)
#          [2] person: 752 (18.2%)
#          [3] stair: 860 (20.8%)
#          [4] door: 715 (17.3%)
#
#       📋 Muestra de 3 labels:
#          aug_000746.txt:
#             idx=1 → 'dog' | bbox=[0.5343, 0.5296, 0.3484, 0.7468]
#             idx=1 → 'dog' | bbox=[0.9804, 0.5296, 0.0390, 0.7468]
#          img_007411.txt:
#             idx=4 → 'door' | bbox=[0.7601, 0.4992, 0.2640, 0.9984]
#          img_007846.txt:
#             idx=4 → 'door' | bbox=[0.7593, 0.4203, 0.2875, 0.7062]
#
#    📁 TEST:
#       Imágenes: 2138
#       Bounding boxes: 4000
#       Distribución por clase:
#          [0] obstacle: 1091 (27.3%)
#          [1] dog: 713 (17.8%)
#          [2] person: 572 (14.3%)
#          [3] stair: 870 (21.8%)
#          [4] door: 754 (18.9%)
#
#       📋 Muestra de 3 labels:
#          img_010180.txt:
#             idx=0 → 'obstacle' | bbox=[0.1015, 0.4882, 0.0929, 0.1453]
#             idx=0 → 'obstacle' | bbox=[0.4195, 0.4875, 0.0757, 0.1437]
#          img_000282.txt:
#             idx=0 → 'obstacle' | bbox=[0.4968, 0.5015, 0.6265, 0.9281]
#          aug_003394.txt:
#             idx=3 → 'stair' | bbox=[0.5249, 0.4999, 0.9445, 0.9953]
#
# ============================================================
# ✅ VERIFICACIÓN EXITOSA - Labels correctamente formateados
# ============================================================

# %% [markdown]
# ## 4. Análisis de Distribución de Clases

# %%
# ============================================================================
# SECCIÓN 4: ANÁLISIS DE DISTRIBUCIÓN DE CLASES
# ============================================================================

import matplotlib.pyplot as plt
import numpy as np

# Obtener distribución de clases según formato del dataset
if DATASET_FORMAT == "YOLO":
    # Para YOLO: usar el dataset procesado en YOLO_DATASET_DIR
    yolo_dist = get_class_distribution_yolo(str(YOLO_DATASET_DIR))
    # Usar distribución del split train
    class_dist_full = yolo_dist.get("train", {})
    print(f"📊 Distribución obtenida de: {YOLO_DATASET_DIR}/labels/train/")
else:
    # Para COCO: usar el JSON original
    class_dist_full = get_class_distribution(str(COCO_TRAIN_JSON))
    print(f"📊 Distribución obtenida de: {COCO_TRAIN_JSON}")

if class_dist_full:
    # Filtrar solo las clases seleccionadas en CLASS_NAMES
    class_dist = {k: v for k, v in class_dist_full.items() if k in CLASS_NAMES}
    
    # Verificar que todas las clases solicitadas existen en el dataset
    missing_classes = [c for c in CLASS_NAMES if c not in class_dist_full]
    if missing_classes:
        print(f"⚠️ Clases no encontradas en dataset: {missing_classes}")
    
    print(f"\n📊 Distribución de Clases Seleccionadas (Train Set):")
    print(f"   Clases filtradas: {CLASS_NAMES}")
    print("-" * 40)
    total = sum(class_dist.values())
    for cls_name, count in sorted(class_dist.items(), key=lambda x: x[1], reverse=True):
        pct = (count / total) * 100
        bar = "█" * int(pct / 2)
        print(f"   {cls_name:<12} {count:>5} ({pct:>5.1f}%) {bar}")
    print("-" * 40)
    print(f"   Total: {total} objetos (de {sum(class_dist_full.values())} en dataset completo)")
    
    # Calcular class weights para manejo de desbalance (solo clases filtradas)
    class_weights = calculate_class_weights(class_dist, CLASS_NAMES)
    print("\n⚖️ Class Weights (para pérdida ponderada):")
    for cls_name, weight in class_weights.items():
        print(f"   {cls_name}: {weight:.3f}")
    
    # Visualizar distribución (solo clases seleccionadas)
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    # Bar chart
    ax = axes[0]
    classes = list(class_dist.keys())
    counts = list(class_dist.values())
    colors = plt.cm.tab10.colors[:len(classes)]
    bars = ax.bar(classes, counts, color=colors)
    ax.set_title(f"Distribución de Clases Seleccionadas ({len(CLASS_NAMES)})", 
                 fontsize=12, fontweight="bold")
    ax.set_xlabel("Clase")
    ax.set_ylabel("Número de Objetos")
    ax.grid(True, alpha=0.3, axis="y")
    for bar, count in zip(bars, counts):
        ax.annotate(f"{count}", xy=(bar.get_x() + bar.get_width()/2, count),
                    ha="center", va="bottom", fontsize=10)
    
    # Pie chart
    ax = axes[1]
    ax.pie(counts, labels=classes, autopct="%1.1f%%", colors=colors, startangle=90)
    ax.set_title(f"Proporción de Clases Seleccionadas ({len(CLASS_NAMES)})", 
                 fontsize=12, fontweight="bold")
    
    plt.tight_layout()
    plt.savefig(str(REPORTS_DIR / f"{EXPERIMENT_NAME}_class_distribution.png"), dpi=150)
    plt.show()
else:
    print("⚠️ No se pudo obtener la distribución de clases")
# Out:
# 📊 Distribución obtenida de: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/labels/train/
#
# 📊 Distribución de Clases Seleccionadas (Train Set):
#    Clases filtradas: ['obstacle', 'dog', 'person', 'stair', 'door']
# ----------------------------------------
#    obstacle      5273 ( 27.6%) █████████████
#    stair         4048 ( 21.2%) ██████████
#    dog           3568 ( 18.6%) █████████
#    door          3260 ( 17.0%) ████████
#    person        2990 ( 15.6%) ███████
# ----------------------------------------
#    Total: 19139 objetos (de 19139 en dataset completo)
#
# ⚖️ Class Weights (para pérdida ponderada):
#    obstacle: 0.698
#    dog: 1.032
#    person: 1.231
#    stair: 0.909
#    door: 1.129

# %% [markdown]
# ## 5. Configuración de Entrenamiento YOLO26

# %%
# ============================================================================
# SECCIÓN 5: CONFIGURACIÓN DE ENTRENAMIENTO YOLO26
# ============================================================================

# Mostrar especificaciones de variantes YOLO26
print("📋 Especificaciones YOLO26 disponibles:")
print("-" * 70)
print(f"{'Variante':<12} {'Params':>10} {'GFLOPs':>10} {'mAP50':>10} {'mAP50-95':>12}")
print("-" * 70)
for variant, specs in YOLO26_SPECS.items():
    print(f"{variant:<12} {specs['params']:<10} {specs['gflops']:<10} "
          f"{specs['map50']:>10.1f} {specs['map50_95']:>12.1f}")
print("-" * 70)
print(f"\n🎯 Seleccionado: {MODEL_VARIANT}")

# Crear configuración de entrenamiento
train_config = Yolo26TrainConfig(
    # Modelo (de Sección 2)
    model=f"{MODEL_VARIANT}.pt",
    imgsz=IMGSZ,
    
    # Entrenamiento (de Sección 2B)
    epochs=EPOCHS,
    patience=PATIENCE,
    batch=BATCH_SIZE,
    
    # Optimizador (de Sección 2B)
    optimizer=OPTIMIZER,
    lr0=LR0,
    lrf=LRF,
    cos_lr=COS_LR,
    
    # Augmentación (de Sección 2B)
    mosaic=MOSAIC,
    mixup=MIXUP,
    close_mosaic=CLOSE_MOSAIC,
    scale=SCALE,
    fliplr=FLIPLR,
    
    # Loss weights (de Sección 2B)
    box=BOX_LOSS_WEIGHT,
    cls=CLS_LOSS_WEIGHT,

    # YOLO26 específico (de Sección 2B)
    max_det=MAX_DET,
    
    # Proyecto
    project=str(LOGS_DIR),
    name=EXPERIMENT_NAME,
    exist_ok=True,
)

# Mostrar resumen de configuración
print(train_config.summary())

# Verificar características YOLO26
print("\n🔍 Verificando características YOLO26...")
check_yolo26_features()
# Out:
# 📋 Especificaciones YOLO26 disponibles:
# ----------------------------------------------------------------------
# Variante         Params     GFLOPs      mAP50     mAP50-95
# ----------------------------------------------------------------------
# yolo26n      2.4M       5.4              40.9         40.1
# yolo26s      9.5M       20.7             48.6         47.8
# yolo26m      20.4M      68.2             53.1         52.5
# yolo26l      24.8M      86.4             55.0         54.4
# yolo26x      55.7M      193.9            57.5         56.9
# ----------------------------------------------------------------------
#
# 🎯 Seleccionado: yolo26n
# ============================================================
# 🔧 CONFIGURACIÓN DE ENTRENAMIENTO YOLO26
# ============================================================
# 📦 Modelo: yolo26n.pt
# 📐 Imagen: 224x224
#
# ⏱️ Entrenamiento:
#    Épocas: 5 | Paciencia: 4
#    Batch: 16 | Workers: 8
#
# 🎯 Optimizador:
#    Tipo: MuSGD (MuSGD para YOLO26)
#    LR inicial: 0.01 → final: 0.0001
#    Cosine LR: True
#
# 🔄 Augmentación:
#    Mosaic: 1.0 | Mixup: 0.15
#    Close mosaic: 15 épocas
#    Scale: 0.5 | Flip LR: 0.5
#
# ⚖️ Loss Weights:
#    Box: 7.5 | Cls: 1.0
#
# 📁 Proyecto: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2
# ============================================================
#
# 🔍 Verificando características YOLO26...
# {'ultralytics_available': True,
#  'yolo26_available': True,
#  'end2end_available': True,
#  'tflite_export': True,
#  'int8_quantization': True}

# %%
# ============================================================================
# SECCIÓN 6: ENTRENAMIENTO DEL MODELO
# ============================================================================

# Iniciar entrenamiento
# YOLO26 usa:
# - MuSGD optimizer (auto-seleccionado)
# - ProgLoss + STAL para mejor detección de objetos pequeños
# - End-to-end training (sin fases separadas)

print("🚀 Iniciando entrenamiento YOLO26n...")
print("⏱️ Tiempo estimado: ~30-60 minutos (GPU) / 2-4 horas (CPU)")
print()

# Entrenar modelo
training_results = train_yolo26(
    data_yaml=DATA_YAML,
    cfg=train_config,
    resume=False,
)

if training_results:
    print("\n✅ Entrenamiento completado exitosamente")
    RESULTS_DIR = str(LOGS_DIR / EXPERIMENT_NAME)
else:
    print("\n⚠️ El entrenamiento tuvo problemas - verificar logs")
    RESULTS_DIR = None
# Out:
# 🚀 Iniciando entrenamiento YOLO26n...
# ⏱️ Tiempo estimado: ~30-60 minutos (GPU) / 2-4 horas (CPU)
#
#
# ============================================================
# 🔧 CONFIGURACIÓN DE ENTRENAMIENTO YOLO26
# ============================================================
# 📦 Modelo: yolo26n.pt
# 📐 Imagen: 224x224
#
# ⏱️ Entrenamiento:
#    Épocas: 5 | Paciencia: 4
#    Batch: 16 | Workers: 8
#
# 🎯 Optimizador:
#    Tipo: MuSGD (MuSGD para YOLO26)
#    LR inicial: 0.01 → final: 0.0001
#    Cosine LR: True
#
# 🔄 Augmentación:
#    Mosaic: 1.0 | Mixup: 0.15
#    Close mosaic: 15 épocas
#    Scale: 0.5 | Flip LR: 0.5
#
# ⚖️ Loss Weights:
#    Box: 7.5 | Cls: 1.0
#
# 📁 Proyecto: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2
# ============================================================
# 🔄 Cargando modelo base: yolo26n.pt
#
# 🚀 Iniciando entrenamiento YOLO26...
#    💡 YOLO26 usa MuSGD optimizer y entrenamiento end-to-end
#    💡 ProgLoss + STAL activos para mejor detección de objetos pequeños
#    💡 Modelo NMS-free para deployment simplificado
#
# New https://pypi.org/project/ultralytics/8.4.12 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.9 🚀 Python-3.10.19 torch-2.5.1 CPU (Apple M1)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=15, cls=1.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=5, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.15, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26n_v2, nbs=64, nms=False, opset=None, optimize=False, optimizer=MuSGD, overlap_mask=True, patience=4, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    243126  ultralytics.nn.modules.head.Detect           [5, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,505,750 parameters, 2,505,750 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 133.0±87.9 MB/s, size: 47.5 KB)
# train: Scanning /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/labels/train... 9975 images, 28 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 9975/9975 4.8Kit/s 2.1s0.1s
# train: New cache created: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/labels/train.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 69, len(boxes) = 19139. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 212.0±58.9 MB/s, size: 42.3 KB)
# val: Scanning /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/labels/val... 2137 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2137/2137 3.5Kit/s 0.6s0.0s
# val: New cache created: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/labels/val.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 11, len(boxes) = 4125. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/labels.jpg...
# optimizer: MuSGD(lr=0.01, momentum=0.937) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5         0G      1.596      6.489    0.02647         29        224: 100% ━━━━━━━━━━━━ 624/624 2.7s/it 28:21<1.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 67/67 1.0it/s 1:041.0sss
#                    all       2137       4125      0.455      0.416      0.367      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5         0G      1.603      4.861    0.02648         44        224: 100% ━━━━━━━━━━━━ 624/624 2.2s/it 23:12<1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 67/67 1.1it/s 1:031.0sss
#                    all       2137       4125       0.54      0.421      0.429      0.237
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5         0G      1.677      4.592    0.02776         33        224: 100% ━━━━━━━━━━━━ 624/624 2.2s/it 22:37<1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 67/67 1.0s/it 1:081.0sss
#                    all       2137       4125       0.51      0.452      0.451      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5         0G      1.632      4.198    0.02699         19        224: 100% ━━━━━━━━━━━━ 624/624 2.1s/it 22:08<1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 67/67 1.0s/it 1:101.2sss
#                    all       2137       4125      0.675      0.558        0.6      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5         0G      1.556       3.88    0.02499         22        224: 100% ━━━━━━━━━━━━ 624/624 2.2s/it 22:50<1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 67/67 1.0it/s 1:051.0sss
#                    all       2137       4125      0.694      0.582       0.63      0.382
#
# 5 epochs completed in 2.077 hours.
# Optimizer stripped from /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/last.pt, 5.3MB
# Optimizer stripped from /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best.pt, 5.3MB
#
# Validating /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best.pt...
# Ultralytics 8.4.9 🚀 Python-3.10.19 torch-2.5.1 CPU (Apple M1)
# YOLO26n summary (fused): 122 layers, 2,375,811 parameters, 0 gradients, 5.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 67/67 1.3it/s 53.6s0.8ss
#                    all       2137       4125      0.695      0.581       0.63      0.382
#               obstacle        478       1138      0.572       0.59      0.589      0.358
#                    dog        246        660       0.67      0.526      0.549      0.285
#                 person        151        752      0.678      0.394      0.489      0.247
#                  stair        749        860      0.751      0.678      0.744      0.444
#                   door        557        715      0.805       0.72      0.776      0.576
# Speed: 0.1ms preprocess, 22.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2
#
# ✅ Entrenamiento completado
#
# 📊 Métricas finales:
#    metrics/precision(B): 0.6953
#    metrics/recall(B): 0.5814
#    metrics/mAP50(B): 0.6296
#    metrics/mAP50-95(B): 0.3821
#    fitness: 0.3821
#
# ✅ Entrenamiento completado exitosamente

# %%
# ============================================================================
# SECCIÓN 6B: RECUPERACIÓN DE ENTRENAMIENTO INTERRUMPIDO
# ============================================================================
# Ejecutar esta celda si el entrenamiento fue interrumpido pero el modelo best.pt existe

RESULTS_DIR = str(LOGS_DIR / EXPERIMENT_NAME)

# Verificar que el modelo existe
BEST_MODEL_PATH = str(LOGS_DIR / EXPERIMENT_NAME / "weights" / "best.pt")

if safe_exists(BEST_MODEL_PATH):
    print(f"✅ Modelo best.pt encontrado: {BEST_MODEL_PATH}")
    print(f"   📂 Results dir: {RESULTS_DIR}")
    print("\n💡 Puedes continuar con la Sección 7 (Extracción de Métricas)")
else:
    print(f"❌ Modelo no encontrado: {BEST_MODEL_PATH}")
# Out:
# ✅ Modelo best.pt encontrado: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best.pt
#    📂 Results dir: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2
#
# 💡 Puedes continuar con la Sección 7 (Extracción de Métricas)

# %% [markdown]
# ## 7. Extracción y Visualización de Métricas

# %%
# ============================================================================
# SECCIÓN 7: EXTRACCIÓN Y VISUALIZACIÓN DE MÉTRICAS
# ============================================================================

# Extraer métricas del entrenamiento
if RESULTS_DIR and safe_exists(RESULTS_DIR):
    history_df = extract_yolo_metrics(
        results_dir=RESULTS_DIR,
        logs_dir=str(LOGS_DIR),
        version_tag=EXPERIMENT_NAME,
        copy_best_model=True,
    )
    
    if history_df is not None:
        print("\n📊 Métricas extraídas exitosamente")
        print(f"   Épocas completadas: {len(history_df)}")
        
        # Obtener mejores métricas
        best_metrics = get_best_metrics(history_df)
        print("\n🏆 Mejores métricas:")
        for key, value in best_metrics.items():
            if "epoch" not in key:
                print(f"   {key}: {value:.4f}")
        
        # Graficar curvas de entrenamiento
        plot_path = str(REPORTS_DIR / f"{EXPERIMENT_NAME}_training_curves.png")
        plot_yolo_history(
            df=history_df,
            save_path=plot_path,
            title=f"YOLO26n - {VERSION} - Curvas de Entrenamiento",
            show=True,
        )
    else:
        print("⚠️ No se pudieron extraer las métricas")
else:
    print("⚠️ Directorio de resultados no encontrado")
    print("   Si el entrenamiento se interrumpió, verificar logs/")
# Out:
# ✅ Historial guardado en: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2_history.csv
# ✅ Mejor modelo: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/models/checkpoints/yolo26n_v2_best.pt
#    📦 Tamaño: 5.09 MB | INT8 estimado: ~1.27 MB
#
# 📊 Métricas extraídas exitosamente
#    Épocas completadas: 5
#
# 🏆 Mejores métricas:
#    best_mAP50: 0.6297
#    best_mAP50-95: 0.3822
#    best_precision: 0.6943
#    best_recall: 0.5823
#    best_box_loss: 1.4149
#    best_cls_loss: 2.7557
# ✅ Gráfico guardado en: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/reports/yolo26n_v2/yolo26n_v2_training_curves.png

# %% [markdown]
# ## 8. Evaluación en Test Set

# %%
# ============================================================================
# SECCIÓN 8: EVALUACIÓN EN TEST SET
# ============================================================================

# Cargar mejor modelo y evaluar en test set
BEST_MODEL_PATH = str(LOGS_DIR / EXPERIMENT_NAME / "weights" / "best.pt")

if safe_exists(BEST_MODEL_PATH):
    print(f"🔄 Cargando mejor modelo: {BEST_MODEL_PATH}")
    
    # Cargar modelo
    model = load_yolo26_model(BEST_MODEL_PATH)
    
    if model:
        # Mostrar información del modelo
        print_model_summary(model)
        
        # Evaluar en test set
        print("\n🔍 Evaluando en Test Set (PyTorch)...")
        eval_results_pytorch = evaluate_model(
            model=model,
            data_yaml=DATA_YAML,
            split="test",
            imgsz=IMGSZ,
            conf_threshold=CONF_THRESHOLD,
            iou_threshold=IOU_THRESHOLD,
            end2end=True,  # NMS-free para YOLO26
            verbose=True,
        )
        
        if eval_results_pytorch:
            # Guardar confusion matrix
            if eval_results_pytorch.confusion_matrix is not None:
                cm_path = str(REPORTS_DIR / f"{EXPERIMENT_NAME}_confusion_matrix.png")
                plot_confusion_matrix(
                    confusion_matrix=eval_results_pytorch.confusion_matrix,
                    class_names=CLASS_NAMES,
                    save_path=cm_path,
                    title=f"YOLO26n - {VERSION} - Confusion Matrix",
                    normalize=True,
                    show=True,
                )
        else:
            print("⚠️ Error en evaluación")
else:
    print(f"❌ Modelo no encontrado: {BEST_MODEL_PATH}")
# Out:
# 🔄 Cargando mejor modelo: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best.pt
# 🔄 Cargando modelo: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best.pt
# ✅ Modelo cargado: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best.pt
#
# ============================================================
# 📋 RESUMEN DEL MODELO YOLO26
# ============================================================
# 🎯 Tarea: detect
# 📦 Clases: 5
#    ['obstacle', 'dog', 'person', 'stair', 'door']
# 📊 Parámetros totales: 2.51M
# 📊 Parámetros entrenables: 0.00M
#
# 💾 Tamaño estimado del modelo:
#    FP32: 9.56 MB
#    FP16: 4.78 MB
#    INT8: 2.39 MB
#    ⚠️ Ajustado para ESP32-S3 - considerar optimizaciones
# ============================================================
#
#
# 🔍 Evaluando en Test Set (PyTorch)...
#
# 🔍 Evaluando modelo en split: test
#    📂 Resultados en: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/val
# Ultralytics 8.4.9 🚀 Python-3.10.19 torch-2.5.1 CPU (Apple M1)
# YOLO26n summary (fused): 122 layers, 2,375,811 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 0.1±0.0 ms, read: 158.9±31.3 MB/s, size: 46.2 KB)
# val: Scanning /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/labels/test... 2138 images, 4 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2138/2138 5.3Kit/s 0.4s<0.0s
# val: New cache created: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/labels/test.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 8, len(boxes) = 4000. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 134/134 2.2it/s 1:010.5sss
#                    all       2138       4000      0.755      0.534      0.659      0.448
#               obstacle        468       1091      0.628      0.528      0.617      0.413
#                    dog        254        713      0.752      0.494      0.607      0.353
#                 person        148        572      0.727      0.316      0.527      0.319
#                  stair        753        870      0.805      0.643      0.748      0.507
#                   door        581        754      0.863      0.691      0.794      0.646
# Speed: 0.1ms preprocess, 26.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/val
# ============================================================
# 📊 RESULTADOS DE EVALUACIÓN: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best.pt
# ============================================================
# 🎯 mAP@50: 0.6587 (65.9%)
# 🎯 mAP@50-95: 0.4476 (44.8%)
# 📈 Precision: 0.7550
# 📈 Recall: 0.5343
# 📈 F1-Score: 0.6258
#
# 📋 mAP@50 por clase:
#
# 📸 Imágenes: 0
# 🔍 Predicciones: 0
# ✅ Ground Truth: 0
# ⏱️ Tiempo promedio: 0.00 ms
# ============================================================
# ✅ Confusion matrix guardada en: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/reports/yolo26n_v2/yolo26n_v2_confusion_matrix.png

# %%
# ============================================================================
# SECCIÓN 8B: VISUALIZACIÓN DE PREDICCIONES EN TEST SET
# ============================================================================

# Visualizar predicciones en imágenes aleatorias del test set
# YOLO26 es NMS-free (end-to-end), por lo que no requiere post-procesado

from src_yolo import visualize_yolo_predictions_grid

if model is not None:
    # Directorio de imágenes de test
    test_images_dir = str(YOLO_DATASET_DIR / "images" / "test")
    
    print("🖼️ Visualizando predicciones en imágenes de test...")
    print(f"   📂 Directorio: {test_images_dir}")
    print(f"   🎯 Umbral confianza: {CONF_THRESHOLD}")
    print(f"   💡 YOLO26 es NMS-free (end-to-end inference)")
    
    fig = visualize_yolo_predictions_grid(
        model=model,
        images_dir=test_images_dir,
        class_names=CLASS_NAMES,
        imgsz=IMGSZ,
        num_samples=12,
        conf_threshold=CONF_THRESHOLD,
        random_seed=None,  # None = selección aleatoria cada vez
        save_path=str(REPORTS_DIR / f"{EXPERIMENT_NAME}_predictions_grid.png"),
        title=f"Predicciones YOLO26n - {VERSION} (NMS-free)",
        max_cols=4,
    )
    
    plt.show()
    print("✅ Predicciones visualizadas (imágenes aleatorias del test set)")
else:
    print("⚠️ Modelo no disponible para visualización")
# Out:
# 🖼️ Visualizando predicciones en imágenes de test...
#    📂 Directorio: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/images/test
#    🎯 Umbral confianza: 0.25
#    💡 YOLO26 es NMS-free (end-to-end inference)
# ✅ Visualización guardada en: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/reports/yolo26n_v2/yolo26n_v2_predictions_grid.png
# ✅ Predicciones visualizadas (imágenes aleatorias del test set)

# %% [markdown]
# ## 9. Exportación a TFLite INT8

# %%
# ============================================================================
# SECCIÓN 9: EXPORTACIÓN A TFLITE INT8
# ============================================================================

# Exportar modelo a TFLite con cuantización INT8
# YOLO26 es DFL-free, lo que mejora la calidad de cuantización

TFLITE_OUTPUT_DIR = str(MODELS_DIR / "tflite")

if safe_exists(BEST_MODEL_PATH):
    # Estimar tamaño antes de exportar
    print("📊 Estimación de tamaño del modelo:")
    estimate_model_size(BEST_MODEL_PATH)
    
    print("\n🔄 Exportando a TFLite INT8...")
    print("   💡 YOLO26 es DFL-free → mejor cuantización INT8")
    print("   💡 End-to-end export → inferencia NMS-free")
    
    tflite_path = export_tflite_int8(
        model_path=BEST_MODEL_PATH,
        output_dir=TFLITE_OUTPUT_DIR,
        data_yaml=DATA_YAML,
        imgsz=IMGSZ,
        end2end=True,  # NMS-free
    )
    
    if tflite_path:
        TFLITE_MODEL_PATH = tflite_path
        print(f"\n✅ Modelo TFLite exportado: {TFLITE_MODEL_PATH}")
        
        # Verificar modelo exportado
        verification = verify_tflite_model(TFLITE_MODEL_PATH, imgsz=IMGSZ)
        
        if verification.get("valid"):
            print("\n✅ Verificación exitosa:")
            print(f"   Input shape: {verification.get('input_shape')}")
            print(f"   Output shapes: {verification.get('output_shapes')}")
            print(f"   Inference time: {verification.get('inference_time_ms', 0):.2f} ms")
    else:
        print("❌ Error en exportación TFLite")
        TFLITE_MODEL_PATH = None
else:
    print(f"❌ Modelo PyTorch no encontrado: {BEST_MODEL_PATH}")
    TFLITE_MODEL_PATH = None
# Out:
# 📊 Estimación de tamaño del modelo:
#
# 📊 Estimación de tamaño del modelo:
#    PyTorch: 5.09 MB
#    FP32 TFLite: ~2.40 MB
#    FP16 TFLite: ~1.20 MB
#    INT8 TFLite: ~0.60 MB
#    ESP32-S3: ✅ Compatible
#
# 🔄 Exportando a TFLite INT8...
#    💡 YOLO26 es DFL-free → mejor cuantización INT8
#    💡 End-to-end export → inferencia NMS-free
#
# 🔄 Exportando modelo a TFLite...
#    📥 Entrada: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best.pt
#    📐 Tamaño: 224x224
#    🔢 Cuantización: INT8
#    🎯 End-to-end (NMS-free): True
#    📊 Datos calibración: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/data.yaml
# Ultralytics 8.4.9 🚀 Python-3.10.19 torch-2.5.1 CPU (Apple M1)
# YOLO26n summary (fused): 122 layers, 2,375,811 parameters, 0 gradients, 5.2 GFLOPs
#
# PyTorch: starting from '/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 300, 6) (5.1 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.1...
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/data.yaml'
# Fast image access ✅ (ping: 0.0±0.0 ms, read: 308.2±148.2 MB/s, size: 87.9 KB)
# Scanning /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/labels/val.cache... 2137 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2137/2137 746.9Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 11, len(boxes) = 4125. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#
# ONNX: starting export with onnx 1.15.0 opset 19...
# ONNX: slimming with onnxslim 0.1.83...
# ONNX: export success ✅ 1.7s, saved as '/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best.onnx' (9.2 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770397900.127696   82817 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1770397900.128612   82817 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Saved artifact at '/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 224, 224, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 300, 6), dtype=tf.float32, name=None)
# Captures:
#   5941659600: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   5941659248: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   5941665584: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   5942138608: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   5942140192: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   5942256816: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   5942262800: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   5942148288: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   5956541024: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5956537504: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5956464208: TensorSpec(shape=(3, 3, 16, 8), dtype=tf.float32, name=None)
#   5956538736: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   5956536448: TensorSpec(shape=(3, 3, 8, 16), dtype=tf.float32, name=None)
#   5956544544: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   5956540496: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5956541552: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5941672976: TensorSpec(shape=(1, 1, 48, 64), dtype=tf.float32, name=None)
#   5941662592: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5941431632: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   5941428816: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   5930299136: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13514750288: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   5930301248: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13522028496: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13522028672: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13107800096: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   13522035888: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13443750320: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   13443746096: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13522028848: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13522036592: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13467917072: TensorSpec(shape=(1, 1, 96, 128), dtype=tf.float32, name=None)
#   13467923936: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13107026176: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   13107029168: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   6062110528: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13107024944: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   13480286464: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13480287344: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13480289456: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   4423021696: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   13019216384: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13445827040: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   13496340496: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13496349296: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   13094577680: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13103162720: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   5956850736: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13103167296: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   13445826160: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   5956855664: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13445831440: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13445111776: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   13445108960: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13480282768: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13480287168: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13445116176: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   13445109488: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13445346960: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   13445341856: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   5907045664: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   13445343792: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   5907050944: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   5906760976: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5906768016: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5906902608: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   5906900320: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5906447200: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   5906440864: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5906018752: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   5906017344: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5906007664: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   5906244080: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5906440160: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   5906433824: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   5906246720: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5906434352: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5906046416: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   5906049760: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   5906766080: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5906768544: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5906365456: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   5906352608: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   5906380080: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   5930468624: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   5930653952: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   5930654480: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   5930433728: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   5930433376: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   5930431264: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   5930376480: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   13469141824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13433502912: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13433490944: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   13434384832: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13433483008: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   13434388176: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   13469798944: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   13469910112: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13109714560: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   13109715792: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   13109601984: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   13109599168: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13109330336: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13109334912: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13469796304: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   13469810032: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13109787136: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   13109782384: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13109783264: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   14179703392: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   14179709024: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   14179139824: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   14179155664: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   13109368208: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   14179859472: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13109368736: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   14179167648: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   14179756240: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13109340016: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13109336144: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   14179847504: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   14179140704: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   14179163776: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   13473647952: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13474115680: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13474117440: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13474118320: TensorSpec(shape=(1, 1, 32, 16), dtype=tf.float32, name=None)
#   13474116384: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13473592800: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   13473584352: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13473603376: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   13474114448: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13474035168: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   13474034992: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13474028832: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   13473601264: TensorSpec(shape=(1, 1, 32, 16), dtype=tf.float32, name=None)
#   13473552640: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13473601792: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13473676656: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   13473675600: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13474112160: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13474115856: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13473236416: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   13435276448: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13435287712: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   13435282080: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   13435150128: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13435364176: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   13435364704: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   5941490288: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5941484480: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5941486064: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   5941335968: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   5941352176: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   5941357808: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   5941470032: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   5941323104: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   5941302320: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   13432738864: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   5941305840: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   5941461936: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   13432745904: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   5941463168: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   13432692176: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   13432748896: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5941547904: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   5941550368: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13433048224: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   13433047344: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13432827120: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   13432830992: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   13432964896: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13432761584: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   13432537504: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   13431986256: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13431990128: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13431987664: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   13432286976: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13432280112: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   13431821008: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13431439776: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   13431447344: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   13431494560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13431303936: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   5930996784: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   13431494208: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   5930999248: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   13431307632: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   5931414832: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   13431491920: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13431993120: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13431996112: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   13431369296: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   13431371408: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   5931387008: TensorSpec(shape=(3, 3, 256, 1), dtype=tf.float32, name=None)
#   13432972640: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   13435289840: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   5931392288: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   13432965248: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   13435289664: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5930943232: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   13432763696: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   13435356784: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   5930950976: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13432764224: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13435358016: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5931118512: TensorSpec(shape=(3, 3, 256, 16), dtype=tf.float32, name=None)
#   13432970176: TensorSpec(shape=(3, 3, 128, 16), dtype=tf.float32, name=None)
#   13435151184: TensorSpec(shape=(3, 3, 64, 16), dtype=tf.float32, name=None)
#   5931116928: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13432970704: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13435152768: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   5931350176: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   13432435312: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   13435432880: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   5931350000: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13432435136: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13435343744: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5931035536: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   13433227040: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   13435351840: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   5931038528: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13433240944: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   13435349200: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   5931309312: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   13431816256: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   5941469328: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   5931307024: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   13431817488: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5941469856: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   5931118336: TensorSpec(shape=(1, 1, 16, 4), dtype=tf.float32, name=None)
#   13432490816: TensorSpec(shape=(1, 1, 16, 4), dtype=tf.float32, name=None)
#   13435377920: TensorSpec(shape=(1, 1, 16, 4), dtype=tf.float32, name=None)
#   5931399504: TensorSpec(shape=(4,), dtype=tf.float32, name=None)
#   13432493104: TensorSpec(shape=(4,), dtype=tf.float32, name=None)
#   13435298640: TensorSpec(shape=(4,), dtype=tf.float32, name=None)
#   13491627888: TensorSpec(shape=(1, 1, 64, 5), dtype=tf.float32, name=None)
#   13431269760: TensorSpec(shape=(1, 1, 64, 5), dtype=tf.float32, name=None)
#   5941290160: TensorSpec(shape=(1, 1, 64, 5), dtype=tf.float32, name=None)
#   13491623664: TensorSpec(shape=(5,), dtype=tf.float32, name=None)
#   13431270288: TensorSpec(shape=(5,), dtype=tf.float32, name=None)
#   5941285584: TensorSpec(shape=(5,), dtype=tf.float32, name=None)
#   13491032432: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   13491034368: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   13491028912: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   13491028032: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   13491033136: TensorSpec(shape=(1, 2, 1029), dtype=tf.float32, name=None)
#   13491039472: TensorSpec(shape=(1, 2, 1029), dtype=tf.float32, name=None)
#   5940538080: TensorSpec(shape=(), dtype=tf.int64, name=None)
#   6290745904: TensorSpec(shape=(2, 1), dtype=tf.int32, name=None)
#   6290741152: TensorSpec(shape=(2,), dtype=tf.int32, name=None)
#   5956906928: TensorSpec(shape=(), dtype=tf.float32, name=None)
#   5957300144: TensorSpec(shape=(), dtype=tf.int64, name=None)
#   13108558864: TensorSpec(shape=(2, 1), dtype=tf.int32, name=None)
#   13108556224: TensorSpec(shape=(2,), dtype=tf.int32, name=None)
#   5956898656: TensorSpec(shape=(), dtype=tf.int64, name=None)
# I0000 00:00:1770397920.718439   82817 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770397920.719240   82817 single_machine.cc:374] Starting new session
# I0000 00:00:1770397920.720077   82817 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1770397920.720085   82817 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# W0000 00:00:1770397921.266661   82817 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1770397921.266675   82817 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1770397921.816574   82817 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# I0000 00:00:1770397921.816644   82817 single_machine.cc:374] Starting new session
# I0000 00:00:1770397921.816763   82817 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1770397921.816773   82817 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# W0000 00:00:1770397922.256279   82817 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1770397922.256296   82817 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1770397922.785401   82817 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# I0000 00:00:1770397922.785476   82817 single_machine.cc:374] Starting new session
# I0000 00:00:1770397922.785583   82817 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1770397922.785592   82817 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# W0000 00:00:1770397923.219549   82817 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1770397923.219561   82817 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# W0000 00:00:1770397926.254803   82817 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1770397926.254839   82817 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1770397926.284196   82817 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# W0000 00:00:1770398314.695059   82817 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1770398314.695077   82817 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# W0000 00:00:1770398700.795752   82817 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1770398700.795790   82817 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# W0000 00:00:1770399461.670847   82817 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1770399461.670872   82817 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# TensorFlow SavedModel: export success ✅ 2336.2s, saved as '/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best_saved_model' (31.1 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.1...
# TensorFlow Lite: export success ✅ 0.0s, saved as '/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best_saved_model/best_int8.tflite' (2.6 MB)
#
# Export complete (2336.4s)
# Results saved to /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights
# Predict:         yolo predict task=detect model=/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best_saved_model/best_int8.tflite imgsz=224 int8
# Validate:        yolo val task=detect model=/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best_saved_model/best_int8.tflite imgsz=224 data=/Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/datasets/yolo26/data.yaml int8
# Visualize:       https://netron.app
#
# ✅ Exportación completada en 2336.4s
#    📁 Modelo: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best_saved_model/best_int8.tflite
#    📦 Tamaño: 2.55 MB
#    ⚠️ Ajustado para ESP32-S3 - verificar memoria
#
# ✅ Modelo TFLite exportado: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best_saved_model/best_int8.tflite
#
# ✅ Verificación TFLite exitosa:
#    📁 Modelo: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26n_v2/weights/best_saved_model/best_int8.tflite
#    📦 Tamaño: 2.55 MB
#    📐 Input: [1, 224, 224, 3] (<class 'numpy.float32'>)
#    📤 Outputs: 1
#    ⏱️ Inferencia: 6.27 ms
#
# ✅ Verificación exitosa:
#    Input shape: [1, 224, 224, 3]
#    Output shapes: [[1, 300, 6]]
#    Inference time: 6.27 ms
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# ## 10. Comparación PyTorch vs TFLite

# %%
# ============================================================================
# SECCIÓN 10: COMPARACIÓN PYTORCH VS TFLITE
# ============================================================================

# Comparación exhaustiva entre PyTorch y TFLite INT8
# Métricas calculadas:
#   - Tiempos de inferencia y speedup
#   - Conteo de detecciones (filtradas por confianza)
#   - Agreement rate (% de detecciones coincidentes via IoU)
#   - IoU estadísticas entre detecciones matched
#   - Comparación de confianzas (correlación, diferencia media)
#   - Métricas por clase
#   - Comparación visual side-by-side (3 imágenes aleatorias)

# Nota: Usa CONF_THRESHOLD e IOU_THRESHOLD definidos en Sección 2

# Recargar módulo para usar la versión actualizada
import importlib
import src_yolo.utils_yolo_export
importlib.reload(src_yolo.utils_yolo_export)
from src_yolo.utils_yolo_export import compare_keras_vs_tflite

if TFLITE_MODEL_PATH and safe_exists(TFLITE_MODEL_PATH):
    import cv2
    
    # Cargar imágenes de test para comparación
    test_images_dir = YOLO_DATASET_DIR / "images" / "test"
    test_images = []
    
    if test_images_dir.exists():
        # Usar todas las imágenes de test para comparación más robusta
        image_files = sorted([f for f in test_images_dir.iterdir() 
                             if f.suffix.lower() in ['.jpg', '.jpeg', '.png']])
        
        print(f"📂 Cargando {len(image_files)} imágenes de test...")
        for img_file in image_files:
            img = cv2.imread(str(img_file))
            if img is not None:
                # Resize to model input size
                img_resized = cv2.resize(img, (IMGSZ, IMGSZ))
                test_images.append(img_resized)
    
    if test_images:
        print(f"🔄 Comparando PyTorch vs TFLite con {len(test_images)} imágenes...")
        print(f"   Conf threshold: {CONF_THRESHOLD}")
        print(f"   IoU threshold:  {IOU_THRESHOLD}")
        
        comparison = compare_keras_vs_tflite(
            keras_model=model,
            tflite_path=TFLITE_MODEL_PATH,
            test_images=test_images,
            class_names=CLASS_NAMES,
            imgsz=IMGSZ,
            conf_threshold=CONF_THRESHOLD,
            iou_threshold=IOU_THRESHOLD,
            save_path=str(REPORTS_DIR / f"{EXPERIMENT_NAME}_pytorch_vs_tflite.png"),
            experiment_name=EXPERIMENT_NAME,
            num_visual_samples=3,
        )
        
        # Mostrar la comparación visual en el notebook
        if comparison.get("visual_comparison_fig"):
            import matplotlib.pyplot as plt
            plt.show()
    else:
        print("⚠️ No se encontraron imágenes de test para comparación")
        comparison = None
else:
    print("⚠️ Modelo TFLite no disponible para comparación")
    comparison = None
# Out:
# 📂 Cargando 2138 imágenes de test...
# 🔄 Comparando PyTorch vs TFLite con 2138 imágenes...
#    Conf threshold: 0.25
#    IoU threshold:  0.5
#
# 🔄 Ejecutando inferencia PyTorch...
# 🔄 Ejecutando inferencia TFLite...
#
# 📸 Comparación visual guardada: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/reports/yolo26n_v2/yolo26n_v2_pytorch_vs_tflite.png
#
# ============================================================
# 📊 COMPARACIÓN PYTORCH vs TFLITE
# ============================================================
#
# ⏱️ Tiempos de inferencia:
#    PyTorch: 13.30 ms/img
#    TFLite:  5.25 ms/img
#    Speedup: 2.53x
#
# 🔢 Detecciones (conf >= 0.25):
#    PyTorch: 2850 (1.3/img)
#    TFLite:  2513 (1.2/img)
#
# 🎯 Concordancia (IoU >= 0.5):
#    Agreement rate: 78.3%
#    Matched: 2231
#    Unmatched PyTorch: 619
#    Unmatched TFLite: 282
#
# 📐 IoU entre detecciones coincidentes:
#    Mean: 0.946
#    Min:  0.507
#    Max:  0.997
#    Std:  0.057
#
# 🔬 Comparación de confianzas:
#    Mean PyTorch: 0.616
#    Mean TFLite:  0.582
#    Diff (Py-TF): +0.035
#    Correlation:  0.769
#
# 📋 Concordancia por clase:
#    obstacle: Py=993, TF=772, Agreement=66.8%
#    dog: Py=399, TF=364, Agreement=79.4%
#    person: Py=248, TF=212, Agreement=76.6%
#    stair: Py=648, TF=607, Agreement=83.8%
#    door: Py=562, TF=558, Agreement=92.2%
# ============================================================

# %% [markdown]
# ## 11. Guardado de Resultados del Experimento

# %%
# ============================================================================
# SECCIÓN 11: GUARDADO DE RESULTADOS DEL EXPERIMENTO
# ============================================================================

from src_yolo.utils_io import safe_filesize_mb

# Crear configuración del experimento
experiment_config = Yolo26ExperimentConfig(
    name=EXPERIMENT_NAME,
    description=DESCRIPTION,
    model=f"{MODEL_VARIANT}.pt",
    imgsz=IMGSZ,
    epochs=train_config.epochs,
    patience=train_config.patience,
    batch=train_config.batch,
    optimizer=train_config.optimizer,
    lr0=train_config.lr0,
    lrf=train_config.lrf,
    cos_lr=train_config.cos_lr,
    mosaic=train_config.mosaic,
    mixup=train_config.mixup,
    close_mosaic=train_config.close_mosaic,
    box=train_config.box,
    cls=train_config.cls,
    num_classes=NUM_CLASSES,
    class_names=CLASS_NAMES,
    end2end=True,
    conf_threshold=CONF_THRESHOLD,
    iou_threshold=IOU_THRESHOLD,
    data_yaml=DATA_YAML,
    project_dir=str(LOGS_DIR),
)

# Crear resultados del experimento
experiment_results = Yolo26ExperimentResults()

# Métricas de entrenamiento (si existen)
if 'best_metrics' in dir():
    experiment_results.best_epoch = best_metrics.get('best_mAP50_epoch', 0)

# Métricas de evaluación PyTorch (si existen)
if 'eval_results_pytorch' in dir() and eval_results_pytorch:
    # Métricas principales
    experiment_results.map50_keras = eval_results_pytorch.map50
    experiment_results.map50_95_keras = eval_results_pytorch.map50_95
    experiment_results.precision_keras = eval_results_pytorch.precision
    experiment_results.recall_keras = eval_results_pytorch.recall
    experiment_results.f1_keras = eval_results_pytorch.f1_score
    
    # Métricas por clase
    experiment_results.per_class_ap50_keras = eval_results_pytorch.per_class_ap50 or {}
    experiment_results.per_class_precision_keras = getattr(eval_results_pytorch, 'per_class_precision', {}) or {}
    experiment_results.per_class_recall_keras = getattr(eval_results_pytorch, 'per_class_recall', {}) or {}
    
    # Matriz de confusión (convertir np.ndarray a lista para JSON)
    if eval_results_pytorch.confusion_matrix is not None:
        experiment_results.confusion_matrix = eval_results_pytorch.confusion_matrix.tolist()
        # Guardar también el path de la imagen de la matriz
        cm_image_path = str(REPORTS_DIR / f"{EXPERIMENT_NAME}_confusion_matrix.png")
        if safe_exists(cm_image_path):
            experiment_results.confusion_matrix_path = cm_image_path
    
    # Estadísticas de evaluación
    experiment_results.total_images = getattr(eval_results_pytorch, 'total_images', 0)
    experiment_results.total_predictions = getattr(eval_results_pytorch, 'total_predictions', 0)
    experiment_results.total_ground_truth = getattr(eval_results_pytorch, 'total_ground_truth', 0)
    experiment_results.inference_time_pytorch_ms = getattr(eval_results_pytorch, 'avg_inference_time_ms', 0.0)

# Comparación PyTorch vs TFLite (si existe)
if 'comparison' in dir() and comparison:
    # Métricas básicas de timing
    experiment_results.comparison_speedup = comparison.get('speedup', 0.0)
    experiment_results.inference_time_tflite_ms = comparison.get('tflite_time_ms', 0.0)
    if experiment_results.inference_time_pytorch_ms == 0.0:
        experiment_results.inference_time_pytorch_ms = comparison.get('keras_time_ms', 0.0)
    
    # Conteo de detecciones
    experiment_results.comparison_keras_detections = comparison.get('keras_detections', 0)
    experiment_results.comparison_tflite_detections = comparison.get('tflite_detections', 0)
    experiment_results.comparison_keras_detections_per_image = comparison.get('keras_detections_per_image', 0.0)
    experiment_results.comparison_tflite_detections_per_image = comparison.get('tflite_detections_per_image', 0.0)
    
    # Métricas de concordancia (agreement)
    experiment_results.comparison_agreement_rate = comparison.get('agreement_rate', 0.0)
    experiment_results.comparison_matched_detections = comparison.get('matched_detections', 0)
    experiment_results.comparison_unmatched_keras = comparison.get('unmatched_keras', 0)
    experiment_results.comparison_unmatched_tflite = comparison.get('unmatched_tflite', 0)
    
    # Estadísticas de IoU entre detecciones coincidentes
    experiment_results.comparison_mean_iou = comparison.get('mean_iou', 0.0)
    experiment_results.comparison_min_iou = comparison.get('min_iou', 0.0)
    experiment_results.comparison_max_iou = comparison.get('max_iou', 0.0)
    experiment_results.comparison_std_iou = comparison.get('std_iou', 0.0)
    
    # Comparación de confianzas
    experiment_results.comparison_mean_conf_keras = comparison.get('mean_conf_keras', 0.0)
    experiment_results.comparison_mean_conf_tflite = comparison.get('mean_conf_tflite', 0.0)
    experiment_results.comparison_mean_conf_diff = comparison.get('mean_conf_diff', 0.0)
    experiment_results.comparison_conf_correlation = comparison.get('conf_correlation', 0.0)
    
    # Métricas por clase
    experiment_results.comparison_per_class_agreement = comparison.get('per_class_agreement', {})
    experiment_results.comparison_per_class_detections_keras = comparison.get('per_class_detections_keras', {})
    experiment_results.comparison_per_class_detections_tflite = comparison.get('per_class_detections_tflite', {})

# Paths y tamaños
if safe_exists(BEST_MODEL_PATH):
    experiment_results.best_model_path = BEST_MODEL_PATH
    experiment_results.pytorch_model_size_mb = safe_filesize_mb(BEST_MODEL_PATH) or 0.0

if TFLITE_MODEL_PATH and safe_exists(TFLITE_MODEL_PATH):
    experiment_results.tflite_model_path = TFLITE_MODEL_PATH
    experiment_results.tflite_int8_size_mb = safe_filesize_mb(TFLITE_MODEL_PATH) or 0.0

# Historia CSV
history_csv_path = str(LOGS_DIR / f"{EXPERIMENT_NAME}_history.csv")
if safe_exists(history_csv_path):
    experiment_results.history_csv_path = history_csv_path

# Crear objeto de experimento completo
experiment = Yolo26Experiment(
    config=experiment_config,
    results=experiment_results,
    status="completed",
    notes=EXPERIMENT_NOTES,
)

# Guardar experimento
experiment_file = save_experiment(
    experiment=experiment,
    experiments_dir=str(EXPERIMENTS_DIR),
)

# Mostrar resumen
print(experiment.summary())
# Out:
# ✅ Experimento guardado: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/experiments/yolo26n_v2_20260206_134026.json
# ======================================================================
# 🔬 EXPERIMENTO: yolo26n_v2
# ======================================================================
# 📝 Descripción: Segundo entrenenamiento YOLO26n para ESP32-S3.
# Objetivo: Probar el desempeño con un nuevo dataset optimizado, balanceado y aumentado.
# 📅 Timestamp: 20260206_134026
# 📊 Status: completed
#
# ⚙️ Configuración:
#    Modelo: yolo26n.pt | Tamaño: 224x224
#    Épocas: 5 | Batch: 16
#    Optimizer: MuSGD | LR: 0.01
#    Mosaic: 1.0 | Mixup: 0.15
#    End-to-end: True
#
# 📊 Resultados:
#    mAP@50 (PyTorch): 0.6587
#    mAP@50 (TFLite):  0.0000
#    Gap:              0.6587
#
#    Precision: 0.7550
#    Recall:    0.5343
#    F1-Score:  0.6258
#
#    Tamaño TFLite INT8: 2.55 MB
#    Tiempo inferencia:  5.25 ms
#
# 📝 Notas: Análisis del problema:
# 1. Dataset: 27,264 anotaciones (obstacle:7,502, dog:4941, person: 4314, stair: 5,778 , door: 4,729)
# 2. Se elimina el uso de la clase 'footpath'.
# 3. Se tiene un dataset mucho más equilibrado, con media de : 5452.8 anotaciones por clase, lo que debería mejorar la capacidad de generalización del modelo.
#
# Configuración justificada:
# - EPOCHS=5: En esta primera prueba, se reduce a 5 para validar la configuración y evitar largos tiempos de entrenamiento (se aumentará en futuros experimentos)
# - PATIENCE=4: Early stopping moderado para evitar overfitting
# - LR0=0.01: Default Ultralytics, mayor que v0 para mejor convergencia
# - MOSAIC=1.0: Máximo para mejorar detección de objetos pequeños (obstacle)
# - MIXUP=0.15: Bajo-moderado, regularización sin confusión
# - CLS_LOSS_WEIGHT=1.0: Aumentado para mejorar clasificación (problema en MobileNetV3)
# - SCALE=0.5: ±50% escala para variabilidad de tamaños de obstacle
#
# Objetivos: (mantener los de la v1)
# - mAP@50 (Keras) ≥ 0.65 (vs 0.606 MobileNetV3)
# - mAP@50 (TFLite) ≥ 0.60 (vs 0.574 MobileNetV3)
# - Precision ≥ 0.50 (vs 0.204 MobileNetV3)
# - Recall ≥ 0.55 (vs 0.419 MobileNetV3)
# - F1 ≥ 0.52 (vs 0.274 MobileNetV3)
# ======================================================================

# %% [markdown]
# ## 12. Comparación de Experimentos

# %%
# ============================================================================
# SECCIÓN 12: COMPARACIÓN DE EXPERIMENTOS
# ============================================================================

from src_yolo import print_experiments_table, export_experiments_csv

# Cargar todos los experimentos guardados
all_experiments = load_all_experiments(str(EXPERIMENTS_DIR))

if all_experiments:
    # Mostrar tabla comparativa
    print_experiments_table(all_experiments)
    
    # Exportar comparación a CSV
    comparison_csv = str(LOGS_DIR / "yolo26_experiments_comparison.csv")
    export_experiments_csv(all_experiments, comparison_csv)
    
    # Crear DataFrame para análisis
    comparison_df = compare_experiments(all_experiments, sort_by="map50_keras", ascending=False)
    
    if not comparison_df.empty:
        print("\n📊 Top 5 experimentos por mAP@50:")
        display_cols = ["name", "map50_keras", "precision_keras", "recall_keras", "tflite_size_mb"]
        display_cols = [c for c in display_cols if c in comparison_df.columns]
        print(comparison_df[display_cols].head(5).to_string(index=False))
else:
    print("ℹ️ No hay experimentos previos para comparar")
# Out:
# 📦 Cargados 12 experimentos de /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/experiments
#
# ====================================================================================================
# 📊 COMPARACIÓN DE EXPERIMENTOS YOLO26
# ====================================================================================================
# Name                       mAP@50 PT  mAP@50 TF      Gap     Prec      Rec  Size MB
# ----------------------------------------------------------------------------------------------------
# yolo26n_v2                    0.6587     0.0000   0.6587   0.7550   0.5343     2.55
# yolo26n_v2                    0.6587     0.0000   0.6587   0.7550   0.5343     2.55
# yolo26n_v1                    0.6231     0.0000   0.6231   0.6716   0.5303     2.54
# MBNTv3_ssdlite_v3             0.6059     0.5744   0.0315   0.2036   0.4188     0.00
# MBNTv3L_ssdlite_v6            0.5757     0.5766   0.0009   0.3580   0.3625     0.00
# MBNTv3_ssdlite_v1             0.5675     0.5509   0.0165   0.2674   0.4313     0.00
# MBNTv3_ssdlite_v7             0.5591     0.5437   0.0154   0.4238   0.4000     0.00
# MBNTv3_ssdlite_v5             0.5492     0.4705   0.0787   0.4071   0.3563     0.00
# MBNTv3_ssdlite_v4             0.4523     0.4501   0.0022   0.6933   0.3250     0.00
# MBNTv3_ssdlite_v2             0.4058     0.3624   0.0435   0.6863   0.2188     0.00
# yolo26n_v0                    0.3742     0.0000   0.3742   0.6875   0.0511     2.54
# yolo26n_v0                    0.3742     0.0000   0.3742   0.6875   0.0511     2.54
# ====================================================================================================
# ✅ Comparación exportada: /Users/admin/Documents/TFM_UNIR/02_ING_MODELOS/logs/yolo26_experiments_comparison.csv
#
# 📊 Top 5 experimentos por mAP@50:
#               name  map50_keras  precision_keras  recall_keras  tflite_size_mb
#         yolo26n_v2     0.658709         0.755048      0.534318        2.553693
#         yolo26n_v2     0.658709         0.755048      0.534318        2.553693
#         yolo26n_v1     0.623053         0.671593      0.530303        2.537229
#  MBNTv3_ssdlite_v3     0.605898         0.203647      0.418750        0.000000
# MBNTv3L_ssdlite_v6     0.575725         0.358025      0.362500        0.000000

# %% [markdown]
# ---
#
# ## 🎯 Resumen Final
#
# Este notebook ha completado el pipeline de entrenamiento YOLO26n:
#
# 1. ✅ **Setup**: Configuración de paths y imports
# 2. ✅ **Experimento**: Definición de versión y parámetros
# 3. ✅ **Dataset**: Conversión COCO → YOLO
# 4. ✅ **Análisis**: Distribución de clases y weights
# 5. ✅ **Config**: Hiperparámetros YOLO26 optimizados
# 6. ✅ **Training**: Entrenamiento con MuSGD y end-to-end
# 7. ✅ **Métricas**: Extracción y visualización
# 8. ✅ **Evaluación**: Métricas en test set
# 9. ✅ **Export**: TFLite INT8 para ESP32-S3
# 10. ✅ **Comparación**: PyTorch vs TFLite
# 11. ✅ **Guardado**: Experimento serializado
# 12. ✅ **Histórico**: Comparación de experimentos
#
# ### Próximos pasos:
# - Ajustar hiperparámetros según resultados
# - Probar variantes (yolo26s, yolo26m) si hay presupuesto de memoria
# - Deployment en ESP32-S3 con ESP-IDF
